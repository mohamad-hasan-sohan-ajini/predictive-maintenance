# %%
import random
from pathlib import Path

import numpy as np
import torch

DATA_DIR = Path("output")

OUTPUT_DIR = Path("model_outputs")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

RANDOM_STATE = 42


def set_seed(seed=RANDOM_STATE):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True, warn_only=True)


set_seed()

# %%
import json

WINDOW_SELECTION_PATH = OUTPUT_DIR / "xgboost_when" / "selected_window.json"
if not WINDOW_SELECTION_PATH.exists():
    raise FileNotFoundError(
        f"Missing window-selection manifest: {WINDOW_SELECTION_PATH}. "
        "Run BPA notebook 9 before this notebook."
    )

with WINDOW_SELECTION_PATH.open(encoding="utf-8") as file:
    window_selection = json.load(file)
if not isinstance(window_selection, dict):
    raise TypeError(f"{WINDOW_SELECTION_PATH} must contain a JSON object.")

required_selection_keys = {
    "selected_window_hours",
    "selection_metric",
    "selection_metric_value",
    "selected_dataset_path",
    "window_metrics_path",
    "selection_source",
}
missing_selection_keys = required_selection_keys - set(window_selection)
if missing_selection_keys:
    raise ValueError(
        f"{WINDOW_SELECTION_PATH} is missing keys: " f"{sorted(missing_selection_keys)}"
    )
if window_selection["selection_metric"] != "test_mae_seconds":
    raise ValueError(
        "Expected selection_metric='test_mae_seconds', found "
        f"{window_selection['selection_metric']!r}."
    )
if window_selection["selection_source"] != "stage_1_xgboost_window_comparison":
    raise ValueError(
        "Unexpected selection_source: " f"{window_selection['selection_source']!r}."
    )

try:
    WINDOW_HOURS = float(window_selection["selected_window_hours"])
    selection_metric_value = float(window_selection["selection_metric_value"])
except (TypeError, ValueError) as error:
    raise ValueError(
        "selected_window_hours and selection_metric_value must be numeric."
    ) from error
if (
    not np.isfinite(WINDOW_HOURS)
    or WINDOW_HOURS <= 0
    or not np.isfinite(selection_metric_value)
    or selection_metric_value < 0
):
    raise ValueError(
        "selected_window_hours must be positive and finite, and the MAE "
        "must be finite and non-negative."
    )

WINDOW_LABEL = f"{WINDOW_HOURS:g}h"
RUN_TAG = f"winsize{WINDOW_LABEL}"
selected_when_path = Path(window_selection["selected_dataset_path"])
expected_when_name = f"dataset_{RUN_TAG}_when.csv"
expected_when_path = DATA_DIR / expected_when_name
if selected_when_path.name != expected_when_name:
    raise ValueError(
        f"Manifest window/path mismatch: selected {WINDOW_LABEL}, but "
        f"selected_dataset_path is {selected_when_path}."
    )
if selected_when_path.resolve() != expected_when_path.resolve():
    raise ValueError(
        f"selected_dataset_path must resolve to {expected_when_path}, found "
        f"{selected_when_path}."
    )
if not selected_when_path.exists():
    raise FileNotFoundError(
        f"Selected WHEN dataset does not exist: {selected_when_path}"
    )

window_metrics_path = Path(window_selection["window_metrics_path"])
if not window_metrics_path.exists():
    raise FileNotFoundError(f"Selection metrics do not exist: {window_metrics_path}")

dataset_path = DATA_DIR / f"dataset_{RUN_TAG}_where.csv"
if not dataset_path.exists():
    raise FileNotFoundError(
        f"Missing WHERE dataset matching the selected window: {dataset_path}"
    )

MODEL_OUTPUT_DIR = OUTPUT_DIR / "where_transformer" / RUN_TAG
MODEL_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(
    f"Selected {WINDOW_LABEL} from {WINDOW_SELECTION_PATH} "
    f"({window_selection['selection_metric']}={selection_metric_value:.3f})."
)
print(f"Using WHERE dataset: {dataset_path}")
print(f"Writing artifacts to: {MODEL_OUTPUT_DIR}")
# Out:
# Selected 4h from model_outputs/xgboost_when/selected_window.json (test_mae_seconds=369.774).
# Using WHERE dataset: output/dataset_winsize4h_where.csv
# Writing artifacts to: model_outputs/where_transformer/winsize4h

# %%
import json

import pandas as pd

where_df = pd.read_csv(
    dataset_path,
    dtype={"fold_id": "int64"},
    converters={
        "window": json.loads,
        "label": json.loads,
    },
)
where_df = where_df.loc[~where_df["is_bg"]].drop(columns="is_bg")

where_df.head()
# Out:
#    fold_id                                             window  \
# 1        4  [{'from_zone_index': 5, 'to_zone_index': 5, 'o...
# 2        4  [{'from_zone_index': 5, 'to_zone_index': 1, 'o...
# 3        1  [{'from_zone_index': 5, 'to_zone_index': 1, 'o...
# 4        4  [{'from_zone_index': 5, 'to_zone_index': 5, 'o...
# 6        4  [{'from_zone_index': 5, 'to_zone_index': 5, 'o...
#
#                                         label
# 1  {'from_zone_index': 0, 'to_zone_index': 0}
# 2  {'from_zone_index': 2, 'to_zone_index': 2}
# 3  {'from_zone_index': 7, 'to_zone_index': 7}
# 4  {'from_zone_index': 9, 'to_zone_index': 9}
# 6  {'from_zone_index': 9, 'to_zone_index': 9}

# %%
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset

OUTAGE_TYPE_TO_ID = {
    "Planned": 0,
    "Auto": 1,
}


class WhereOutageDataset(Dataset):
    def __init__(self, df):
        self.df = df.reset_index(drop=True)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        window = row["window"]
        label = row["label"]

        outage_type = torch.tensor(
            [OUTAGE_TYPE_TO_ID[event["outage_type"]] for event in window],
            dtype=torch.long,
        )
        from_zone_indices = torch.tensor(
            [event["from_zone_index"] for event in window],
            dtype=torch.long,
        )
        to_zone_indices = torch.tensor(
            [event["to_zone_index"] for event in window],
            dtype=torch.long,
        )
        time_interval_index = torch.tensor(
            [event["time_interval_index"] for event in window],
            dtype=torch.long,
        )
        target = torch.tensor(
            [label["from_zone_index"], label["to_zone_index"]],
            dtype=torch.long,
        )

        return {
            "outage_type": outage_type,
            "from_zone_indices": from_zone_indices,
            "to_zone_indices": to_zone_indices,
            "time_interval_index": time_interval_index,
            "target": target,
        }


TRAIN_FOLDS = [0, 1, 2, 3, 4]
TEST_FOLDS = [-1]

train_where_dataset = WhereOutageDataset(
    where_df[where_df["fold_id"].isin(TRAIN_FOLDS)]
)
test_where_dataset = WhereOutageDataset(where_df[where_df["fold_id"].isin(TEST_FOLDS)])

# %%
for i, sample_dict in enumerate(train_where_dataset):
    print(sample_dict)
    if i == 10:
        break
# Out:
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([0, 0])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([1]), 'time_interval_index': tensor([0]), 'target': tensor([2, 2])}
# {'outage_type': tensor([0, 1, 1, 1, 1, 1, 1, 0]), 'from_zone_indices': tensor([ 5,  2,  2,  2,  2, 18,  1,  5]), 'to_zone_indices': tensor([1, 2, 2, 2, 2, 0, 1, 5]), 'time_interval_index': tensor([4, 4, 4, 4, 4, 0, 0, 0]), 'target': tensor([7, 7])}
# {'outage_type': tensor([1, 0]), 'from_zone_indices': tensor([5, 7]), 'to_zone_indices': tensor([5, 7]), 'time_interval_index': tensor([4, 0]), 'target': tensor([9, 9])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([9, 9])}
# {'outage_type': tensor([1, 1, 1, 1, 1, 1, 1, 0]), 'from_zone_indices': tensor([5, 5, 5, 5, 5, 5, 5, 7]), 'to_zone_indices': tensor([5, 5, 5, 5, 5, 5, 5, 7]), 'time_interval_index': tensor([3, 3, 3, 3, 1, 1, 1, 0]), 'target': tensor([5, 5])}
# {'outage_type': tensor([1, 0]), 'from_zone_indices': tensor([6, 5]), 'to_zone_indices': tensor([6, 5]), 'time_interval_index': tensor([4, 0]), 'target': tensor([5, 5])}
# {'outage_type': tensor([1, 0]), 'from_zone_indices': tensor([5, 5]), 'to_zone_indices': tensor([5, 5]), 'time_interval_index': tensor([4, 0]), 'target': tensor([5, 9])}
# {'outage_type': tensor([0, 0, 0, 0]), 'from_zone_indices': tensor([5, 5, 5, 5]), 'to_zone_indices': tensor([5, 5, 5, 5]), 'time_interval_index': tensor([1, 1, 0, 0]), 'target': tensor([5, 5])}
# {'outage_type': tensor([0, 0, 0, 0, 1, 1, 1, 1, 0]), 'from_zone_indices': tensor([5, 5, 5, 5, 5, 5, 5, 5, 3]), 'to_zone_indices': tensor([5, 5, 5, 5, 5, 5, 5, 5, 3]), 'time_interval_index': tensor([3, 3, 3, 3, 3, 3, 3, 3, 0]), 'target': tensor([11, 11])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([6, 6])}

# %%
observed_time_interval_indices = sorted(
    {
        int(event["time_interval_index"])
        for window in where_df["window"]
        for event in window
    }
)
if not observed_time_interval_indices:
    raise ValueError(
        f"The selected {WINDOW_LABEL} WHERE dataset contains no interval indices."
    )

NUM_TIME_INTERVALS = observed_time_interval_indices[-1] + 1
if observed_time_interval_indices != list(range(NUM_TIME_INTERVALS)):
    raise ValueError(
        "Time interval indices must be contiguous and zero-based; found "
        f"{observed_time_interval_indices}."
    )

train_time_interval_indices = {
    int(event["time_interval_index"])
    for window in where_df.loc[where_df["fold_id"].isin(TRAIN_FOLDS), "window"]
    for event in window
}
test_time_interval_indices = {
    int(event["time_interval_index"])
    for window in where_df.loc[where_df["fold_id"].isin(TEST_FOLDS), "window"]
    for event in window
}
if not train_time_interval_indices or not test_time_interval_indices:
    raise ValueError(
        f"The selected {WINDOW_LABEL} train or test split has no interval indices."
    )
if max(train_time_interval_indices | test_time_interval_indices) >= NUM_TIME_INTERVALS:
    raise ValueError("A train/test interval index exceeds the embedding size.")

print(
    f"{NUM_TIME_INTERVALS = }; "
    f"train={sorted(train_time_interval_indices)}, "
    f"test={sorted(test_time_interval_indices)}"
)
# Out:
# NUM_TIME_INTERVALS = 5; train=[0, 1, 2, 3, 4], test=[0, 1, 2, 3, 4]

# %% [markdown]
# # Model definitions for the selected WHERE window

# %%
MODEL_SCALE = 1

ZONE_EMBEDDING_DIM = int(64 * MODEL_SCALE)
OUTAGE_TYPE_EMBEDDING_DIM = int(32 * MODEL_SCALE)
TIME_INTERVAL_EMBEDDING_DIM = int(32 * MODEL_SCALE)
TRANSFORMER_DIM = int(256 * MODEL_SCALE)

DROPOUT = 0.15

# %%
import torch.nn as nn

num_zones = int(
    max(
        where_df["label"]
        .map(lambda x: max(x["from_zone_index"], x["to_zone_index"]))
        .max(),
        max(
            max(event["from_zone_index"], event["to_zone_index"])
            for window in where_df["window"]
            for event in window
        ),
    )
    + 1
)
num_outage_types = len(OUTAGE_TYPE_TO_ID)


class WhereTransformer(nn.Module):
    """ "Vanilla transformer model"""

    def __init__(
        self,
        num_zones,
        num_outage_types,
        num_time_intervals,
        zone_embedding_dim=ZONE_EMBEDDING_DIM,
        outage_type_embedding_dim=OUTAGE_TYPE_EMBEDDING_DIM,
        time_interval_embedding_dim=TIME_INTERVAL_EMBEDDING_DIM,
        transformer_dim=TRANSFORMER_DIM,
        dropout=DROPOUT,
    ):
        super().__init__()
        self.num_zones = num_zones
        self.num_time_intervals = int(num_time_intervals)
        self.zone_embedding = nn.Embedding(num_zones, zone_embedding_dim)
        self.outage_type_embedding = nn.Embedding(
            num_outage_types,
            outage_type_embedding_dim,
        )
        self.time_interval_embedding = nn.Embedding(
            self.num_time_intervals,
            time_interval_embedding_dim,
        )
        self.input_fc = nn.Linear(
            2 * zone_embedding_dim
            + outage_type_embedding_dim
            + time_interval_embedding_dim,
            transformer_dim,
        )
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=transformer_dim,
            nhead=transformer_dim // 64,
            dim_feedforward=transformer_dim * 4,
            dropout=dropout,
            batch_first=True,
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=1,
        )
        self.projection = nn.Linear(transformer_dim, 2 * num_zones)

    def forward(
        self,
        from_zone_indices,
        to_zone_indices,
        outage_type,
        time_interval_index,
    ):
        from_zone_emb = self.zone_embedding(from_zone_indices)
        to_zone_emb = self.zone_embedding(to_zone_indices)
        outage_type_emb = self.outage_type_embedding(outage_type)
        time_interval_emb = self.time_interval_embedding(time_interval_index)

        x = torch.cat(
            [from_zone_emb, to_zone_emb, outage_type_emb, time_interval_emb],
            dim=-1,
        )
        x = self.input_fc(x)

        x = self.transformer_encoder(x)

        # Pool the last event in this unpadded, one-sample sequence.
        pooled = x[:, -1, :]

        logits = self.projection(pooled)
        return logits.view(-1, 2, self.num_zones)

# %%
class GraphDistanceUnorderedZoneLoss(nn.Module):
    def __init__(
        self,
        graph,
        num_zones,
        distance_weight=0.2,
        unreachable_distance=None,
        reduction="mean",
    ):
        super().__init__()
        self.num_zones = num_zones
        self.distance_weight = distance_weight
        self.reduction = reduction

        distance_matrix = torch.as_tensor(
            graph.distances(
                source=range(num_zones),
                target=range(num_zones),
                mode="ALL",
            ),
            dtype=torch.float32,
        )
        finite_distances = distance_matrix[torch.isfinite(distance_matrix)]
        if unreachable_distance is None:
            unreachable_distance = finite_distances.max().item() + 1.0
        distance_matrix = torch.where(
            torch.isfinite(distance_matrix),
            distance_matrix,
            torch.full_like(distance_matrix, float(unreachable_distance)),
        )
        self.register_buffer("distance_matrix", distance_matrix)

    def _ordered_loss(self, from_logits, to_logits, target_from, target_to):
        ce_loss = nn.functional.cross_entropy(
            from_logits,
            target_from,
            reduction="none",
        ) + nn.functional.cross_entropy(
            to_logits,
            target_to,
            reduction="none",
        )

        from_probs = nn.functional.softmax(from_logits, dim=-1)
        to_probs = nn.functional.softmax(to_logits, dim=-1)
        from_distance = (from_probs * self.distance_matrix[target_from]).sum(dim=-1)
        to_distance = (to_probs * self.distance_matrix[target_to]).sum(dim=-1)
        distance_loss = from_distance + to_distance

        return ce_loss + self.distance_weight * distance_loss

    def forward(self, logits, target):
        from_logits = logits[:, 0, :]
        to_logits = logits[:, 1, :]
        target_from = target[:, 0]
        target_to = target[:, 1]

        forward_loss = self._ordered_loss(
            from_logits,
            to_logits,
            target_from,
            target_to,
        )
        swapped_loss = self._ordered_loss(
            from_logits,
            to_logits,
            target_to,
            target_from,
        )
        loss = torch.minimum(forward_loss, swapped_loss)

        if self.reduction == "mean":
            return loss.mean()
        if self.reduction == "sum":
            return loss.sum()
        if self.reduction == "none":
            return loss
        raise ValueError(f"Unsupported reduction: {self.reduction}")

# %%
class SelfAttentivePooling(nn.Module):
    def __init__(self, input_dim, attention_dim=None, dropout=DROPOUT):
        super().__init__()
        attention_dim = attention_dim or input_dim
        self.attention = nn.Sequential(
            nn.Linear(input_dim, attention_dim),
            nn.Tanh(),
            nn.Dropout(dropout),
            nn.Linear(attention_dim, 1),
        )

    def forward(self, x):
        attention_scores = self.attention(x).squeeze(-1)
        attention_weights = torch.softmax(attention_scores, dim=1).unsqueeze(-1)
        return (x * attention_weights).sum(dim=1)


class WhereTransformerSAP(nn.Module):
    def __init__(
        self,
        num_zones,
        num_outage_types,
        num_time_intervals,
        zone_embedding_dim=ZONE_EMBEDDING_DIM,
        outage_type_embedding_dim=OUTAGE_TYPE_EMBEDDING_DIM,
        time_interval_embedding_dim=TIME_INTERVAL_EMBEDDING_DIM,
        transformer_dim=TRANSFORMER_DIM,
        dropout=DROPOUT,
    ):
        super().__init__()
        self.num_zones = num_zones
        self.num_time_intervals = int(num_time_intervals)
        self.zone_embedding = nn.Embedding(num_zones, zone_embedding_dim)
        self.outage_type_embedding = nn.Embedding(
            num_outage_types,
            outage_type_embedding_dim,
        )
        self.time_interval_embedding = nn.Embedding(
            self.num_time_intervals,
            time_interval_embedding_dim,
        )
        self.input_fc = nn.Linear(
            2 * zone_embedding_dim
            + outage_type_embedding_dim
            + time_interval_embedding_dim,
            transformer_dim,
        )
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=transformer_dim,
            nhead=transformer_dim // 64,
            dim_feedforward=transformer_dim * 4,
            dropout=dropout,
            batch_first=True,
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=1,
        )
        self.self_attentive_pooling = SelfAttentivePooling(
            transformer_dim,
            dropout=dropout,
        )
        self.projection = nn.Linear(transformer_dim, 2 * num_zones)

    def forward(
        self,
        from_zone_indices,
        to_zone_indices,
        outage_type,
        time_interval_index,
    ):
        from_zone_emb = self.zone_embedding(from_zone_indices)
        to_zone_emb = self.zone_embedding(to_zone_indices)
        outage_type_emb = self.outage_type_embedding(outage_type)
        time_interval_emb = self.time_interval_embedding(time_interval_index)

        x = torch.cat(
            [from_zone_emb, to_zone_emb, outage_type_emb, time_interval_emb],
            dim=-1,
        )
        x = self.input_fc(x)

        x = self.transformer_encoder(x)

        pooled = self.self_attentive_pooling(x)

        logits = self.projection(pooled)
        return logits.view(-1, 2, self.num_zones)

# %% [markdown]
# # Cross-entropy last-event model for the selected window

# %%
LEARNING_RATE = 3e-6
NUM_EPOCHS = 64
VIRTUAL_BATCH_SIZE = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def sample_to_device(sample, device):
    return {
        "from_zone_indices": sample["from_zone_indices"].unsqueeze(0).to(device),
        "to_zone_indices": sample["to_zone_indices"].unsqueeze(0).to(device),
        "outage_type": sample["outage_type"].unsqueeze(0).to(device),
        "time_interval_index": sample["time_interval_index"].unsqueeze(0).to(device),
        "target": sample["target"].unsqueeze(0).to(device),
    }


def unordered_zone_loss(logits, target):
    from_logits = logits[:, 0, :]
    to_logits = logits[:, 1, :]
    target_from = target[:, 0]
    target_to = target[:, 1]

    forward_loss = nn.functional.cross_entropy(
        from_logits,
        target_from,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_to,
    )
    swapped_loss = nn.functional.cross_entropy(
        from_logits,
        target_to,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_from,
    )
    return torch.minimum(forward_loss, swapped_loss).mean()


def unordered_zone_correct_count(logits, target):
    pred = logits.argmax(dim=-1)
    pred_sorted = torch.sort(pred, dim=1).values
    target_sorted = torch.sort(target, dim=1).values
    return (pred_sorted == target_sorted).all(dim=1).sum().item()


set_seed()
where_transformer = WhereTransformer(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
    num_time_intervals=NUM_TIME_INTERVALS,
)
where_transformer.to(DEVICE)
optimizer = torch.optim.Adam(where_transformer.parameters(), lr=LEARNING_RATE)

training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    where_transformer.train()
    optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = where_transformer(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = unordered_zone_loss(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            optimizer.step()
            optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        optimizer.step()
        optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    where_transformer.eval()
    test_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = where_transformer(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy,
    }
    training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test loss={test_loss:.6f}, test acc={test_accuracy:.4f}"
    )

last_event_ce_checkpoint_path = (
    MODEL_OUTPUT_DIR
    / f"where_transformer_cross_entropy_last_event_{WINDOW_LABEL}_final.pt"
)

torch.save(
    {
        "model_state_dict": where_transformer.state_dict(),
        "window_hours": WINDOW_HOURS,
        "window_label": WINDOW_LABEL,
        "dataset": dataset_path.name,
        "window_selection_manifest": str(WINDOW_SELECTION_PATH),
        "window_selection": window_selection,
        "pooling": "last_event",
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "num_time_intervals": NUM_TIME_INTERVALS,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "time_interval_embedding_dim": TIME_INTERVAL_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "training_history": training_history,
    },
    last_event_ce_checkpoint_path,
)

print(
    "Saved final cross-entropy last-event checkpoint to "
    f"{last_event_ce_checkpoint_path}"
)
# Out:
# /home/aj/venv/lib/python3.14/site-packages/torch/autograd/graph.py:979: UserWarning: Memory Efficient attention defaults to a non-deterministic algorithm. To explicitly enable determinism call torch.use_deterministic_algorithms(True, warn_only=False). (Triggered internally at /__w/pytorch/pytorch/aten/src/ATen/native/transformers/cuda/attention_backward.cu:833.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 001 | train loss=6.669378, train acc=0.0000 | test loss=6.571793, test acc=0.0000
# Epoch 002 | train loss=6.621623, train acc=0.0015 | test loss=6.532011, test acc=0.0000
# Epoch 003 | train loss=6.575398, train acc=0.0000 | test loss=6.494853, test acc=0.0000
# Epoch 004 | train loss=6.528615, train acc=0.0045 | test loss=6.460569, test acc=0.0000
# Epoch 005 | train loss=6.490867, train acc=0.0030 | test loss=6.427471, test acc=0.0055
# Epoch 006 | train loss=6.431189, train acc=0.0059 | test loss=6.398748, test acc=0.0110
# Epoch 007 | train loss=6.399283, train acc=0.0074 | test loss=6.371442, test acc=0.0110
# Epoch 008 | train loss=6.366287, train acc=0.0119 | test loss=6.346343, test acc=0.0166
# Epoch 009 | train loss=6.314425, train acc=0.0134 | test loss=6.322962, test acc=0.0166
# Epoch 010 | train loss=6.300249, train acc=0.0148 | test loss=6.302553, test acc=0.0110
# Epoch 011 | train loss=6.267127, train acc=0.0223 | test loss=6.282632, test acc=0.0110
# Epoch 012 | train loss=6.241892, train acc=0.0163 | test loss=6.265197, test acc=0.0110
# Epoch 013 | train loss=6.203771, train acc=0.0267 | test loss=6.248786, test acc=0.0110
# Epoch 014 | train loss=6.185407, train acc=0.0312 | test loss=6.233482, test acc=0.0166
# Epoch 015 | train loss=6.163103, train acc=0.0326 | test loss=6.219122, test acc=0.0221
# Epoch 016 | train loss=6.141914, train acc=0.0371 | test loss=6.206550, test acc=0.0221
# Epoch 017 | train loss=6.124513, train acc=0.0326 | test loss=6.194083, test acc=0.0166
# Epoch 018 | train loss=6.098844, train acc=0.0415 | test loss=6.183820, test acc=0.0166
# Epoch 019 | train loss=6.092985, train acc=0.0430 | test loss=6.173959, test acc=0.0166
# Epoch 020 | train loss=6.071477, train acc=0.0460 | test loss=6.164298, test acc=0.0166
# Epoch 021 | train loss=6.043442, train acc=0.0475 | test loss=6.155267, test acc=0.0166
# Epoch 022 | train loss=6.042597, train acc=0.0445 | test loss=6.147357, test acc=0.0166
# Epoch 023 | train loss=6.016065, train acc=0.0534 | test loss=6.140949, test acc=0.0166
# Epoch 024 | train loss=6.016696, train acc=0.0564 | test loss=6.133697, test acc=0.0166
# Epoch 025 | train loss=5.985086, train acc=0.0534 | test loss=6.127258, test acc=0.0166
# Epoch 026 | train loss=5.977314, train acc=0.0504 | test loss=6.121399, test acc=0.0166
# Epoch 027 | train loss=5.972109, train acc=0.0415 | test loss=6.116590, test acc=0.0166
# Epoch 028 | train loss=5.961072, train acc=0.0579 | test loss=6.110420, test acc=0.0221
# Epoch 029 | train loss=5.946390, train acc=0.0519 | test loss=6.105409, test acc=0.0221
# Epoch 030 | train loss=5.926716, train acc=0.0608 | test loss=6.100708, test acc=0.0221
# Epoch 031 | train loss=5.922895, train acc=0.0579 | test loss=6.097006, test acc=0.0166
# Epoch 032 | train loss=5.919052, train acc=0.0549 | test loss=6.092753, test acc=0.0166
# Epoch 033 | train loss=5.903945, train acc=0.0564 | test loss=6.088766, test acc=0.0166
# Epoch 034 | train loss=5.890471, train acc=0.0549 | test loss=6.085013, test acc=0.0166
# Epoch 035 | train loss=5.887433, train acc=0.0579 | test loss=6.081572, test acc=0.0221
# Epoch 036 | train loss=5.875415, train acc=0.0579 | test loss=6.078112, test acc=0.0276
# Epoch 037 | train loss=5.853057, train acc=0.0638 | test loss=6.075329, test acc=0.0276
# Epoch 038 | train loss=5.848846, train acc=0.0593 | test loss=6.071880, test acc=0.0221
# Epoch 039 | train loss=5.845542, train acc=0.0579 | test loss=6.069268, test acc=0.0276
# Epoch 040 | train loss=5.845067, train acc=0.0623 | test loss=6.066396, test acc=0.0276
# Epoch 041 | train loss=5.840103, train acc=0.0682 | test loss=6.063779, test acc=0.0276
# Epoch 042 | train loss=5.825223, train acc=0.0712 | test loss=6.061655, test acc=0.0276
# Epoch 043 | train loss=5.818442, train acc=0.0549 | test loss=6.058801, test acc=0.0276
# Epoch 044 | train loss=5.815506, train acc=0.0623 | test loss=6.056619, test acc=0.0276
# Epoch 045 | train loss=5.804645, train acc=0.0623 | test loss=6.054998, test acc=0.0221
# Epoch 046 | train loss=5.810545, train acc=0.0623 | test loss=6.052654, test acc=0.0221
# Epoch 047 | train loss=5.798854, train acc=0.0608 | test loss=6.051424, test acc=0.0221
# Epoch 048 | train loss=5.795593, train acc=0.0549 | test loss=6.049460, test acc=0.0221
# Epoch 049 | train loss=5.779890, train acc=0.0697 | test loss=6.047511, test acc=0.0276
# Epoch 050 | train loss=5.780445, train acc=0.0638 | test loss=6.045206, test acc=0.0276
# Epoch 051 | train loss=5.755309, train acc=0.0668 | test loss=6.042856, test acc=0.0276
# Epoch 052 | train loss=5.776660, train acc=0.0668 | test loss=6.042315, test acc=0.0221
# Epoch 053 | train loss=5.752360, train acc=0.0623 | test loss=6.039954, test acc=0.0221
# Epoch 054 | train loss=5.753554, train acc=0.0593 | test loss=6.038609, test acc=0.0221
# Epoch 055 | train loss=5.744528, train acc=0.0668 | test loss=6.037264, test acc=0.0221
# Epoch 056 | train loss=5.750544, train acc=0.0653 | test loss=6.035517, test acc=0.0276
# Epoch 057 | train loss=5.736423, train acc=0.0623 | test loss=6.034299, test acc=0.0221
# Epoch 058 | train loss=5.725415, train acc=0.0623 | test loss=6.033207, test acc=0.0276
# Epoch 059 | train loss=5.728944, train acc=0.0534 | test loss=6.031390, test acc=0.0276
# Epoch 060 | train loss=5.725018, train acc=0.0638 | test loss=6.030719, test acc=0.0221
# Epoch 061 | train loss=5.723008, train acc=0.0682 | test loss=6.028655, test acc=0.0221
# Epoch 062 | train loss=5.704782, train acc=0.0712 | test loss=6.028222, test acc=0.0221
# Epoch 063 | train loss=5.711926, train acc=0.0549 | test loss=6.027578, test acc=0.0221
# Epoch 064 | train loss=5.696863, train acc=0.0638 | test loss=6.025308, test acc=0.0221
# Saved final cross-entropy last-event checkpoint to model_outputs/where_transformer/winsize4h/where_transformer_cross_entropy_last_event_4h_final.pt

# %%
import matplotlib.pyplot as plt

epochs = [row["epoch"] for row in training_history]
train_losses = [row["train_loss"] for row in training_history]
test_losses = [row["test_loss"] for row in training_history]
train_accuracies = [row["train_accuracy"] for row in training_history]
test_accuracies = [row["test_accuracy"] for row in training_history]

plt.figure(figsize=(8, 4))

plt.plot(epochs, train_losses, label="Train")
plt.plot(epochs, test_losses, label="Test")
plt.xlabel("Epoch")
plt.ylabel("Loss")
# plt.title("Training and test loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_cross_entropy_last_event_{WINDOW_LABEL}_training_loss_bpa.pdf",
    dpi=300,
)
plt.show()

plt.figure(figsize=(8, 4))

plt.plot(epochs, train_accuracies, label="Train")
plt.plot(epochs, test_accuracies, label="Test")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# plt.title("Training and test accuracy")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_cross_entropy_last_event_{WINDOW_LABEL}_training_accuracy_bpa.pdf",
    dpi=300,
)
plt.show()

# %%
from collections import deque
from pathlib import Path

import igraph as ig
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

GRAPH_PATH = Path("res/outage_graph.pkl")
EDGE_ZONE_PATH = Path("output/edge_zones.csv")
RANDOM_PAIR_BASELINE_SIZE = 10_000


def build_zone_distance_lookup(edge_zone_path):
    edge_zone_df = pd.read_csv(edge_zone_path)
    zones = sorted(
        set(edge_zone_df["from_zone"].astype(int))
        | set(edge_zone_df["to_zone"].astype(int))
    )
    adjacency = {zone: {zone} for zone in zones}

    for from_zone, to_zone in zip(
        edge_zone_df["from_zone"].astype(int),
        edge_zone_df["to_zone"].astype(int),
    ):
        adjacency.setdefault(from_zone, {from_zone}).add(to_zone)
        adjacency.setdefault(to_zone, {to_zone}).add(from_zone)

    distances = {}
    for source in adjacency:
        source_distances = {source: 0}
        queue = deque([source])
        while queue:
            current = queue.popleft()
            for neighbor in adjacency[current]:
                if neighbor not in source_distances:
                    source_distances[neighbor] = source_distances[current] + 1
                    queue.append(neighbor)
        distances[source] = source_distances

    return distances


def zone_distance(source_zone, target_zone, distance_lookup):
    return distance_lookup.get(int(source_zone), {}).get(int(target_zone), np.nan)


def unordered_pair_graph_distance(true_pair, pred_pair, distance_lookup):
    direct = (
        zone_distance(true_pair[0], pred_pair[0], distance_lookup)
        + zone_distance(true_pair[1], pred_pair[1], distance_lookup)
    ) / 2
    swapped = (
        zone_distance(true_pair[0], pred_pair[1], distance_lookup)
        + zone_distance(true_pair[1], pred_pair[0], distance_lookup)
    ) / 2
    candidates = [distance for distance in [direct, swapped] if np.isfinite(distance)]
    return min(candidates) if candidates else np.nan


def summarize_pair_distances(distances):
    distances = np.asarray(distances, dtype=float)
    finite = distances[np.isfinite(distances)]
    return {
        "mean_distance": finite.mean(),
        "median_distance": np.median(finite),
        "p90_distance": np.percentile(finite, 90),
        "same_zone_pair_rate": (finite == 0).mean(),
        "adjacent_or_same_pair_rate": (finite <= 1).mean(),
        "unreachable_count": int(np.isnan(distances).sum()),
    }


def collect_where_predictions(model, dataset, device):
    model.eval()
    rows = []
    with torch.no_grad():
        for sample in dataset:
            batch = sample_to_device(sample, device)
            logits = model(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            pred_pair = logits.argmax(dim=-1).squeeze(0).cpu().tolist()
            true_pair = sample["target"].cpu().tolist()
            rows.append(
                {
                    "true_from_zone": int(true_pair[0]),
                    "true_to_zone": int(true_pair[1]),
                    "pred_from_zone": int(pred_pair[0]),
                    "pred_to_zone": int(pred_pair[1]),
                    "exact_pair_match": sorted(true_pair) == sorted(pred_pair),
                }
            )
    return pd.DataFrame(rows)


outage_graph = ig.Graph.Read_Pickle(str(GRAPH_PATH))
zone_distance_lookup = build_zone_distance_lookup(EDGE_ZONE_PATH)
zone_ids = sorted(zone_distance_lookup)
rng = np.random.default_rng(RANDOM_STATE)

raw_graph_diameter = outage_graph.diameter(directed=False, unconn=True)
node_a, node_b = rng.choice(outage_graph.vcount(), size=2, replace=False)
random_node_distance = outage_graph.distances(
    source=[int(node_a)],
    target=[int(node_b)],
    mode="ALL",
)[0][0]

zone_graph_diameter = max(
    distance
    for source_distances in zone_distance_lookup.values()
    for distance in source_distances.values()
)
zone_a, zone_b = rng.choice(zone_ids, size=2, replace=False)
random_zone_distance = zone_distance_lookup[int(zone_a)][int(zone_b)]

checkpoint_path = Path(last_event_ce_checkpoint_path)
if not checkpoint_path.exists():
    raise FileNotFoundError(
        f"Missing selected-window checkpoint: {checkpoint_path}. "
        "Run the cross-entropy last-event training cell first."
    )
try:
    checkpoint = torch.load(checkpoint_path, map_location=DEVICE, weights_only=False)
except TypeError:
    checkpoint = torch.load(checkpoint_path, map_location=DEVICE)

if not np.isclose(float(checkpoint.get("window_hours", np.nan)), WINDOW_HOURS):
    raise ValueError(
        f"Checkpoint window does not match selected {WINDOW_LABEL}: {checkpoint_path}"
    )
if checkpoint.get("dataset") != dataset_path.name:
    raise ValueError(
        f"Checkpoint dataset does not match {dataset_path.name}: {checkpoint_path}"
    )
if checkpoint.get("num_time_intervals") != NUM_TIME_INTERVALS:
    raise ValueError(
        "Checkpoint time-interval vocabulary does not match the selected dataset."
    )
if checkpoint.get("pooling") != "last_event":
    raise ValueError(f"Checkpoint pooling metadata is invalid: {checkpoint_path}")

where_transformer.load_state_dict(checkpoint["model_state_dict"])
print(f"Loaded {WINDOW_LABEL} model checkpoint from {checkpoint_path}")

prediction_df = collect_where_predictions(where_transformer, test_where_dataset, DEVICE)
pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in prediction_df.itertuples(index=False)
    ],
    dtype=float,
)

random_pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            tuple(
                prediction_df.iloc[i % len(prediction_df)][
                    ["true_from_zone", "true_to_zone"]
                ].to_numpy()
            ),
            rng.choice(zone_ids, size=2, replace=True),
            zone_distance_lookup,
        )
        for i in range(RANDOM_PAIR_BASELINE_SIZE)
    ],
    dtype=float,
)

model_summary = summarize_pair_distances(pair_distances)
random_summary = summarize_pair_distances(random_pair_distances)
model_summary["exact_pair_accuracy"] = prediction_df["exact_pair_match"].mean()
model_summary["mean_distance_vs_diameter"] = (
    model_summary["mean_distance"] / zone_graph_diameter
)
model_summary["mean_distance_reduction_vs_random"] = 1 - (
    model_summary["mean_distance"] / random_summary["mean_distance"]
)

summary_df = pd.DataFrame(
    [
        {"model": "Transformer", **model_summary},
        {"model": "Random zone-pair baseline", **random_summary},
    ]
)

print(f"Raw outage graph: {outage_graph.vcount()} nodes, {outage_graph.ecount()} edges")
print(f"Maximum raw graph node distance: {raw_graph_diameter}")
print(
    f"Random raw nodes {int(node_a)} -> {int(node_b)} distance: "
    f"{random_node_distance}"
)
print(f"Maximum zone graph distance: {zone_graph_diameter}")
print(f"Random zones {int(zone_a)} -> {int(zone_b)} distance: {random_zone_distance}")
print(
    "Average unordered zone-pair distance, model: "
    f"{model_summary['mean_distance']:.3f}"
)
print(
    "Average unordered zone-pair distance, random baseline: "
    f"{random_summary['mean_distance']:.3f}"
)
print(
    "Model mean unordered pair distance: "
    f"{model_summary['mean_distance']:.3f} / {zone_graph_diameter} "
    f"({model_summary['mean_distance_vs_diameter']:.1%} of zone diameter)"
)
print(
    "Distance reduction versus random zone-pair baseline: "
    f"{model_summary['mean_distance_reduction_vs_random']:.1%}"
)

display(summary_df.round(3))
display(prediction_df.head())

bins = np.arange(-0.5, zone_graph_diameter + 1.5, 1)
fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(
    pair_distances[np.isfinite(pair_distances)], bins=bins, alpha=0.7, label="Model"
)
ax.hist(
    random_pair_distances[np.isfinite(random_pair_distances)],
    bins=bins,
    histtype="step",
    linewidth=2,
    label="Random baseline",
)
ax.set_xlabel("Unordered zone-pair graph distance")
ax.set_ylabel("Count")
# ax.set_title("Where-model graph-distance error")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_cross_entropy_last_event_{WINDOW_LABEL}_graph_distance_error_bpa.pdf",
    dpi=300,
)
plt.show()
# Out:
# Loaded 4h model checkpoint from model_outputs/where_transformer/winsize4h/where_transformer_cross_entropy_last_event_4h_final.pt
# Raw outage graph: 1082 nodes, 1462 edges
# Maximum raw graph node distance: 18
# Random raw nodes 96 -> 837 distance: 4
# Maximum zone graph distance: 4
# Random zones 10 -> 24 distance: 3
# Average unordered zone-pair distance, model: 1.436
# Average unordered zone-pair distance, random baseline: 1.795
# Model mean unordered pair distance: 1.436 / 4 (35.9% of zone diameter)
# Distance reduction versus random zone-pair baseline: 20.0%
#                        model  mean_distance  median_distance  p90_distance  \
# 0                Transformer          1.436              1.5           2.0
# 1  Random zone-pair baseline          1.795              2.0           2.5
#
#    same_zone_pair_rate  adjacent_or_same_pair_rate  unreachable_count  \
# 0                0.022                       0.453                  0
# 1                0.002                       0.161                  0
#
#    exact_pair_accuracy  mean_distance_vs_diameter  \
# 0                0.022                      0.359
# 1                  NaN                        NaN
#
#    mean_distance_reduction_vs_random
# 0                                0.2
# 1                                NaN
#    true_from_zone  true_to_zone  pred_from_zone  pred_to_zone  \
# 0               0             0               0             2
# 1               2             2               5            12
# 2               3             3               0             5
# 3              22            22               5            12
# 4              20            20               0             5
#
#    exact_pair_match
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# # Cross-entropy self-attentive-pooling model for the selected window

# %%
LEARNING_RATE = 3e-6
NUM_EPOCHS = 64
VIRTUAL_BATCH_SIZE = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def sample_to_device(sample, device):
    return {
        "from_zone_indices": sample["from_zone_indices"].unsqueeze(0).to(device),
        "to_zone_indices": sample["to_zone_indices"].unsqueeze(0).to(device),
        "outage_type": sample["outage_type"].unsqueeze(0).to(device),
        "time_interval_index": sample["time_interval_index"].unsqueeze(0).to(device),
        "target": sample["target"].unsqueeze(0).to(device),
    }


def unordered_zone_loss(logits, target):
    from_logits = logits[:, 0, :]
    to_logits = logits[:, 1, :]
    target_from = target[:, 0]
    target_to = target[:, 1]

    forward_loss = nn.functional.cross_entropy(
        from_logits,
        target_from,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_to,
    )
    swapped_loss = nn.functional.cross_entropy(
        from_logits,
        target_to,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_from,
    )
    return torch.minimum(forward_loss, swapped_loss).mean()


def unordered_zone_correct_count(logits, target):
    pred = logits.argmax(dim=-1)
    pred_sorted = torch.sort(pred, dim=1).values
    target_sorted = torch.sort(target, dim=1).values
    return (pred_sorted == target_sorted).all(dim=1).sum().item()


set_seed()
where_transformer_sap = WhereTransformerSAP(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
    num_time_intervals=NUM_TIME_INTERVALS,
)
where_transformer_sap
where_transformer_sap.to(DEVICE)
optimizer = torch.optim.Adam(where_transformer_sap.parameters(), lr=LEARNING_RATE)

training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    where_transformer_sap.train()
    optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = where_transformer_sap(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = unordered_zone_loss(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            optimizer.step()
            optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        optimizer.step()
        optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    where_transformer_sap.eval()
    test_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = where_transformer_sap(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy,
    }
    training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test loss={test_loss:.6f}, test acc={test_accuracy:.4f}"
    )

sap_ce_checkpoint_path = (
    MODEL_OUTPUT_DIR / f"where_transformer_cross_entropy_sap_{WINDOW_LABEL}_final.pt"
)

torch.save(
    {
        "model_state_dict": where_transformer_sap.state_dict(),
        "window_hours": WINDOW_HOURS,
        "window_label": WINDOW_LABEL,
        "dataset": dataset_path.name,
        "window_selection_manifest": str(WINDOW_SELECTION_PATH),
        "window_selection": window_selection,
        "pooling": "self_attentive",
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "num_time_intervals": NUM_TIME_INTERVALS,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "time_interval_embedding_dim": TIME_INTERVAL_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "training_history": training_history,
    },
    sap_ce_checkpoint_path,
)

print(
    "Saved final cross-entropy self-attentive-pooling checkpoint to "
    f"{sap_ce_checkpoint_path}"
)
# Out:
# Epoch 001 | train loss=6.784105, train acc=0.0000 | test loss=6.705595, test acc=0.0000
# Epoch 002 | train loss=6.728585, train acc=0.0000 | test loss=6.672166, test acc=0.0000
# Epoch 003 | train loss=6.681058, train acc=0.0000 | test loss=6.639813, test acc=0.0000
# Epoch 004 | train loss=6.641769, train acc=0.0015 | test loss=6.609175, test acc=0.0000
# Epoch 005 | train loss=6.598295, train acc=0.0000 | test loss=6.580730, test acc=0.0000
# Epoch 006 | train loss=6.554579, train acc=0.0000 | test loss=6.552673, test acc=0.0000
# Epoch 007 | train loss=6.514456, train acc=0.0000 | test loss=6.526371, test acc=0.0000
# Epoch 008 | train loss=6.481042, train acc=0.0000 | test loss=6.501613, test acc=0.0000
# Epoch 009 | train loss=6.437492, train acc=0.0000 | test loss=6.478370, test acc=0.0000
# Epoch 010 | train loss=6.397589, train acc=0.0000 | test loss=6.455616, test acc=0.0000
# Epoch 011 | train loss=6.362762, train acc=0.0015 | test loss=6.434913, test acc=0.0000
# Epoch 012 | train loss=6.324606, train acc=0.0074 | test loss=6.414558, test acc=0.0000
# Epoch 013 | train loss=6.302249, train acc=0.0030 | test loss=6.395457, test acc=0.0000
# Epoch 014 | train loss=6.272076, train acc=0.0045 | test loss=6.378091, test acc=0.0000
# Epoch 015 | train loss=6.250277, train acc=0.0074 | test loss=6.361964, test acc=0.0000
# Epoch 016 | train loss=6.217891, train acc=0.0104 | test loss=6.346760, test acc=0.0000
# Epoch 017 | train loss=6.189843, train acc=0.0089 | test loss=6.332183, test acc=0.0000
# Epoch 018 | train loss=6.177636, train acc=0.0104 | test loss=6.318789, test acc=0.0055
# Epoch 019 | train loss=6.148998, train acc=0.0163 | test loss=6.305481, test acc=0.0110
# Epoch 020 | train loss=6.127992, train acc=0.0178 | test loss=6.294506, test acc=0.0110
# Epoch 021 | train loss=6.101211, train acc=0.0208 | test loss=6.283236, test acc=0.0110
# Epoch 022 | train loss=6.090923, train acc=0.0223 | test loss=6.272866, test acc=0.0110
# Epoch 023 | train loss=6.052706, train acc=0.0356 | test loss=6.263592, test acc=0.0110
# Epoch 024 | train loss=6.038257, train acc=0.0326 | test loss=6.254591, test acc=0.0110
# Epoch 025 | train loss=6.027383, train acc=0.0415 | test loss=6.246650, test acc=0.0110
# Epoch 026 | train loss=6.011151, train acc=0.0430 | test loss=6.238659, test acc=0.0110
# Epoch 027 | train loss=5.991577, train acc=0.0519 | test loss=6.231720, test acc=0.0110
# Epoch 028 | train loss=5.975550, train acc=0.0490 | test loss=6.224252, test acc=0.0166
# Epoch 029 | train loss=5.969697, train acc=0.0519 | test loss=6.217939, test acc=0.0166
# Epoch 030 | train loss=5.960534, train acc=0.0579 | test loss=6.211627, test acc=0.0166
# Epoch 031 | train loss=5.943357, train acc=0.0608 | test loss=6.204969, test acc=0.0166
# Epoch 032 | train loss=5.924117, train acc=0.0579 | test loss=6.199552, test acc=0.0166
# Epoch 033 | train loss=5.913414, train acc=0.0653 | test loss=6.194366, test acc=0.0166
# Epoch 034 | train loss=5.907585, train acc=0.0682 | test loss=6.190045, test acc=0.0166
# Epoch 035 | train loss=5.888637, train acc=0.0564 | test loss=6.185195, test acc=0.0166
# Epoch 036 | train loss=5.882287, train acc=0.0757 | test loss=6.180493, test acc=0.0166
# Epoch 037 | train loss=5.873674, train acc=0.0608 | test loss=6.175996, test acc=0.0166
# Epoch 038 | train loss=5.865755, train acc=0.0653 | test loss=6.172728, test acc=0.0221
# Epoch 039 | train loss=5.851265, train acc=0.0668 | test loss=6.167691, test acc=0.0221
# Epoch 040 | train loss=5.846120, train acc=0.0786 | test loss=6.163958, test acc=0.0221
# Epoch 041 | train loss=5.835416, train acc=0.0786 | test loss=6.161323, test acc=0.0276
# Epoch 042 | train loss=5.819757, train acc=0.0742 | test loss=6.157446, test acc=0.0276
# Epoch 043 | train loss=5.811096, train acc=0.0772 | test loss=6.154722, test acc=0.0276
# Epoch 044 | train loss=5.805315, train acc=0.0742 | test loss=6.151612, test acc=0.0276
# Epoch 045 | train loss=5.803854, train acc=0.0757 | test loss=6.148405, test acc=0.0276
# Epoch 046 | train loss=5.792851, train acc=0.0757 | test loss=6.144262, test acc=0.0276
# Epoch 047 | train loss=5.778172, train acc=0.0831 | test loss=6.142513, test acc=0.0276
# Epoch 048 | train loss=5.780853, train acc=0.0727 | test loss=6.138966, test acc=0.0276
# Epoch 049 | train loss=5.771578, train acc=0.0831 | test loss=6.136518, test acc=0.0276
# Epoch 050 | train loss=5.770224, train acc=0.0846 | test loss=6.133329, test acc=0.0276
# Epoch 051 | train loss=5.760937, train acc=0.0861 | test loss=6.131218, test acc=0.0276
# Epoch 052 | train loss=5.752824, train acc=0.0861 | test loss=6.128267, test acc=0.0276
# Epoch 053 | train loss=5.752519, train acc=0.0801 | test loss=6.126183, test acc=0.0276
# Epoch 054 | train loss=5.735589, train acc=0.0890 | test loss=6.123857, test acc=0.0276
# Epoch 055 | train loss=5.731760, train acc=0.0875 | test loss=6.122049, test acc=0.0276
# Epoch 056 | train loss=5.720885, train acc=0.0861 | test loss=6.118952, test acc=0.0221
# Epoch 057 | train loss=5.713142, train acc=0.0905 | test loss=6.117209, test acc=0.0276
# Epoch 058 | train loss=5.726312, train acc=0.0816 | test loss=6.115407, test acc=0.0221
# Epoch 059 | train loss=5.706573, train acc=0.0831 | test loss=6.113767, test acc=0.0276
# Epoch 060 | train loss=5.707749, train acc=0.0905 | test loss=6.111960, test acc=0.0276
# Epoch 061 | train loss=5.701693, train acc=0.0861 | test loss=6.110431, test acc=0.0331
# Epoch 062 | train loss=5.698084, train acc=0.0890 | test loss=6.108282, test acc=0.0276
# Epoch 063 | train loss=5.682722, train acc=0.0920 | test loss=6.106495, test acc=0.0276
# Epoch 064 | train loss=5.682973, train acc=0.0831 | test loss=6.104807, test acc=0.0276
# Saved final cross-entropy self-attentive-pooling checkpoint to model_outputs/where_transformer/winsize4h/where_transformer_cross_entropy_sap_4h_final.pt

# %% [markdown]
# # Adjacency-aware last-event model for the selected window

# %%
ADJACENCY_DISTANCE_WEIGHT = 2.0

edge_zone_df = pd.read_csv(EDGE_ZONE_PATH)
zone_edges = [
    (int(from_zone), int(to_zone))
    for from_zone, to_zone in zip(edge_zone_df["from_zone"], edge_zone_df["to_zone"])
    if 0 <= int(from_zone) < num_zones and 0 <= int(to_zone) < num_zones
]
zone_graph = ig.Graph(n=num_zones, edges=zone_edges, directed=False)
zone_graph.simplify(multiple=True, loops=True)

set_seed()
adjacency_where_transformer = WhereTransformer(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
    num_time_intervals=NUM_TIME_INTERVALS,
)
adjacency_where_transformer.to(DEVICE)

adjacency_criterion = GraphDistanceUnorderedZoneLoss(
    zone_graph,
    num_zones=num_zones,
    distance_weight=ADJACENCY_DISTANCE_WEIGHT,
).to(DEVICE)
adjacency_optimizer = torch.optim.Adam(
    adjacency_where_transformer.parameters(),
    lr=LEARNING_RATE,
)

adjacency_training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    adjacency_where_transformer.train()
    adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = adjacency_where_transformer(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = adjacency_criterion(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            adjacency_optimizer.step()
            adjacency_optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        adjacency_optimizer.step()
        adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    adjacency_where_transformer.eval()
    test_loss_sum = 0.0
    test_cross_entropy_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = adjacency_where_transformer(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = adjacency_criterion(logits, batch["target"])
            cross_entropy_loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_cross_entropy_loss_sum += cross_entropy_loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_cross_entropy_loss = test_cross_entropy_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_cross_entropy_loss": test_cross_entropy_loss,
        "test_accuracy": test_accuracy,
    }
    adjacency_training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test adjacency loss={test_loss:.6f}, "
        f"test CE loss={test_cross_entropy_loss:.6f}, "
        f"test acc={test_accuracy:.4f}"
    )

last_event_adjacency_checkpoint_path = (
    MODEL_OUTPUT_DIR
    / f"where_transformer_adjacency_aware_last_event_{WINDOW_LABEL}_final.pt"
)

torch.save(
    {
        "model_state_dict": adjacency_where_transformer.state_dict(),
        "window_hours": WINDOW_HOURS,
        "window_label": WINDOW_LABEL,
        "dataset": dataset_path.name,
        "window_selection_manifest": str(WINDOW_SELECTION_PATH),
        "window_selection": window_selection,
        "pooling": "last_event",
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "num_time_intervals": NUM_TIME_INTERVALS,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "time_interval_embedding_dim": TIME_INTERVAL_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "distance_weight": ADJACENCY_DISTANCE_WEIGHT,
        "training_history": adjacency_training_history,
    },
    last_event_adjacency_checkpoint_path,
)

print(
    "Saved final adjacency-aware last-event checkpoint to "
    f"{last_event_adjacency_checkpoint_path}"
)
# Out:
# Epoch 001 | train loss=14.072080, train acc=0.0000 | test adjacency loss=13.849403, test CE loss=6.570377, test acc=0.0000
# Epoch 002 | train loss=13.996220, train acc=0.0015 | test adjacency loss=13.781804, test CE loss=6.529342, test acc=0.0000
# Epoch 003 | train loss=13.917570, train acc=0.0015 | test adjacency loss=13.716001, test CE loss=6.490826, test acc=0.0000
# Epoch 004 | train loss=13.845992, train acc=0.0059 | test adjacency loss=13.653305, test CE loss=6.454824, test acc=0.0000
# Epoch 005 | train loss=13.774515, train acc=0.0059 | test adjacency loss=13.591373, test CE loss=6.419923, test acc=0.0055
# Epoch 006 | train loss=13.684549, train acc=0.0119 | test adjacency loss=13.534684, test CE loss=6.389822, test acc=0.0000
# Epoch 007 | train loss=13.621471, train acc=0.0059 | test adjacency loss=13.478215, test CE loss=6.361316, test acc=0.0000
# Epoch 008 | train loss=13.556659, train acc=0.0134 | test adjacency loss=13.425166, test CE loss=6.335054, test acc=0.0000
# Epoch 009 | train loss=13.466452, train acc=0.0223 | test adjacency loss=13.373074, test CE loss=6.311191, test acc=0.0055
# Epoch 010 | train loss=13.427156, train acc=0.0252 | test adjacency loss=13.325041, test CE loss=6.290909, test acc=0.0110
# Epoch 011 | train loss=13.360724, train acc=0.0267 | test adjacency loss=13.277520, test CE loss=6.271472, test acc=0.0110
# Epoch 012 | train loss=13.306903, train acc=0.0356 | test adjacency loss=13.233500, test CE loss=6.255303, test acc=0.0110
# Epoch 013 | train loss=13.237286, train acc=0.0401 | test adjacency loss=13.190489, test CE loss=6.241603, test acc=0.0221
# Epoch 014 | train loss=13.186510, train acc=0.0490 | test adjacency loss=13.150109, test CE loss=6.229659, test acc=0.0276
# Epoch 015 | train loss=13.132506, train acc=0.0564 | test adjacency loss=13.111227, test CE loss=6.219639, test acc=0.0331
# Epoch 016 | train loss=13.083001, train acc=0.0549 | test adjacency loss=13.074778, test CE loss=6.213117, test acc=0.0331
# Epoch 017 | train loss=13.038741, train acc=0.0593 | test adjacency loss=13.039455, test CE loss=6.207226, test acc=0.0387
# Epoch 018 | train loss=12.984843, train acc=0.0623 | test adjacency loss=13.008284, test CE loss=6.204972, test acc=0.0387
# Epoch 019 | train loss=12.952908, train acc=0.0757 | test adjacency loss=12.978433, test CE loss=6.203764, test acc=0.0387
# Epoch 020 | train loss=12.900878, train acc=0.0727 | test adjacency loss=12.948683, test CE loss=6.204755, test acc=0.0387
# Epoch 021 | train loss=12.848251, train acc=0.0861 | test adjacency loss=12.922325, test CE loss=6.206258, test acc=0.0497
# Epoch 022 | train loss=12.827577, train acc=0.0890 | test adjacency loss=12.897456, test CE loss=6.210957, test acc=0.0497
# Epoch 023 | train loss=12.775155, train acc=0.0905 | test adjacency loss=12.875664, test CE loss=6.218020, test acc=0.0497
# Epoch 024 | train loss=12.758516, train acc=0.0875 | test adjacency loss=12.854648, test CE loss=6.224361, test acc=0.0497
# Epoch 025 | train loss=12.701889, train acc=0.0905 | test adjacency loss=12.835558, test CE loss=6.231661, test acc=0.0497
# Epoch 026 | train loss=12.672753, train acc=0.0905 | test adjacency loss=12.817956, test CE loss=6.241684, test acc=0.0497
# Epoch 027 | train loss=12.654709, train acc=0.0905 | test adjacency loss=12.803486, test CE loss=6.251341, test acc=0.0552
# Epoch 028 | train loss=12.627797, train acc=0.0920 | test adjacency loss=12.787729, test CE loss=6.259706, test acc=0.0552
# Epoch 029 | train loss=12.599446, train acc=0.0964 | test adjacency loss=12.774578, test CE loss=6.270375, test acc=0.0552
# Epoch 030 | train loss=12.563017, train acc=0.0920 | test adjacency loss=12.762289, test CE loss=6.281662, test acc=0.0552
# Epoch 031 | train loss=12.548852, train acc=0.0994 | test adjacency loss=12.752453, test CE loss=6.293209, test acc=0.0552
# Epoch 032 | train loss=12.531291, train acc=0.0964 | test adjacency loss=12.742889, test CE loss=6.302114, test acc=0.0552
# Epoch 033 | train loss=12.504074, train acc=0.0935 | test adjacency loss=12.733843, test CE loss=6.313208, test acc=0.0552
# Epoch 034 | train loss=12.481332, train acc=0.0964 | test adjacency loss=12.725567, test CE loss=6.323347, test acc=0.0552
# Epoch 035 | train loss=12.471298, train acc=0.0964 | test adjacency loss=12.718162, test CE loss=6.333050, test acc=0.0552
# Epoch 036 | train loss=12.451173, train acc=0.1009 | test adjacency loss=12.710822, test CE loss=6.341181, test acc=0.0552
# Epoch 037 | train loss=12.416793, train acc=0.0964 | test adjacency loss=12.705214, test CE loss=6.349059, test acc=0.0552
# Epoch 038 | train loss=12.411493, train acc=0.0994 | test adjacency loss=12.699148, test CE loss=6.355970, test acc=0.0552
# Epoch 039 | train loss=12.399481, train acc=0.0994 | test adjacency loss=12.694676, test CE loss=6.364014, test acc=0.0552
# Epoch 040 | train loss=12.383415, train acc=0.1024 | test adjacency loss=12.688863, test CE loss=6.371414, test acc=0.0552
# Epoch 041 | train loss=12.388009, train acc=0.1024 | test adjacency loss=12.684346, test CE loss=6.376876, test acc=0.0552
# Epoch 042 | train loss=12.360875, train acc=0.0994 | test adjacency loss=12.680069, test CE loss=6.382813, test acc=0.0552
# Epoch 043 | train loss=12.350442, train acc=0.0994 | test adjacency loss=12.675143, test CE loss=6.387488, test acc=0.0552
# Epoch 044 | train loss=12.346391, train acc=0.0994 | test adjacency loss=12.671118, test CE loss=6.391430, test acc=0.0608
# Epoch 045 | train loss=12.330527, train acc=0.1009 | test adjacency loss=12.668432, test CE loss=6.399473, test acc=0.0608
# Epoch 046 | train loss=12.333353, train acc=0.1009 | test adjacency loss=12.664037, test CE loss=6.401657, test acc=0.0608
# Epoch 047 | train loss=12.313793, train acc=0.1024 | test adjacency loss=12.662310, test CE loss=6.408407, test acc=0.0608
# Epoch 048 | train loss=12.303748, train acc=0.1053 | test adjacency loss=12.658561, test CE loss=6.410355, test acc=0.0608
# Epoch 049 | train loss=12.287301, train acc=0.1009 | test adjacency loss=12.654999, test CE loss=6.411998, test acc=0.0608
# Epoch 050 | train loss=12.285533, train acc=0.1024 | test adjacency loss=12.651457, test CE loss=6.414167, test acc=0.0608
# Epoch 051 | train loss=12.257972, train acc=0.1039 | test adjacency loss=12.647642, test CE loss=6.416157, test acc=0.0608
# Epoch 052 | train loss=12.272098, train acc=0.1024 | test adjacency loss=12.646510, test CE loss=6.421768, test acc=0.0608
# Epoch 053 | train loss=12.241628, train acc=0.1039 | test adjacency loss=12.642955, test CE loss=6.421765, test acc=0.0608
# Epoch 054 | train loss=12.247915, train acc=0.1053 | test adjacency loss=12.640538, test CE loss=6.423531, test acc=0.0608
# Epoch 055 | train loss=12.240312, train acc=0.1024 | test adjacency loss=12.638153, test CE loss=6.424002, test acc=0.0608
# Epoch 056 | train loss=12.238599, train acc=0.1039 | test adjacency loss=12.635332, test CE loss=6.425519, test acc=0.0608
# Epoch 057 | train loss=12.222415, train acc=0.1053 | test adjacency loss=12.633208, test CE loss=6.426126, test acc=0.0608
# Epoch 058 | train loss=12.203557, train acc=0.1024 | test adjacency loss=12.630952, test CE loss=6.425600, test acc=0.0608
# Epoch 059 | train loss=12.214233, train acc=0.1053 | test adjacency loss=12.627929, test CE loss=6.426116, test acc=0.0608
# Epoch 060 | train loss=12.208668, train acc=0.1024 | test adjacency loss=12.626549, test CE loss=6.427317, test acc=0.0608
# Epoch 061 | train loss=12.209133, train acc=0.1009 | test adjacency loss=12.623013, test CE loss=6.424819, test acc=0.0608
# Epoch 062 | train loss=12.176248, train acc=0.1039 | test adjacency loss=12.622519, test CE loss=6.428311, test acc=0.0608
# Epoch 063 | train loss=12.185458, train acc=0.1053 | test adjacency loss=12.621337, test CE loss=6.431653, test acc=0.0608
# Epoch 064 | train loss=12.166072, train acc=0.1039 | test adjacency loss=12.617449, test CE loss=6.427171, test acc=0.0608
# Saved final adjacency-aware last-event checkpoint to model_outputs/where_transformer/winsize4h/where_transformer_adjacency_aware_last_event_4h_final.pt

# %% [markdown]
# # Adjacency-aware self-attentive-pooling model for the selected window

# %%
ADJACENCY_DISTANCE_WEIGHT = 2.0

edge_zone_df = pd.read_csv(EDGE_ZONE_PATH)
zone_edges = [
    (int(from_zone), int(to_zone))
    for from_zone, to_zone in zip(edge_zone_df["from_zone"], edge_zone_df["to_zone"])
    if 0 <= int(from_zone) < num_zones and 0 <= int(to_zone) < num_zones
]
zone_graph = ig.Graph(n=num_zones, edges=zone_edges, directed=False)
zone_graph.simplify(multiple=True, loops=True)

set_seed()
adjacency_where_transformer_sap = WhereTransformerSAP(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
    num_time_intervals=NUM_TIME_INTERVALS,
)
adjacency_where_transformer_sap.to(DEVICE)

adjacency_criterion = GraphDistanceUnorderedZoneLoss(
    zone_graph,
    num_zones=num_zones,
    distance_weight=ADJACENCY_DISTANCE_WEIGHT,
).to(DEVICE)
adjacency_optimizer = torch.optim.Adam(
    adjacency_where_transformer_sap.parameters(),
    lr=LEARNING_RATE,
)

adjacency_training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    adjacency_where_transformer_sap.train()
    adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = adjacency_where_transformer_sap(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = adjacency_criterion(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            adjacency_optimizer.step()
            adjacency_optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        adjacency_optimizer.step()
        adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    adjacency_where_transformer_sap.eval()
    test_loss_sum = 0.0
    test_cross_entropy_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = adjacency_where_transformer_sap(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = adjacency_criterion(logits, batch["target"])
            cross_entropy_loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_cross_entropy_loss_sum += cross_entropy_loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_cross_entropy_loss = test_cross_entropy_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_cross_entropy_loss": test_cross_entropy_loss,
        "test_accuracy": test_accuracy,
    }
    adjacency_training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test adjacency loss={test_loss:.6f}, "
        f"test CE loss={test_cross_entropy_loss:.6f}, "
        f"test acc={test_accuracy:.4f}"
    )

sap_adjacency_checkpoint_path = (
    MODEL_OUTPUT_DIR / f"where_transformer_adjacency_aware_sap_{WINDOW_LABEL}_final.pt"
)

torch.save(
    {
        "model_state_dict": adjacency_where_transformer_sap.state_dict(),
        "window_hours": WINDOW_HOURS,
        "window_label": WINDOW_LABEL,
        "dataset": dataset_path.name,
        "window_selection_manifest": str(WINDOW_SELECTION_PATH),
        "window_selection": window_selection,
        "pooling": "self_attentive",
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "num_time_intervals": NUM_TIME_INTERVALS,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "time_interval_embedding_dim": TIME_INTERVAL_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "distance_weight": ADJACENCY_DISTANCE_WEIGHT,
        "training_history": adjacency_training_history,
    },
    sap_adjacency_checkpoint_path,
)

print(
    "Saved final adjacency-aware self-attentive-pooling checkpoint to "
    f"{sap_adjacency_checkpoint_path}"
)
# Out:
# Epoch 001 | train loss=14.281708, train acc=0.0000 | test adjacency loss=14.115079, test CE loss=6.702515, test acc=0.0000
# Epoch 002 | train loss=14.191564, train acc=0.0000 | test adjacency loss=14.051977, test CE loss=6.666358, test acc=0.0000
# Epoch 003 | train loss=14.114171, train acc=0.0000 | test adjacency loss=13.990618, test CE loss=6.631681, test acc=0.0000
# Epoch 004 | train loss=14.046204, train acc=0.0015 | test adjacency loss=13.932017, test CE loss=6.598633, test acc=0.0000
# Epoch 005 | train loss=13.978145, train acc=0.0000 | test adjacency loss=13.876077, test CE loss=6.567443, test acc=0.0000
# Epoch 006 | train loss=13.906113, train acc=0.0000 | test adjacency loss=13.821109, test CE loss=6.536977, test acc=0.0055
# Epoch 007 | train loss=13.839817, train acc=0.0015 | test adjacency loss=13.768069, test CE loss=6.508525, test acc=0.0055
# Epoch 008 | train loss=13.776415, train acc=0.0000 | test adjacency loss=13.717590, test CE loss=6.481696, test acc=0.0000
# Epoch 009 | train loss=13.706530, train acc=0.0015 | test adjacency loss=13.669037, test CE loss=6.456213, test acc=0.0000
# Epoch 010 | train loss=13.638954, train acc=0.0000 | test adjacency loss=13.620548, test CE loss=6.431568, test acc=0.0000
# Epoch 011 | train loss=13.575721, train acc=0.0015 | test adjacency loss=13.575248, test CE loss=6.409466, test acc=0.0000
# Epoch 012 | train loss=13.514146, train acc=0.0074 | test adjacency loss=13.529810, test CE loss=6.387981, test acc=0.0000
# Epoch 013 | train loss=13.461008, train acc=0.0030 | test adjacency loss=13.486507, test CE loss=6.368078, test acc=0.0110
# Epoch 014 | train loss=13.402632, train acc=0.0059 | test adjacency loss=13.445261, test CE loss=6.350225, test acc=0.0110
# Epoch 015 | train loss=13.357956, train acc=0.0119 | test adjacency loss=13.405899, test CE loss=6.334587, test acc=0.0110
# Epoch 016 | train loss=13.298924, train acc=0.0119 | test adjacency loss=13.367886, test CE loss=6.320198, test acc=0.0110
# Epoch 017 | train loss=13.243336, train acc=0.0163 | test adjacency loss=13.330542, test CE loss=6.306941, test acc=0.0110
# Epoch 018 | train loss=13.206136, train acc=0.0178 | test adjacency loss=13.294825, test CE loss=6.296047, test acc=0.0166
# Epoch 019 | train loss=13.150865, train acc=0.0282 | test adjacency loss=13.260037, test CE loss=6.285765, test acc=0.0221
# Epoch 020 | train loss=13.100294, train acc=0.0267 | test adjacency loss=13.228346, test CE loss=6.278654, test acc=0.0166
# Epoch 021 | train loss=13.044957, train acc=0.0401 | test adjacency loss=13.195951, test CE loss=6.273038, test acc=0.0166
# Epoch 022 | train loss=13.016398, train acc=0.0490 | test adjacency loss=13.166768, test CE loss=6.267789, test acc=0.0276
# Epoch 023 | train loss=12.947267, train acc=0.0653 | test adjacency loss=13.138556, test CE loss=6.265772, test acc=0.0276
# Epoch 024 | train loss=12.906315, train acc=0.0682 | test adjacency loss=13.111502, test CE loss=6.264962, test acc=0.0331
# Epoch 025 | train loss=12.871830, train acc=0.0668 | test adjacency loss=13.087562, test CE loss=6.265675, test acc=0.0331
# Epoch 026 | train loss=12.834274, train acc=0.0801 | test adjacency loss=13.063988, test CE loss=6.266850, test acc=0.0331
# Epoch 027 | train loss=12.793266, train acc=0.0875 | test adjacency loss=13.041608, test CE loss=6.271751, test acc=0.0387
# Epoch 028 | train loss=12.753317, train acc=0.0875 | test adjacency loss=13.019747, test CE loss=6.275783, test acc=0.0387
# Epoch 029 | train loss=12.730482, train acc=0.0890 | test adjacency loss=13.001089, test CE loss=6.281031, test acc=0.0497
# Epoch 030 | train loss=12.707936, train acc=0.0964 | test adjacency loss=12.982646, test CE loss=6.287796, test acc=0.0552
# Epoch 031 | train loss=12.665525, train acc=0.0950 | test adjacency loss=12.965258, test CE loss=6.294166, test acc=0.0552
# Epoch 032 | train loss=12.626976, train acc=0.0964 | test adjacency loss=12.949401, test CE loss=6.302961, test acc=0.0552
# Epoch 033 | train loss=12.603901, train acc=0.0994 | test adjacency loss=12.935174, test CE loss=6.312505, test acc=0.0552
# Epoch 034 | train loss=12.581393, train acc=0.1009 | test adjacency loss=12.923431, test CE loss=6.319790, test acc=0.0552
# Epoch 035 | train loss=12.543847, train acc=0.1009 | test adjacency loss=12.910404, test CE loss=6.331701, test acc=0.0552
# Epoch 036 | train loss=12.527730, train acc=0.1024 | test adjacency loss=12.899226, test CE loss=6.340761, test acc=0.0552
# Epoch 037 | train loss=12.500260, train acc=0.1024 | test adjacency loss=12.888063, test CE loss=6.350521, test acc=0.0552
# Epoch 038 | train loss=12.485132, train acc=0.1068 | test adjacency loss=12.879370, test CE loss=6.361569, test acc=0.0552
# Epoch 039 | train loss=12.462520, train acc=0.1053 | test adjacency loss=12.868537, test CE loss=6.368988, test acc=0.0552
# Epoch 040 | train loss=12.448653, train acc=0.1068 | test adjacency loss=12.860334, test CE loss=6.378853, test acc=0.0552
# Epoch 041 | train loss=12.422889, train acc=0.1053 | test adjacency loss=12.854096, test CE loss=6.389329, test acc=0.0552
# Epoch 042 | train loss=12.402681, train acc=0.1053 | test adjacency loss=12.846086, test CE loss=6.398692, test acc=0.0552
# Epoch 043 | train loss=12.387450, train acc=0.1024 | test adjacency loss=12.840314, test CE loss=6.408083, test acc=0.0552
# Epoch 044 | train loss=12.373221, train acc=0.1068 | test adjacency loss=12.834586, test CE loss=6.416554, test acc=0.0552
# Epoch 045 | train loss=12.366428, train acc=0.1053 | test adjacency loss=12.828463, test CE loss=6.422234, test acc=0.0552
# Epoch 046 | train loss=12.347388, train acc=0.1068 | test adjacency loss=12.821095, test CE loss=6.427660, test acc=0.0552
# Epoch 047 | train loss=12.326393, train acc=0.1068 | test adjacency loss=12.817775, test CE loss=6.437767, test acc=0.0552
# Epoch 048 | train loss=12.326472, train acc=0.1068 | test adjacency loss=12.811519, test CE loss=6.443183, test acc=0.0608
# Epoch 049 | train loss=12.307976, train acc=0.1068 | test adjacency loss=12.807248, test CE loss=6.451077, test acc=0.0608
# Epoch 050 | train loss=12.302083, train acc=0.1068 | test adjacency loss=12.801455, test CE loss=6.452103, test acc=0.0608
# Epoch 051 | train loss=12.286134, train acc=0.1068 | test adjacency loss=12.797550, test CE loss=6.457743, test acc=0.0608
# Epoch 052 | train loss=12.278931, train acc=0.1068 | test adjacency loss=12.792810, test CE loss=6.460321, test acc=0.0608
# Epoch 053 | train loss=12.277022, train acc=0.1068 | test adjacency loss=12.788921, test CE loss=6.465535, test acc=0.0608
# Epoch 054 | train loss=12.254626, train acc=0.1068 | test adjacency loss=12.784927, test CE loss=6.471318, test acc=0.0608
# Epoch 055 | train loss=12.243506, train acc=0.1068 | test adjacency loss=12.781691, test CE loss=6.475214, test acc=0.0608
# Epoch 056 | train loss=12.231064, train acc=0.1068 | test adjacency loss=12.775985, test CE loss=6.471827, test acc=0.0608
# Epoch 057 | train loss=12.220556, train acc=0.1068 | test adjacency loss=12.772343, test CE loss=6.475111, test acc=0.0608
# Epoch 058 | train loss=12.233994, train acc=0.1068 | test adjacency loss=12.769109, test CE loss=6.476283, test acc=0.0608
# Epoch 059 | train loss=12.211727, train acc=0.1068 | test adjacency loss=12.766003, test CE loss=6.479868, test acc=0.0608
# Epoch 060 | train loss=12.204599, train acc=0.1068 | test adjacency loss=12.762473, test CE loss=6.481983, test acc=0.0608
# Epoch 061 | train loss=12.197098, train acc=0.1068 | test adjacency loss=12.759660, test CE loss=6.484986, test acc=0.0608
# Epoch 062 | train loss=12.191994, train acc=0.1068 | test adjacency loss=12.755692, test CE loss=6.483450, test acc=0.0608
# Epoch 063 | train loss=12.172533, train acc=0.1068 | test adjacency loss=12.752136, test CE loss=6.482982, test acc=0.0608
# Epoch 064 | train loss=12.173015, train acc=0.1068 | test adjacency loss=12.748946, test CE loss=6.482740, test acc=0.0608
# Saved final adjacency-aware self-attentive-pooling checkpoint to model_outputs/where_transformer/winsize4h/where_transformer_adjacency_aware_sap_4h_final.pt

# %%
baseline_prediction_df = collect_where_predictions(
    where_transformer,
    test_where_dataset,
    DEVICE,
)

baseline_sap_df = collect_where_predictions(
    where_transformer_sap,
    test_where_dataset,
    DEVICE,
)

adjacency_prediction_df = collect_where_predictions(
    adjacency_where_transformer,
    test_where_dataset,
    DEVICE,
)

adjacency_prediction_sap_df = collect_where_predictions(
    adjacency_where_transformer_sap,
    test_where_dataset,
    DEVICE,
)


baseline_pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in baseline_prediction_df.itertuples(index=False)
    ],
    dtype=float,
)
baseline_pair_distances_sap = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in baseline_sap_df.itertuples(index=False)
    ],
    dtype=float,
)
adjacency_pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in adjacency_prediction_df.itertuples(index=False)
    ],
    dtype=float,
)
adjacency_pair_distances_sap = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in adjacency_prediction_sap_df.itertuples(index=False)
    ],
    dtype=float,
)


baseline_summary = summarize_pair_distances(baseline_pair_distances)
baseline_summary["exact_pair_accuracy"] = baseline_prediction_df[
    "exact_pair_match"
].mean()

baseline_summary_sap = summarize_pair_distances(baseline_pair_distances_sap)
baseline_summary_sap["exact_pair_accuracy"] = baseline_sap_df["exact_pair_match"].mean()

adjacency_summary = summarize_pair_distances(adjacency_pair_distances)
adjacency_summary["exact_pair_accuracy"] = adjacency_prediction_df[
    "exact_pair_match"
].mean()
adjacency_summary["mean_distance_reduction_vs_cross_entropy"] = 1 - (
    adjacency_summary["mean_distance"] / baseline_summary["mean_distance"]
)

adjacency_summary_sap = summarize_pair_distances(adjacency_pair_distances_sap)
adjacency_summary_sap["exact_pair_accuracy"] = adjacency_prediction_sap_df[
    "exact_pair_match"
].mean()
adjacency_summary_sap["mean_distance_reduction_vs_cross_entropy"] = 1 - (
    adjacency_summary_sap["mean_distance"] / baseline_summary_sap["mean_distance"]
)

adjacency_comparison_df = pd.DataFrame(
    [
        {"model": "Cross entropy", **baseline_summary},
        {"model": "Cross entropy (SAP)", **baseline_summary_sap},
        {"model": "Adjacency-aware", **adjacency_summary},
        {"model": "Adjacency-aware (SAP)", **adjacency_summary_sap},
    ]
)

comparison_table_path = (
    MODEL_OUTPUT_DIR / f"where_transformer_{WINDOW_LABEL}_model_comparison.csv"
)
adjacency_comparison_df.to_csv(comparison_table_path, index=False)
print(f"Saved {WINDOW_LABEL} model comparison to {comparison_table_path}")

display(adjacency_comparison_df.round(3))
print(
    "Adjacency-aware mean unordered pair distance reduction vs cross entropy: "
    f"{adjacency_summary['mean_distance_reduction_vs_cross_entropy']:.1%}"
)
print(
    "Adjacency-aware (SAP) mean unordered pair distance reduction vs cross entropy: "
    f"{adjacency_summary_sap['mean_distance_reduction_vs_cross_entropy']:.1%}"
)

bins = np.arange(-0.5, zone_graph_diameter + 1.5, 1)
bin_centers = (bins[:-1] + bins[1:]) / 2
bar_width = 0.2
baseline_counts, _ = np.histogram(
    baseline_pair_distances[np.isfinite(baseline_pair_distances)], bins=bins
)
baseline_sap_counts, _ = np.histogram(
    baseline_pair_distances_sap[np.isfinite(baseline_pair_distances_sap)], bins=bins
)
adjacency_counts, _ = np.histogram(
    adjacency_pair_distances[np.isfinite(adjacency_pair_distances)], bins=bins
)
adjacency_sap_counts, _ = np.histogram(
    adjacency_pair_distances_sap[np.isfinite(adjacency_pair_distances_sap)], bins=bins
)
baseline_percentages = 100 * baseline_counts / baseline_counts.sum()
baseline_sap_percentages = 100 * baseline_sap_counts / baseline_sap_counts.sum()
adjacency_percentages = 100 * adjacency_counts / adjacency_counts.sum()
adjacency_sap_percentages = 100 * adjacency_sap_counts / adjacency_sap_counts.sum()

fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(
    bin_centers - 1.5 * bar_width,
    baseline_percentages,
    width=bar_width,
    label="Cross entropy",
    align="center",
)
ax.bar(
    bin_centers - 0.5 * bar_width,
    baseline_sap_percentages,
    width=bar_width,
    label="Cross entropy (SAP)",
    align="center",
)
ax.bar(
    bin_centers + 0.5 * bar_width,
    adjacency_percentages,
    width=bar_width,
    label="Adjacency-aware",
    align="center",
)
ax.bar(
    bin_centers + 1.5 * bar_width,
    adjacency_sap_percentages,
    width=bar_width,
    label="Adjacency-aware (SAP)",
    align="center",
)
ax.set_xticks(bin_centers)
ax.set_xlabel("Unordered zone-pair graph distance")
ax.set_ylabel("Percentage (%)")
# ax.set_title("Cross-entropy vs adjacency-aware graph-distance error")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_{WINDOW_LABEL}_cross_entropy_vs_adjacency_graph_distance_error_bpa.pdf",
    dpi=300,
)
plt.show()
# Out:
# Saved 4h model comparison to model_outputs/where_transformer/winsize4h/where_transformer_4h_model_comparison.csv
#                    model  mean_distance  median_distance  p90_distance  \
# 0          Cross entropy          1.436              1.5           2.0
# 1    Cross entropy (SAP)          1.597              2.0           2.5
# 2        Adjacency-aware          1.257              1.0           2.0
# 3  Adjacency-aware (SAP)          1.260              1.0           2.0
#
#    same_zone_pair_rate  adjacent_or_same_pair_rate  unreachable_count  \
# 0                0.022                       0.453                  0
# 1                0.028                       0.376                  0
# 2                0.061                       0.608                  0
# 3                0.061                       0.608                  0
#
#    exact_pair_accuracy  mean_distance_reduction_vs_cross_entropy
# 0                0.022                                       NaN
# 1                0.028                                       NaN
# 2                0.061                                     0.125
# 3                0.061                                     0.211
# Adjacency-aware mean unordered pair distance reduction vs cross entropy: 12.5%
# Adjacency-aware (SAP) mean unordered pair distance reduction vs cross entropy: 21.1%

# %% [markdown]
# # Selected-window paper plot

# %%
paper_bar_width = 0.36

fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(
    bin_centers - paper_bar_width / 2,
    baseline_percentages,
    width=paper_bar_width,
    label="Cross entropy",
    align="center",
)
ax.bar(
    bin_centers + paper_bar_width / 2,
    adjacency_percentages,
    width=paper_bar_width,
    label="Adjacency-aware",
    align="center",
)
ax.set_xticks(bin_centers)
ax.set_xlabel("Unordered zone-pair graph distance")
ax.set_ylabel("Percentage (%)")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_{WINDOW_LABEL}_cross_entropy_vs_adjacency_graph_distance_error_paper_bpa.pdf",
    dpi=300,
)
plt.show()
