# %%
import random
from pathlib import Path

import numpy as np
import torch

DATA_DIR = Path("output")

OUTPUT_DIR = Path("model_outputs")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

RANDOM_STATE = 42


def set_seed(seed=RANDOM_STATE):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True, warn_only=True)


set_seed()

# %%
dataset_path = Path("output/dataset_winsize1h_where.csv")

# %%
import json

import pandas as pd

where_df = pd.read_csv(
    dataset_path,
    dtype={"fold_id": "int64"},
    converters={
        "window": json.loads,
        "label": json.loads,
    },
)
where_df = where_df.loc[~where_df["is_bg"]].drop(columns="is_bg")

where_df.head()
# Out:
#    fold_id                                             window  \
# 1        4  [{'from_zone_index': 5, 'to_zone_index': 5, 'o...
# 2        4  [{'from_zone_index': 5, 'to_zone_index': 1, 'o...
# 3        1  [{'from_zone_index': 18, 'to_zone_index': 0, '...
# 4        4  [{'from_zone_index': 7, 'to_zone_index': 7, 'o...
# 6        4  [{'from_zone_index': 5, 'to_zone_index': 5, 'o...
#
#                                         label
# 1  {'from_zone_index': 0, 'to_zone_index': 0}
# 2  {'from_zone_index': 2, 'to_zone_index': 2}
# 3  {'from_zone_index': 7, 'to_zone_index': 7}
# 4  {'from_zone_index': 9, 'to_zone_index': 9}
# 6  {'from_zone_index': 9, 'to_zone_index': 9}

# %%
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset

OUTAGE_TYPE_TO_ID = {
    "Planned": 0,
    "Auto": 1,
}


class WhereOutageDataset(Dataset):
    def __init__(self, df):
        self.df = df.reset_index(drop=True)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        window = row["window"]
        label = row["label"]

        outage_type = torch.tensor(
            [OUTAGE_TYPE_TO_ID[event["outage_type"]] for event in window],
            dtype=torch.long,
        )
        from_zone_indices = torch.tensor(
            [event["from_zone_index"] for event in window],
            dtype=torch.long,
        )
        to_zone_indices = torch.tensor(
            [event["to_zone_index"] for event in window],
            dtype=torch.long,
        )
        time_interval_index = torch.tensor(
            [event["time_interval_index"] for event in window],
            dtype=torch.long,
        )
        target = torch.tensor(
            [label["from_zone_index"], label["to_zone_index"]],
            dtype=torch.long,
        )

        return {
            "outage_type": outage_type,
            "from_zone_indices": from_zone_indices,
            "to_zone_indices": to_zone_indices,
            "time_interval_index": time_interval_index,
            "target": target,
        }


TRAIN_FOLDS = [0, 1, 2, 3, 4]
TEST_FOLDS = [-1]

train_where_dataset = WhereOutageDataset(
    where_df[where_df["fold_id"].isin(TRAIN_FOLDS)]
)
test_where_dataset = WhereOutageDataset(where_df[where_df["fold_id"].isin(TEST_FOLDS)])

# %%
for i, sample_dict in enumerate(train_where_dataset):
    print(sample_dict)
    if i == 10:
        break
# Out:
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([0, 0])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([1]), 'time_interval_index': tensor([0]), 'target': tensor([2, 2])}
# {'outage_type': tensor([1, 1, 0]), 'from_zone_indices': tensor([18,  1,  5]), 'to_zone_indices': tensor([0, 1, 5]), 'time_interval_index': tensor([0, 0, 0]), 'target': tensor([7, 7])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([7]), 'to_zone_indices': tensor([7]), 'time_interval_index': tensor([0]), 'target': tensor([9, 9])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([9, 9])}
# {'outage_type': tensor([1, 1, 1, 0]), 'from_zone_indices': tensor([5, 5, 5, 7]), 'to_zone_indices': tensor([5, 5, 5, 7]), 'time_interval_index': tensor([1, 1, 1, 0]), 'target': tensor([5, 5])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([5, 5])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([5, 9])}
# {'outage_type': tensor([0, 0, 0, 0]), 'from_zone_indices': tensor([5, 5, 5, 5]), 'to_zone_indices': tensor([5, 5, 5, 5]), 'time_interval_index': tensor([1, 1, 0, 0]), 'target': tensor([5, 5])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([3]), 'to_zone_indices': tensor([3]), 'time_interval_index': tensor([0]), 'target': tensor([11, 11])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([6, 6])}

# %%
from tqdm import tqdm as tdqm

num_time_intervals = 0
for sample_dict in tdqm(train_where_dataset):
    num_time_intervals = max(
        num_time_intervals, sample_dict["time_interval_index"].max().item() + 1
    )
print(f"{num_time_intervals = }")
# Out:
# 100%|██████████| 674/674 [00:00<00:00, 10722.81it/s]
# num_time_intervals = 3

# %% [markdown]
# # Models definition

# %%
MODEL_SCALE = 1

ZONE_EMBEDDING_DIM = int(64 * MODEL_SCALE)
OUTAGE_TYPE_EMBEDDING_DIM = int(32 * MODEL_SCALE)
TIME_INTERVAL_EMBEDDING_DIM = int(32 * MODEL_SCALE)
TRANSFORMER_DIM = int(256 * MODEL_SCALE)

DROPOUT = 0.15

# %%
import torch.nn as nn

num_zones = int(
    max(
        where_df["label"]
        .map(lambda x: max(x["from_zone_index"], x["to_zone_index"]))
        .max(),
        max(
            max(event["from_zone_index"], event["to_zone_index"])
            for window in where_df["window"]
            for event in window
        ),
    )
    + 1
)
num_outage_types = len(OUTAGE_TYPE_TO_ID)


class WhereTransformer(nn.Module):
    """ "Vanilla transformer model"""

    def __init__(
        self,
        num_zones,
        num_outage_types,
        zone_embedding_dim=ZONE_EMBEDDING_DIM,
        outage_type_embedding_dim=OUTAGE_TYPE_EMBEDDING_DIM,
        time_interval_embedding_dim=TIME_INTERVAL_EMBEDDING_DIM,
        transformer_dim=TRANSFORMER_DIM,
        dropout=DROPOUT,
    ):
        super().__init__()
        self.num_zones = num_zones
        self.zone_embedding = nn.Embedding(num_zones, zone_embedding_dim)
        self.outage_type_embedding = nn.Embedding(
            num_outage_types,
            outage_type_embedding_dim,
        )
        self.time_interval_embedding = nn.Embedding(
            num_time_intervals,
            time_interval_embedding_dim,
        )
        self.input_fc = nn.Linear(
            2 * zone_embedding_dim
            + outage_type_embedding_dim
            + time_interval_embedding_dim,
            transformer_dim,
        )
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=transformer_dim,
            nhead=transformer_dim // 64,
            dim_feedforward=transformer_dim * 4,
            dropout=dropout,
            batch_first=True,
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=1,
        )
        self.projection = nn.Linear(transformer_dim, 2 * num_zones)

    def forward(
        self,
        from_zone_indices,
        to_zone_indices,
        outage_type,
        time_interval_index,
    ):
        from_zone_emb = self.zone_embedding(from_zone_indices)
        to_zone_emb = self.zone_embedding(to_zone_indices)
        outage_type_emb = self.outage_type_embedding(outage_type)
        time_interval_emb = self.time_interval_embedding(time_interval_index)

        x = torch.cat(
            [from_zone_emb, to_zone_emb, outage_type_emb, time_interval_emb],
            dim=-1,
        )
        x = self.input_fc(x)

        x = self.transformer_encoder(x)

        # AVerage pooling over the time dimension (dim=1)
        # pooled = x.mean(dim=1)
        # Use the last time step's output for pooling
        pooled = x[:, -1, :]

        logits = self.projection(pooled)
        return logits.view(-1, 2, self.num_zones)

# %%
class GraphDistanceUnorderedZoneLoss(nn.Module):
    def __init__(
        self,
        graph,
        num_zones,
        distance_weight=0.2,
        unreachable_distance=None,
        reduction="mean",
    ):
        super().__init__()
        self.num_zones = num_zones
        self.distance_weight = distance_weight
        self.reduction = reduction

        distance_matrix = torch.as_tensor(
            graph.distances(
                source=range(num_zones),
                target=range(num_zones),
                mode="ALL",
            ),
            dtype=torch.float32,
        )
        finite_distances = distance_matrix[torch.isfinite(distance_matrix)]
        if unreachable_distance is None:
            unreachable_distance = finite_distances.max().item() + 1.0
        distance_matrix = torch.where(
            torch.isfinite(distance_matrix),
            distance_matrix,
            torch.full_like(distance_matrix, float(unreachable_distance)),
        )
        self.register_buffer("distance_matrix", distance_matrix)

    def _ordered_loss(self, from_logits, to_logits, target_from, target_to):
        ce_loss = nn.functional.cross_entropy(
            from_logits,
            target_from,
            reduction="none",
        ) + nn.functional.cross_entropy(
            to_logits,
            target_to,
            reduction="none",
        )

        from_probs = nn.functional.softmax(from_logits, dim=-1)
        to_probs = nn.functional.softmax(to_logits, dim=-1)
        from_distance = (from_probs * self.distance_matrix[target_from]).sum(dim=-1)
        to_distance = (to_probs * self.distance_matrix[target_to]).sum(dim=-1)
        distance_loss = from_distance + to_distance

        return ce_loss + self.distance_weight * distance_loss

    def forward(self, logits, target):
        from_logits = logits[:, 0, :]
        to_logits = logits[:, 1, :]
        target_from = target[:, 0]
        target_to = target[:, 1]

        forward_loss = self._ordered_loss(
            from_logits,
            to_logits,
            target_from,
            target_to,
        )
        swapped_loss = self._ordered_loss(
            from_logits,
            to_logits,
            target_to,
            target_from,
        )
        loss = torch.minimum(forward_loss, swapped_loss)

        if self.reduction == "mean":
            return loss.mean()
        if self.reduction == "sum":
            return loss.sum()
        if self.reduction == "none":
            return loss
        raise ValueError(f"Unsupported reduction: {self.reduction}")

# %%
class SelfAttentivePooling(nn.Module):
    def __init__(self, input_dim, attention_dim=None, dropout=DROPOUT):
        super().__init__()
        attention_dim = attention_dim or input_dim
        self.attention = nn.Sequential(
            nn.Linear(input_dim, attention_dim),
            nn.Tanh(),
            nn.Dropout(dropout),
            nn.Linear(attention_dim, 1),
        )

    def forward(self, x):
        attention_scores = self.attention(x).squeeze(-1)
        attention_weights = torch.softmax(attention_scores, dim=1).unsqueeze(-1)
        return (x * attention_weights).sum(dim=1)


class WhereTransformerSAP(nn.Module):
    def __init__(
        self,
        num_zones,
        num_outage_types,
        zone_embedding_dim=ZONE_EMBEDDING_DIM,
        outage_type_embedding_dim=OUTAGE_TYPE_EMBEDDING_DIM,
        time_interval_embedding_dim=TIME_INTERVAL_EMBEDDING_DIM,
        transformer_dim=TRANSFORMER_DIM,
        dropout=DROPOUT,
    ):
        super().__init__()
        self.num_zones = num_zones
        self.zone_embedding = nn.Embedding(num_zones, zone_embedding_dim)
        self.outage_type_embedding = nn.Embedding(
            num_outage_types,
            outage_type_embedding_dim,
        )
        self.time_interval_embedding = nn.Embedding(
            num_time_intervals,
            time_interval_embedding_dim,
        )
        self.input_fc = nn.Linear(
            2 * zone_embedding_dim
            + outage_type_embedding_dim
            + time_interval_embedding_dim,
            transformer_dim,
        )
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=transformer_dim,
            nhead=transformer_dim // 64,
            dim_feedforward=transformer_dim * 4,
            dropout=dropout,
            batch_first=True,
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=1,
        )
        self.self_attentive_pooling = SelfAttentivePooling(
            transformer_dim,
            dropout=dropout,
        )
        self.projection = nn.Linear(transformer_dim, 2 * num_zones)

    def forward(
        self,
        from_zone_indices,
        to_zone_indices,
        outage_type,
        time_interval_index,
    ):
        from_zone_emb = self.zone_embedding(from_zone_indices)
        to_zone_emb = self.zone_embedding(to_zone_indices)
        outage_type_emb = self.outage_type_embedding(outage_type)
        time_interval_emb = self.time_interval_embedding(time_interval_index)

        x = torch.cat(
            [from_zone_emb, to_zone_emb, outage_type_emb, time_interval_emb],
            dim=-1,
        )
        x = self.input_fc(x)

        x = self.transformer_encoder(x)

        pooled = self.self_attentive_pooling(x)

        logits = self.projection(pooled)
        return logits.view(-1, 2, self.num_zones)

# %% [markdown]
# # Vanilla Model training

# %%
LEARNING_RATE = 3e-6
NUM_EPOCHS = 64
VIRTUAL_BATCH_SIZE = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def sample_to_device(sample, device):
    return {
        "from_zone_indices": sample["from_zone_indices"].unsqueeze(0).to(device),
        "to_zone_indices": sample["to_zone_indices"].unsqueeze(0).to(device),
        "outage_type": sample["outage_type"].unsqueeze(0).to(device),
        "time_interval_index": sample["time_interval_index"].unsqueeze(0).to(device),
        "target": sample["target"].unsqueeze(0).to(device),
    }


def unordered_zone_loss(logits, target):
    from_logits = logits[:, 0, :]
    to_logits = logits[:, 1, :]
    target_from = target[:, 0]
    target_to = target[:, 1]

    forward_loss = nn.functional.cross_entropy(
        from_logits,
        target_from,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_to,
    )
    swapped_loss = nn.functional.cross_entropy(
        from_logits,
        target_to,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_from,
    )
    return torch.minimum(forward_loss, swapped_loss).mean()


def unordered_zone_correct_count(logits, target):
    pred = logits.argmax(dim=-1)
    pred_sorted = torch.sort(pred, dim=1).values
    target_sorted = torch.sort(target, dim=1).values
    return (pred_sorted == target_sorted).all(dim=1).sum().item()


set_seed()
where_transformer = WhereTransformer(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
)
where_transformer.to(DEVICE)
optimizer = torch.optim.Adam(where_transformer.parameters(), lr=LEARNING_RATE)

training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    where_transformer.train()
    optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = where_transformer(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = unordered_zone_loss(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            optimizer.step()
            optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        optimizer.step()
        optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    where_transformer.eval()
    test_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = where_transformer(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy,
    }
    training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test loss={test_loss:.6f}, test acc={test_accuracy:.4f}"
    )

MODEL_OUTPUT_DIR = OUTPUT_DIR / "where_transformer"
MODEL_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
mean_pooling_ce_checkpoint_path = (
    MODEL_OUTPUT_DIR / "where_transformer_cross_entropy_mean_pooling_last.pt"
)

torch.save(
    {
        "model_state_dict": where_transformer.state_dict(),
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "training_history": training_history,
    },
    mean_pooling_ce_checkpoint_path,
)

print(
    f"Saved final cross-entropy mean-pooling checkpoint to {mean_pooling_ce_checkpoint_path}"
)
# Out:
# /home/aj/venv/lib/python3.14/site-packages/torch/autograd/graph.py:979: UserWarning: Memory Efficient attention defaults to a non-deterministic algorithm. To explicitly enable determinism call torch.use_deterministic_algorithms(True, warn_only=False). (Triggered internally at /__w/pytorch/pytorch/aten/src/ATen/native/transformers/cuda/attention_backward.cu:833.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 001 | train loss=6.583298, train acc=0.0030 | test loss=6.603993, test acc=0.0055
# Epoch 002 | train loss=6.529939, train acc=0.0030 | test loss=6.574581, test acc=0.0055
# Epoch 003 | train loss=6.489915, train acc=0.0074 | test loss=6.546690, test acc=0.0055
# Epoch 004 | train loss=6.443544, train acc=0.0089 | test loss=6.521295, test acc=0.0055
# Epoch 005 | train loss=6.400731, train acc=0.0119 | test loss=6.497730, test acc=0.0110
# Epoch 006 | train loss=6.373075, train acc=0.0104 | test loss=6.475147, test acc=0.0055
# Epoch 007 | train loss=6.357158, train acc=0.0148 | test loss=6.454650, test acc=0.0110
# Epoch 008 | train loss=6.306270, train acc=0.0208 | test loss=6.436181, test acc=0.0110
# Epoch 009 | train loss=6.279428, train acc=0.0134 | test loss=6.418455, test acc=0.0055
# Epoch 010 | train loss=6.261626, train acc=0.0267 | test loss=6.401747, test acc=0.0055
# Epoch 011 | train loss=6.224572, train acc=0.0223 | test loss=6.386007, test acc=0.0055
# Epoch 012 | train loss=6.207490, train acc=0.0208 | test loss=6.371340, test acc=0.0055
# Epoch 013 | train loss=6.184825, train acc=0.0341 | test loss=6.357635, test acc=0.0055
# Epoch 014 | train loss=6.161892, train acc=0.0326 | test loss=6.345583, test acc=0.0055
# Epoch 015 | train loss=6.121956, train acc=0.0386 | test loss=6.332786, test acc=0.0166
# Epoch 016 | train loss=6.111025, train acc=0.0460 | test loss=6.321984, test acc=0.0166
# Epoch 017 | train loss=6.098037, train acc=0.0460 | test loss=6.311213, test acc=0.0166
# Epoch 018 | train loss=6.085222, train acc=0.0475 | test loss=6.301597, test acc=0.0166
# Epoch 019 | train loss=6.075753, train acc=0.0371 | test loss=6.292536, test acc=0.0166
# Epoch 020 | train loss=6.060181, train acc=0.0460 | test loss=6.283251, test acc=0.0166
# Epoch 021 | train loss=6.041138, train acc=0.0490 | test loss=6.275984, test acc=0.0166
# Epoch 022 | train loss=6.010059, train acc=0.0475 | test loss=6.267724, test acc=0.0166
# Epoch 023 | train loss=5.998362, train acc=0.0564 | test loss=6.260487, test acc=0.0166
# Epoch 024 | train loss=5.989573, train acc=0.0549 | test loss=6.252612, test acc=0.0166
# Epoch 025 | train loss=5.995232, train acc=0.0534 | test loss=6.245934, test acc=0.0166
# Epoch 026 | train loss=5.984958, train acc=0.0504 | test loss=6.239394, test acc=0.0166
# Epoch 027 | train loss=5.958185, train acc=0.0593 | test loss=6.233107, test acc=0.0166
# Epoch 028 | train loss=5.953103, train acc=0.0549 | test loss=6.227324, test acc=0.0166
# Epoch 029 | train loss=5.932220, train acc=0.0504 | test loss=6.221498, test acc=0.0166
# Epoch 030 | train loss=5.924645, train acc=0.0519 | test loss=6.216176, test acc=0.0166
# Epoch 031 | train loss=5.912756, train acc=0.0549 | test loss=6.210703, test acc=0.0166
# Epoch 032 | train loss=5.903384, train acc=0.0593 | test loss=6.205707, test acc=0.0166
# Epoch 033 | train loss=5.906870, train acc=0.0519 | test loss=6.201268, test acc=0.0166
# Epoch 034 | train loss=5.883598, train acc=0.0608 | test loss=6.196422, test acc=0.0166
# Epoch 035 | train loss=5.864299, train acc=0.0608 | test loss=6.191357, test acc=0.0166
# Epoch 036 | train loss=5.865408, train acc=0.0608 | test loss=6.186963, test acc=0.0166
# Epoch 037 | train loss=5.852366, train acc=0.0638 | test loss=6.182520, test acc=0.0166
# Epoch 038 | train loss=5.846432, train acc=0.0638 | test loss=6.179124, test acc=0.0166
# Epoch 039 | train loss=5.831212, train acc=0.0564 | test loss=6.175634, test acc=0.0166
# Epoch 040 | train loss=5.830567, train acc=0.0593 | test loss=6.171955, test acc=0.0166
# Epoch 041 | train loss=5.825865, train acc=0.0564 | test loss=6.167401, test acc=0.0166
# Epoch 042 | train loss=5.817174, train acc=0.0534 | test loss=6.163853, test acc=0.0166
# Epoch 043 | train loss=5.817604, train acc=0.0564 | test loss=6.160652, test acc=0.0166
# Epoch 044 | train loss=5.804957, train acc=0.0593 | test loss=6.156797, test acc=0.0166
# Epoch 045 | train loss=5.791431, train acc=0.0593 | test loss=6.153590, test acc=0.0166
# Epoch 046 | train loss=5.791328, train acc=0.0564 | test loss=6.150491, test acc=0.0166
# Epoch 047 | train loss=5.778516, train acc=0.0579 | test loss=6.147147, test acc=0.0166
# Epoch 048 | train loss=5.792686, train acc=0.0638 | test loss=6.144688, test acc=0.0166
# Epoch 049 | train loss=5.773266, train acc=0.0668 | test loss=6.141392, test acc=0.0166
# Epoch 050 | train loss=5.771415, train acc=0.0593 | test loss=6.138811, test acc=0.0166
# Epoch 051 | train loss=5.765522, train acc=0.0623 | test loss=6.136394, test acc=0.0166
# Epoch 052 | train loss=5.742507, train acc=0.0579 | test loss=6.133872, test acc=0.0221
# Epoch 053 | train loss=5.759191, train acc=0.0608 | test loss=6.131365, test acc=0.0221
# Epoch 054 | train loss=5.742761, train acc=0.0668 | test loss=6.128985, test acc=0.0221
# Epoch 055 | train loss=5.740000, train acc=0.0623 | test loss=6.126851, test acc=0.0221
# Epoch 056 | train loss=5.725010, train acc=0.0593 | test loss=6.124700, test acc=0.0221
# Epoch 057 | train loss=5.728840, train acc=0.0579 | test loss=6.121897, test acc=0.0276
# Epoch 058 | train loss=5.733574, train acc=0.0593 | test loss=6.119891, test acc=0.0276
# Epoch 059 | train loss=5.708761, train acc=0.0682 | test loss=6.118057, test acc=0.0276
# Epoch 060 | train loss=5.707009, train acc=0.0653 | test loss=6.115725, test acc=0.0276
# Epoch 061 | train loss=5.709205, train acc=0.0668 | test loss=6.113518, test acc=0.0276
# Epoch 062 | train loss=5.705344, train acc=0.0682 | test loss=6.111364, test acc=0.0331
# Epoch 063 | train loss=5.697310, train acc=0.0608 | test loss=6.109693, test acc=0.0331
# Epoch 064 | train loss=5.697029, train acc=0.0638 | test loss=6.108020, test acc=0.0331
# Saved final cross-entropy mean-pooling checkpoint to model_outputs/where_transformer/where_transformer_cross_entropy_mean_pooling_last.pt

# %%
import matplotlib.pyplot as plt

epochs = [row["epoch"] for row in training_history]
train_losses = [row["train_loss"] for row in training_history]
test_losses = [row["test_loss"] for row in training_history]
train_accuracies = [row["train_accuracy"] for row in training_history]
test_accuracies = [row["test_accuracy"] for row in training_history]

plt.figure(figsize=(8, 4))

plt.plot(epochs, train_losses, label="Train")
plt.plot(epochs, test_losses, label="Test")
plt.xlabel("Epoch")
plt.ylabel("Loss")
# plt.title("Training and test loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "where_training_loss.pdf", dpi=300)
plt.show()

plt.figure(figsize=(8, 4))

plt.plot(epochs, train_accuracies, label="Train")
plt.plot(epochs, test_accuracies, label="Test")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# plt.title("Training and test accuracy")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "where_training_accuracy.pdf", dpi=300)
plt.show()

# %%
from collections import deque
from pathlib import Path

import igraph as ig
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

GRAPH_PATH = Path("res/outage_graph.pkl")
EDGE_ZONE_PATH = Path("output/edge_zones.csv")
RANDOM_PAIR_BASELINE_SIZE = 10_000


def build_zone_distance_lookup(edge_zone_path):
    edge_zone_df = pd.read_csv(edge_zone_path)
    zones = sorted(
        set(edge_zone_df["from_zone"].astype(int))
        | set(edge_zone_df["to_zone"].astype(int))
    )
    adjacency = {zone: {zone} for zone in zones}

    for from_zone, to_zone in zip(
        edge_zone_df["from_zone"].astype(int),
        edge_zone_df["to_zone"].astype(int),
    ):
        adjacency.setdefault(from_zone, {from_zone}).add(to_zone)
        adjacency.setdefault(to_zone, {to_zone}).add(from_zone)

    distances = {}
    for source in adjacency:
        source_distances = {source: 0}
        queue = deque([source])
        while queue:
            current = queue.popleft()
            for neighbor in adjacency[current]:
                if neighbor not in source_distances:
                    source_distances[neighbor] = source_distances[current] + 1
                    queue.append(neighbor)
        distances[source] = source_distances

    return distances


def zone_distance(source_zone, target_zone, distance_lookup):
    return distance_lookup.get(int(source_zone), {}).get(int(target_zone), np.nan)


def unordered_pair_graph_distance(true_pair, pred_pair, distance_lookup):
    direct = (
        zone_distance(true_pair[0], pred_pair[0], distance_lookup)
        + zone_distance(true_pair[1], pred_pair[1], distance_lookup)
    ) / 2
    swapped = (
        zone_distance(true_pair[0], pred_pair[1], distance_lookup)
        + zone_distance(true_pair[1], pred_pair[0], distance_lookup)
    ) / 2
    candidates = [distance for distance in [direct, swapped] if np.isfinite(distance)]
    return min(candidates) if candidates else np.nan


def summarize_pair_distances(distances):
    distances = np.asarray(distances, dtype=float)
    finite = distances[np.isfinite(distances)]
    return {
        "mean_distance": finite.mean(),
        "median_distance": np.median(finite),
        "p90_distance": np.percentile(finite, 90),
        "same_zone_pair_rate": (finite == 0).mean(),
        "adjacent_or_same_pair_rate": (finite <= 1).mean(),
        "unreachable_count": int(np.isnan(distances).sum()),
    }


logits = where_transformer(
    batch["from_zone_indices"],
    batch["to_zone_indices"],
    batch["outage_type"],
    batch["time_interval_index"],
)


def collect_where_predictions(model, dataset, device):
    model.eval()
    rows = []
    with torch.no_grad():
        for sample in dataset:
            batch = sample_to_device(sample, device)
            logits = model(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            pred_pair = logits.argmax(dim=-1).squeeze(0).cpu().tolist()
            true_pair = sample["target"].cpu().tolist()
            rows.append(
                {
                    "true_from_zone": int(true_pair[0]),
                    "true_to_zone": int(true_pair[1]),
                    "pred_from_zone": int(pred_pair[0]),
                    "pred_to_zone": int(pred_pair[1]),
                    "exact_pair_match": sorted(true_pair) == sorted(pred_pair),
                }
            )
    return pd.DataFrame(rows)


outage_graph = ig.Graph.Read_Pickle(str(GRAPH_PATH))
zone_distance_lookup = build_zone_distance_lookup(EDGE_ZONE_PATH)
zone_ids = sorted(zone_distance_lookup)
rng = np.random.default_rng(RANDOM_STATE)

raw_graph_diameter = outage_graph.diameter(directed=False, unconn=True)
node_a, node_b = rng.choice(outage_graph.vcount(), size=2, replace=False)
random_node_distance = outage_graph.distances(
    source=[int(node_a)],
    target=[int(node_b)],
    mode="ALL",
)[0][0]

zone_graph_diameter = max(
    distance
    for source_distances in zone_distance_lookup.values()
    for distance in source_distances.values()
)
zone_a, zone_b = rng.choice(zone_ids, size=2, replace=False)
random_zone_distance = zone_distance_lookup[int(zone_a)][int(zone_b)]

checkpoint_path = Path(
    globals().get(
        "mean_pooling_ce_checkpoint_path",
        OUTPUT_DIR
        / "where_transformer"
        / "where_transformer_cross_entropy_mean_pooling_last.pt",
    )
)
if checkpoint_path.exists():
    try:
        checkpoint = torch.load(
            checkpoint_path, map_location=DEVICE, weights_only=False
        )
    except TypeError:
        checkpoint = torch.load(checkpoint_path, map_location=DEVICE)
    where_transformer.load_state_dict(checkpoint["model_state_dict"])
    print(f"Loaded model checkpoint from {checkpoint_path}")
else:
    print("No saved checkpoint found; evaluating the current in-memory model.")

prediction_df = collect_where_predictions(where_transformer, test_where_dataset, DEVICE)
pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in prediction_df.itertuples(index=False)
    ],
    dtype=float,
)

random_pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            tuple(
                prediction_df.iloc[i % len(prediction_df)][
                    ["true_from_zone", "true_to_zone"]
                ].to_numpy()
            ),
            rng.choice(zone_ids, size=2, replace=True),
            zone_distance_lookup,
        )
        for i in range(RANDOM_PAIR_BASELINE_SIZE)
    ],
    dtype=float,
)

model_summary = summarize_pair_distances(pair_distances)
random_summary = summarize_pair_distances(random_pair_distances)
model_summary["exact_pair_accuracy"] = prediction_df["exact_pair_match"].mean()
model_summary["mean_distance_vs_diameter"] = (
    model_summary["mean_distance"] / zone_graph_diameter
)
model_summary["mean_distance_reduction_vs_random"] = 1 - (
    model_summary["mean_distance"] / random_summary["mean_distance"]
)

summary_df = pd.DataFrame(
    [
        {"model": "Transformer", **model_summary},
        {"model": "Random zone-pair baseline", **random_summary},
    ]
)

print(f"Raw outage graph: {outage_graph.vcount()} nodes, {outage_graph.ecount()} edges")
print(f"Maximum raw graph node distance: {raw_graph_diameter}")
print(
    f"Random raw nodes {int(node_a)} -> {int(node_b)} distance: "
    f"{random_node_distance}"
)
print(f"Maximum zone graph distance: {zone_graph_diameter}")
print(f"Random zones {int(zone_a)} -> {int(zone_b)} distance: {random_zone_distance}")
print(
    "Average unordered zone-pair distance, model: "
    f"{model_summary['mean_distance']:.3f}"
)
print(
    "Average unordered zone-pair distance, random baseline: "
    f"{random_summary['mean_distance']:.3f}"
)
print(
    "Model mean unordered pair distance: "
    f"{model_summary['mean_distance']:.3f} / {zone_graph_diameter} "
    f"({model_summary['mean_distance_vs_diameter']:.1%} of zone diameter)"
)
print(
    "Distance reduction versus random zone-pair baseline: "
    f"{model_summary['mean_distance_reduction_vs_random']:.1%}"
)

display(summary_df.round(3))
display(prediction_df.head())

bins = np.arange(-0.5, zone_graph_diameter + 1.5, 1)
fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(
    pair_distances[np.isfinite(pair_distances)], bins=bins, alpha=0.7, label="Model"
)
ax.hist(
    random_pair_distances[np.isfinite(random_pair_distances)],
    bins=bins,
    histtype="step",
    linewidth=2,
    label="Random baseline",
)
ax.set_xlabel("Unordered zone-pair graph distance")
ax.set_ylabel("Count")
# ax.set_title("Where-model graph-distance error")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "where_graph_distance_error.pdf", dpi=300)
plt.show()
# Out:
# Loaded model checkpoint from model_outputs/where_transformer/where_transformer_cross_entropy_mean_pooling_last.pt
# Raw outage graph: 1082 nodes, 1462 edges
# Maximum raw graph node distance: 18
# Random raw nodes 96 -> 837 distance: 4
# Maximum zone graph distance: 4
# Random zones 10 -> 24 distance: 3
# Average unordered zone-pair distance, model: 1.547
# Average unordered zone-pair distance, random baseline: 1.795
# Model mean unordered pair distance: 1.547 / 4 (38.7% of zone diameter)
# Distance reduction versus random zone-pair baseline: 13.8%
#                        model  mean_distance  median_distance  p90_distance  \
# 0                Transformer          1.547              1.5           2.5
# 1  Random zone-pair baseline          1.795              2.0           2.5
#
#    same_zone_pair_rate  adjacent_or_same_pair_rate  unreachable_count  \
# 0                0.033                       0.343                  0
# 1                0.002                       0.161                  0
#
#    exact_pair_accuracy  mean_distance_vs_diameter  \
# 0                0.033                      0.387
# 1                  NaN                        NaN
#
#    mean_distance_reduction_vs_random
# 0                              0.138
# 1                                NaN
#    true_from_zone  true_to_zone  pred_from_zone  pred_to_zone  \
# 0               0             0               2             9
# 1               2             2               0            18
# 2               3             3               0             5
# 3              22            22               0            18
# 4              20            20               0             0
#
#    exact_pair_match
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# # SAP model

# %%
LEARNING_RATE = 3e-6
NUM_EPOCHS = 64
VIRTUAL_BATCH_SIZE = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def sample_to_device(sample, device):
    return {
        "from_zone_indices": sample["from_zone_indices"].unsqueeze(0).to(device),
        "to_zone_indices": sample["to_zone_indices"].unsqueeze(0).to(device),
        "outage_type": sample["outage_type"].unsqueeze(0).to(device),
        "time_interval_index": sample["time_interval_index"].unsqueeze(0).to(device),
        "target": sample["target"].unsqueeze(0).to(device),
    }


def unordered_zone_loss(logits, target):
    from_logits = logits[:, 0, :]
    to_logits = logits[:, 1, :]
    target_from = target[:, 0]
    target_to = target[:, 1]

    forward_loss = nn.functional.cross_entropy(
        from_logits,
        target_from,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_to,
    )
    swapped_loss = nn.functional.cross_entropy(
        from_logits,
        target_to,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_from,
    )
    return torch.minimum(forward_loss, swapped_loss).mean()


def unordered_zone_correct_count(logits, target):
    pred = logits.argmax(dim=-1)
    pred_sorted = torch.sort(pred, dim=1).values
    target_sorted = torch.sort(target, dim=1).values
    return (pred_sorted == target_sorted).all(dim=1).sum().item()


where_transformer_sap = WhereTransformerSAP(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
)
where_transformer_sap
where_transformer_sap.to(DEVICE)
optimizer = torch.optim.Adam(where_transformer_sap.parameters(), lr=LEARNING_RATE)

training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    where_transformer_sap.train()
    optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = where_transformer_sap(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = unordered_zone_loss(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            optimizer.step()
            optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        optimizer.step()
        optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    where_transformer_sap.eval()
    test_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = where_transformer_sap(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy,
    }
    training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test loss={test_loss:.6f}, test acc={test_accuracy:.4f}"
    )

MODEL_OUTPUT_DIR = OUTPUT_DIR / "where_transformer"
MODEL_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
sap_ce_checkpoint_path = (
    MODEL_OUTPUT_DIR / "where_transformer_cross_entropy_sap_last.pt"
)

torch.save(
    {
        "model_state_dict": where_transformer_sap.state_dict(),
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "training_history": training_history,
    },
    sap_ce_checkpoint_path,
)

print(f"Saved final cross-entropy SAP checkpoint to {sap_ce_checkpoint_path}")
# Out:
# Epoch 001 | train loss=6.576363, train acc=0.0000 | test loss=6.507865, test acc=0.0000
# Epoch 002 | train loss=6.545354, train acc=0.0000 | test loss=6.476362, test acc=0.0000
# Epoch 003 | train loss=6.506927, train acc=0.0000 | test loss=6.447395, test acc=0.0000
# Epoch 004 | train loss=6.463429, train acc=0.0000 | test loss=6.419928, test acc=0.0000
# Epoch 005 | train loss=6.423219, train acc=0.0000 | test loss=6.395232, test acc=0.0000
# Epoch 006 | train loss=6.383795, train acc=0.0000 | test loss=6.371514, test acc=0.0000
# Epoch 007 | train loss=6.354150, train acc=0.0000 | test loss=6.349058, test acc=0.0000
# Epoch 008 | train loss=6.318230, train acc=0.0000 | test loss=6.329117, test acc=0.0000
# Epoch 009 | train loss=6.283620, train acc=0.0045 | test loss=6.309098, test acc=0.0000
# Epoch 010 | train loss=6.246143, train acc=0.0059 | test loss=6.291713, test acc=0.0000
# Epoch 011 | train loss=6.231206, train acc=0.0059 | test loss=6.274842, test acc=0.0000
# Epoch 012 | train loss=6.202930, train acc=0.0015 | test loss=6.259288, test acc=0.0000
# Epoch 013 | train loss=6.187398, train acc=0.0074 | test loss=6.245240, test acc=0.0000
# Epoch 014 | train loss=6.147780, train acc=0.0074 | test loss=6.231755, test acc=0.0055
# Epoch 015 | train loss=6.138006, train acc=0.0089 | test loss=6.219210, test acc=0.0000
# Epoch 016 | train loss=6.110520, train acc=0.0119 | test loss=6.207815, test acc=0.0000
# Epoch 017 | train loss=6.098251, train acc=0.0163 | test loss=6.195827, test acc=0.0000
# Epoch 018 | train loss=6.063075, train acc=0.0178 | test loss=6.186242, test acc=0.0000
# Epoch 019 | train loss=6.050968, train acc=0.0223 | test loss=6.176921, test acc=0.0000
# Epoch 020 | train loss=6.024398, train acc=0.0237 | test loss=6.167554, test acc=0.0000
# Epoch 021 | train loss=6.017643, train acc=0.0193 | test loss=6.160073, test acc=0.0166
# Epoch 022 | train loss=5.992810, train acc=0.0267 | test loss=6.152126, test acc=0.0166
# Epoch 023 | train loss=5.995642, train acc=0.0252 | test loss=6.144100, test acc=0.0166
# Epoch 024 | train loss=5.954695, train acc=0.0326 | test loss=6.137746, test acc=0.0166
# Epoch 025 | train loss=5.957869, train acc=0.0312 | test loss=6.130913, test acc=0.0166
# Epoch 026 | train loss=5.949532, train acc=0.0282 | test loss=6.124856, test acc=0.0166
# Epoch 027 | train loss=5.927737, train acc=0.0356 | test loss=6.119018, test acc=0.0166
# Epoch 028 | train loss=5.925913, train acc=0.0252 | test loss=6.113801, test acc=0.0166
# Epoch 029 | train loss=5.901161, train acc=0.0326 | test loss=6.108710, test acc=0.0166
# Epoch 030 | train loss=5.886719, train acc=0.0415 | test loss=6.103996, test acc=0.0166
# Epoch 031 | train loss=5.871179, train acc=0.0326 | test loss=6.098569, test acc=0.0166
# Epoch 032 | train loss=5.868869, train acc=0.0445 | test loss=6.094286, test acc=0.0166
# Epoch 033 | train loss=5.860236, train acc=0.0490 | test loss=6.090853, test acc=0.0221
# Epoch 034 | train loss=5.846093, train acc=0.0519 | test loss=6.086808, test acc=0.0221
# Epoch 035 | train loss=5.836484, train acc=0.0490 | test loss=6.083049, test acc=0.0221
# Epoch 036 | train loss=5.828781, train acc=0.0564 | test loss=6.079699, test acc=0.0276
# Epoch 037 | train loss=5.824211, train acc=0.0534 | test loss=6.076437, test acc=0.0276
# Epoch 038 | train loss=5.806905, train acc=0.0564 | test loss=6.073023, test acc=0.0276
# Epoch 039 | train loss=5.802468, train acc=0.0593 | test loss=6.069620, test acc=0.0276
# Epoch 040 | train loss=5.800101, train acc=0.0638 | test loss=6.067045, test acc=0.0276
# Epoch 041 | train loss=5.784103, train acc=0.0564 | test loss=6.064146, test acc=0.0276
# Epoch 042 | train loss=5.778716, train acc=0.0712 | test loss=6.061168, test acc=0.0276
# Epoch 043 | train loss=5.771740, train acc=0.0682 | test loss=6.059867, test acc=0.0276
# Epoch 044 | train loss=5.772030, train acc=0.0682 | test loss=6.056987, test acc=0.0276
# Epoch 045 | train loss=5.752101, train acc=0.0697 | test loss=6.054403, test acc=0.0276
# Epoch 046 | train loss=5.754932, train acc=0.0682 | test loss=6.052300, test acc=0.0276
# Epoch 047 | train loss=5.756995, train acc=0.0742 | test loss=6.050445, test acc=0.0276
# Epoch 048 | train loss=5.740630, train acc=0.0712 | test loss=6.049145, test acc=0.0276
# Epoch 049 | train loss=5.733641, train acc=0.0682 | test loss=6.046413, test acc=0.0276
# Epoch 050 | train loss=5.730226, train acc=0.0786 | test loss=6.045031, test acc=0.0276
# Epoch 051 | train loss=5.724072, train acc=0.0816 | test loss=6.044287, test acc=0.0331
# Epoch 052 | train loss=5.717691, train acc=0.0742 | test loss=6.042243, test acc=0.0331
# Epoch 053 | train loss=5.719212, train acc=0.0786 | test loss=6.040968, test acc=0.0331
# Epoch 054 | train loss=5.701660, train acc=0.0831 | test loss=6.039056, test acc=0.0276
# Epoch 055 | train loss=5.697438, train acc=0.0801 | test loss=6.038400, test acc=0.0276
# Epoch 056 | train loss=5.680209, train acc=0.0905 | test loss=6.036898, test acc=0.0276
# Epoch 057 | train loss=5.691027, train acc=0.0786 | test loss=6.035558, test acc=0.0276
# Epoch 058 | train loss=5.693435, train acc=0.0861 | test loss=6.034974, test acc=0.0276
# Epoch 059 | train loss=5.677969, train acc=0.0846 | test loss=6.033930, test acc=0.0276
# Epoch 060 | train loss=5.679391, train acc=0.0905 | test loss=6.033002, test acc=0.0276
# Epoch 061 | train loss=5.685254, train acc=0.0816 | test loss=6.032191, test acc=0.0276
# Epoch 062 | train loss=5.678470, train acc=0.0831 | test loss=6.030624, test acc=0.0276
# Epoch 063 | train loss=5.660328, train acc=0.0831 | test loss=6.030099, test acc=0.0276
# Epoch 064 | train loss=5.660935, train acc=0.0727 | test loss=6.029770, test acc=0.0276
# Saved final cross-entropy SAP checkpoint to model_outputs/where_transformer/where_transformer_cross_entropy_sap_last.pt

# %% [markdown]
# # Adjacency Aware training

# %%
ADJACENCY_DISTANCE_WEIGHT = 2.0

edge_zone_df = pd.read_csv(EDGE_ZONE_PATH)
zone_edges = [
    (int(from_zone), int(to_zone))
    for from_zone, to_zone in zip(edge_zone_df["from_zone"], edge_zone_df["to_zone"])
    if 0 <= int(from_zone) < num_zones and 0 <= int(to_zone) < num_zones
]
zone_graph = ig.Graph(n=num_zones, edges=zone_edges, directed=False)
zone_graph.simplify(multiple=True, loops=True)

set_seed()
adjacency_where_transformer = WhereTransformer(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
)
adjacency_where_transformer.to(DEVICE)

adjacency_criterion = GraphDistanceUnorderedZoneLoss(
    zone_graph,
    num_zones=num_zones,
    distance_weight=ADJACENCY_DISTANCE_WEIGHT,
).to(DEVICE)
adjacency_optimizer = torch.optim.Adam(
    adjacency_where_transformer.parameters(),
    lr=LEARNING_RATE,
)

adjacency_training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    adjacency_where_transformer.train()
    adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = adjacency_where_transformer(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = adjacency_criterion(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            adjacency_optimizer.step()
            adjacency_optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        adjacency_optimizer.step()
        adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    adjacency_where_transformer.eval()
    test_loss_sum = 0.0
    test_cross_entropy_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = adjacency_where_transformer(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = adjacency_criterion(logits, batch["target"])
            cross_entropy_loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_cross_entropy_loss_sum += cross_entropy_loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_cross_entropy_loss = test_cross_entropy_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_cross_entropy_loss": test_cross_entropy_loss,
        "test_accuracy": test_accuracy,
    }
    adjacency_training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test adjacency loss={test_loss:.6f}, "
        f"test CE loss={test_cross_entropy_loss:.6f}, "
        f"test acc={test_accuracy:.4f}"
    )

mean_pooling_adjacency_checkpoint_path = (
    MODEL_OUTPUT_DIR / "where_transformer_adjacency_aware_mean_pooling_last.pt"
)

torch.save(
    {
        "model_state_dict": adjacency_where_transformer.state_dict(),
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "distance_weight": ADJACENCY_DISTANCE_WEIGHT,
        "training_history": adjacency_training_history,
    },
    mean_pooling_adjacency_checkpoint_path,
)

print(
    "Saved final adjacency-aware mean-pooling checkpoint to "
    f"{mean_pooling_adjacency_checkpoint_path}"
)
# Out:
# Epoch 001 | train loss=13.949769, train acc=0.0030 | test adjacency loss=13.887685, test CE loss=6.601306, test acc=0.0055
# Epoch 002 | train loss=13.856931, train acc=0.0030 | test adjacency loss=13.823283, test CE loss=6.569687, test acc=0.0166
# Epoch 003 | train loss=13.779218, train acc=0.0074 | test adjacency loss=13.761447, test CE loss=6.540357, test acc=0.0166
# Epoch 004 | train loss=13.694526, train acc=0.0104 | test adjacency loss=13.703737, test CE loss=6.513777, test acc=0.0166
# Epoch 005 | train loss=13.618333, train acc=0.0134 | test adjacency loss=13.648646, test CE loss=6.489421, test acc=0.0221
# Epoch 006 | train loss=13.556835, train acc=0.0148 | test adjacency loss=13.595646, test CE loss=6.466482, test acc=0.0166
# Epoch 007 | train loss=13.510683, train acc=0.0193 | test adjacency loss=13.545298, test CE loss=6.446471, test acc=0.0110
# Epoch 008 | train loss=13.422608, train acc=0.0252 | test adjacency loss=13.498672, test CE loss=6.429092, test acc=0.0055
# Epoch 009 | train loss=13.361194, train acc=0.0208 | test adjacency loss=13.453075, test CE loss=6.413445, test acc=0.0166
# Epoch 010 | train loss=13.312413, train acc=0.0415 | test adjacency loss=13.410112, test CE loss=6.399248, test acc=0.0221
# Epoch 011 | train loss=13.243232, train acc=0.0415 | test adjacency loss=13.368689, test CE loss=6.387104, test acc=0.0221
# Epoch 012 | train loss=13.198283, train acc=0.0386 | test adjacency loss=13.329131, test CE loss=6.377035, test acc=0.0276
# Epoch 013 | train loss=13.146926, train acc=0.0475 | test adjacency loss=13.291205, test CE loss=6.368953, test acc=0.0331
# Epoch 014 | train loss=13.094681, train acc=0.0475 | test adjacency loss=13.256786, test CE loss=6.363262, test acc=0.0387
# Epoch 015 | train loss=13.021432, train acc=0.0579 | test adjacency loss=13.222909, test CE loss=6.357619, test acc=0.0387
# Epoch 016 | train loss=12.980325, train acc=0.0668 | test adjacency loss=13.192269, test CE loss=6.355249, test acc=0.0387
# Epoch 017 | train loss=12.946830, train acc=0.0682 | test adjacency loss=13.161968, test CE loss=6.353562, test acc=0.0387
# Epoch 018 | train loss=12.909810, train acc=0.0697 | test adjacency loss=13.133945, test CE loss=6.353712, test acc=0.0387
# Epoch 019 | train loss=12.878135, train acc=0.0697 | test adjacency loss=13.107556, test CE loss=6.356178, test acc=0.0442
# Epoch 020 | train loss=12.837143, train acc=0.0772 | test adjacency loss=13.081967, test CE loss=6.358264, test acc=0.0442
# Epoch 021 | train loss=12.798341, train acc=0.0846 | test adjacency loss=13.060230, test CE loss=6.363945, test acc=0.0442
# Epoch 022 | train loss=12.748397, train acc=0.0831 | test adjacency loss=13.038242, test CE loss=6.368759, test acc=0.0442
# Epoch 023 | train loss=12.711214, train acc=0.0905 | test adjacency loss=13.018312, test CE loss=6.376053, test acc=0.0442
# Epoch 024 | train loss=12.688005, train acc=0.0964 | test adjacency loss=12.999673, test CE loss=6.381041, test acc=0.0497
# Epoch 025 | train loss=12.674093, train acc=0.0950 | test adjacency loss=12.982595, test CE loss=6.389015, test acc=0.0497
# Epoch 026 | train loss=12.658528, train acc=0.0964 | test adjacency loss=12.967175, test CE loss=6.395947, test acc=0.0552
# Epoch 027 | train loss=12.616011, train acc=0.0964 | test adjacency loss=12.952221, test CE loss=6.405248, test acc=0.0552
# Epoch 028 | train loss=12.595642, train acc=0.1039 | test adjacency loss=12.939169, test CE loss=6.414072, test acc=0.0552
# Epoch 029 | train loss=12.553556, train acc=0.1009 | test adjacency loss=12.926470, test CE loss=6.422270, test acc=0.0552
# Epoch 030 | train loss=12.542126, train acc=0.1009 | test adjacency loss=12.915593, test CE loss=6.429446, test acc=0.0552
# Epoch 031 | train loss=12.519407, train acc=0.1053 | test adjacency loss=12.904407, test CE loss=6.439000, test acc=0.0552
# Epoch 032 | train loss=12.497237, train acc=0.1039 | test adjacency loss=12.894818, test CE loss=6.446631, test acc=0.0552
# Epoch 033 | train loss=12.492700, train acc=0.0979 | test adjacency loss=12.886813, test CE loss=6.454156, test acc=0.0552
# Epoch 034 | train loss=12.455287, train acc=0.1053 | test adjacency loss=12.877767, test CE loss=6.461355, test acc=0.0552
# Epoch 035 | train loss=12.434556, train acc=0.1024 | test adjacency loss=12.869061, test CE loss=6.467288, test acc=0.0552
# Epoch 036 | train loss=12.427218, train acc=0.1024 | test adjacency loss=12.861809, test CE loss=6.472860, test acc=0.0552
# Epoch 037 | train loss=12.407501, train acc=0.1024 | test adjacency loss=12.854246, test CE loss=6.477466, test acc=0.0552
# Epoch 038 | train loss=12.389622, train acc=0.1024 | test adjacency loss=12.848728, test CE loss=6.484805, test acc=0.0552
# Epoch 039 | train loss=12.368320, train acc=0.1039 | test adjacency loss=12.843021, test CE loss=6.488608, test acc=0.0552
# Epoch 040 | train loss=12.365270, train acc=0.1053 | test adjacency loss=12.837115, test CE loss=6.493448, test acc=0.0552
# Epoch 041 | train loss=12.362708, train acc=0.1024 | test adjacency loss=12.830520, test CE loss=6.497727, test acc=0.0552
# Epoch 042 | train loss=12.346481, train acc=0.1024 | test adjacency loss=12.824935, test CE loss=6.498075, test acc=0.0552
# Epoch 043 | train loss=12.345046, train acc=0.1053 | test adjacency loss=12.820156, test CE loss=6.501711, test acc=0.0552
# Epoch 044 | train loss=12.326371, train acc=0.1024 | test adjacency loss=12.814790, test CE loss=6.502993, test acc=0.0552
# Epoch 045 | train loss=12.308590, train acc=0.1009 | test adjacency loss=12.810014, test CE loss=6.504160, test acc=0.0552
# Epoch 046 | train loss=12.305832, train acc=0.1009 | test adjacency loss=12.805250, test CE loss=6.507932, test acc=0.0552
# Epoch 047 | train loss=12.294551, train acc=0.1024 | test adjacency loss=12.800312, test CE loss=6.506860, test acc=0.0552
# Epoch 048 | train loss=12.306062, train acc=0.1053 | test adjacency loss=12.796392, test CE loss=6.509715, test acc=0.0552
# Epoch 049 | train loss=12.277791, train acc=0.1009 | test adjacency loss=12.791680, test CE loss=6.509767, test acc=0.0552
# Epoch 050 | train loss=12.272788, train acc=0.1039 | test adjacency loss=12.787539, test CE loss=6.511024, test acc=0.0552
# Epoch 051 | train loss=12.267307, train acc=0.1039 | test adjacency loss=12.783916, test CE loss=6.511826, test acc=0.0608
# Epoch 052 | train loss=12.242619, train acc=0.1039 | test adjacency loss=12.779758, test CE loss=6.510291, test acc=0.0552
# Epoch 053 | train loss=12.261972, train acc=0.1009 | test adjacency loss=12.775599, test CE loss=6.508554, test acc=0.0552
# Epoch 054 | train loss=12.243331, train acc=0.1024 | test adjacency loss=12.771483, test CE loss=6.507566, test acc=0.0608
# Epoch 055 | train loss=12.231440, train acc=0.1039 | test adjacency loss=12.768724, test CE loss=6.509315, test acc=0.0608
# Epoch 056 | train loss=12.217719, train acc=0.1068 | test adjacency loss=12.765026, test CE loss=6.509415, test acc=0.0608
# Epoch 057 | train loss=12.220224, train acc=0.1039 | test adjacency loss=12.760751, test CE loss=6.506179, test acc=0.0608
# Epoch 058 | train loss=12.219897, train acc=0.1039 | test adjacency loss=12.757205, test CE loss=6.505023, test acc=0.0608
# Epoch 059 | train loss=12.190832, train acc=0.1053 | test adjacency loss=12.754325, test CE loss=6.507527, test acc=0.0608
# Epoch 060 | train loss=12.189789, train acc=0.1039 | test adjacency loss=12.750462, test CE loss=6.502897, test acc=0.0608
# Epoch 061 | train loss=12.193936, train acc=0.1039 | test adjacency loss=12.747169, test CE loss=6.501465, test acc=0.0608
# Epoch 062 | train loss=12.181806, train acc=0.1024 | test adjacency loss=12.743635, test CE loss=6.498950, test acc=0.0608
# Epoch 063 | train loss=12.179258, train acc=0.1053 | test adjacency loss=12.741073, test CE loss=6.499812, test acc=0.0608
# Epoch 064 | train loss=12.178119, train acc=0.0994 | test adjacency loss=12.737996, test CE loss=6.497146, test acc=0.0608
# Saved final adjacency-aware mean-pooling checkpoint to model_outputs/where_transformer/where_transformer_adjacency_aware_mean_pooling_last.pt

# %% [markdown]
# # adjacency aware + SAP

# %%
ADJACENCY_DISTANCE_WEIGHT = 2.0

edge_zone_df = pd.read_csv(EDGE_ZONE_PATH)
zone_edges = [
    (int(from_zone), int(to_zone))
    for from_zone, to_zone in zip(edge_zone_df["from_zone"], edge_zone_df["to_zone"])
    if 0 <= int(from_zone) < num_zones and 0 <= int(to_zone) < num_zones
]
zone_graph = ig.Graph(n=num_zones, edges=zone_edges, directed=False)
zone_graph.simplify(multiple=True, loops=True)

set_seed()
adjacency_where_transformer_sap = WhereTransformerSAP(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
)
adjacency_where_transformer_sap.to(DEVICE)

adjacency_criterion = GraphDistanceUnorderedZoneLoss(
    zone_graph,
    num_zones=num_zones,
    distance_weight=ADJACENCY_DISTANCE_WEIGHT,
).to(DEVICE)
adjacency_optimizer = torch.optim.Adam(
    adjacency_where_transformer_sap.parameters(),
    lr=LEARNING_RATE,
)

adjacency_training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    adjacency_where_transformer_sap.train()
    adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = adjacency_where_transformer_sap(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = adjacency_criterion(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            adjacency_optimizer.step()
            adjacency_optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        adjacency_optimizer.step()
        adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    adjacency_where_transformer_sap.eval()
    test_loss_sum = 0.0
    test_cross_entropy_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = adjacency_where_transformer_sap(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = adjacency_criterion(logits, batch["target"])
            cross_entropy_loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_cross_entropy_loss_sum += cross_entropy_loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_cross_entropy_loss = test_cross_entropy_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_cross_entropy_loss": test_cross_entropy_loss,
        "test_accuracy": test_accuracy,
    }
    adjacency_training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test adjacency loss={test_loss:.6f}, "
        f"test CE loss={test_cross_entropy_loss:.6f}, "
        f"test acc={test_accuracy:.4f}"
    )

sap_adjacency_checkpoint_path = (
    MODEL_OUTPUT_DIR / "where_transformer_adjacency_aware_sap_last.pt"
)

torch.save(
    {
        "model_state_dict": adjacency_where_transformer_sap.state_dict(),
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "distance_weight": ADJACENCY_DISTANCE_WEIGHT,
        "training_history": adjacency_training_history,
    },
    sap_adjacency_checkpoint_path,
)

print(
    "Saved final adjacency-aware SAP checkpoint to " f"{sap_adjacency_checkpoint_path}"
)
# Out:
# Epoch 001 | train loss=14.302742, train acc=0.0030 | test adjacency loss=14.123103, test CE loss=6.728531, test acc=0.0000
# Epoch 002 | train loss=14.215874, train acc=0.0030 | test adjacency loss=14.055066, test CE loss=6.691052, test acc=0.0000
# Epoch 003 | train loss=14.124715, train acc=0.0030 | test adjacency loss=13.989466, test CE loss=6.654187, test acc=0.0000
# Epoch 004 | train loss=14.066157, train acc=0.0030 | test adjacency loss=13.925995, test CE loss=6.619121, test acc=0.0000
# Epoch 005 | train loss=13.982134, train acc=0.0030 | test adjacency loss=13.866050, test CE loss=6.586439, test acc=0.0000
# Epoch 006 | train loss=13.903243, train acc=0.0089 | test adjacency loss=13.809829, test CE loss=6.555966, test acc=0.0000
# Epoch 007 | train loss=13.856325, train acc=0.0059 | test adjacency loss=13.755341, test CE loss=6.527310, test acc=0.0000
# Epoch 008 | train loss=13.763441, train acc=0.0074 | test adjacency loss=13.702235, test CE loss=6.499593, test acc=0.0000
# Epoch 009 | train loss=13.705666, train acc=0.0059 | test adjacency loss=13.651461, test CE loss=6.473520, test acc=0.0000
# Epoch 010 | train loss=13.635782, train acc=0.0059 | test adjacency loss=13.604799, test CE loss=6.450801, test acc=0.0000
# Epoch 011 | train loss=13.582365, train acc=0.0059 | test adjacency loss=13.559014, test CE loss=6.428909, test acc=0.0000
# Epoch 012 | train loss=13.520719, train acc=0.0074 | test adjacency loss=13.515610, test CE loss=6.408892, test acc=0.0000
# Epoch 013 | train loss=13.455693, train acc=0.0089 | test adjacency loss=13.472831, test CE loss=6.389268, test acc=0.0000
# Epoch 014 | train loss=13.402734, train acc=0.0074 | test adjacency loss=13.432573, test CE loss=6.372575, test acc=0.0000
# Epoch 015 | train loss=13.354416, train acc=0.0045 | test adjacency loss=13.394033, test CE loss=6.357251, test acc=0.0055
# Epoch 016 | train loss=13.297179, train acc=0.0074 | test adjacency loss=13.356099, test CE loss=6.342664, test acc=0.0055
# Epoch 017 | train loss=13.241828, train acc=0.0104 | test adjacency loss=13.318735, test CE loss=6.329381, test acc=0.0055
# Epoch 018 | train loss=13.189597, train acc=0.0148 | test adjacency loss=13.284759, test CE loss=6.318411, test acc=0.0055
# Epoch 019 | train loss=13.158014, train acc=0.0134 | test adjacency loss=13.251763, test CE loss=6.309560, test acc=0.0166
# Epoch 020 | train loss=13.100114, train acc=0.0119 | test adjacency loss=13.219858, test CE loss=6.301548, test acc=0.0166
# Epoch 021 | train loss=13.045899, train acc=0.0119 | test adjacency loss=13.188975, test CE loss=6.294542, test acc=0.0166
# Epoch 022 | train loss=13.001676, train acc=0.0134 | test adjacency loss=13.161377, test CE loss=6.289941, test acc=0.0166
# Epoch 023 | train loss=12.967117, train acc=0.0148 | test adjacency loss=13.133556, test CE loss=6.286731, test acc=0.0221
# Epoch 024 | train loss=12.918236, train acc=0.0237 | test adjacency loss=13.108021, test CE loss=6.285828, test acc=0.0221
# Epoch 025 | train loss=12.887189, train acc=0.0267 | test adjacency loss=13.082987, test CE loss=6.285661, test acc=0.0221
# Epoch 026 | train loss=12.842624, train acc=0.0341 | test adjacency loss=13.058788, test CE loss=6.285783, test acc=0.0221
# Epoch 027 | train loss=12.816406, train acc=0.0371 | test adjacency loss=13.038811, test CE loss=6.289886, test acc=0.0276
# Epoch 028 | train loss=12.768272, train acc=0.0460 | test adjacency loss=13.018649, test CE loss=6.293236, test acc=0.0276
# Epoch 029 | train loss=12.740690, train acc=0.0445 | test adjacency loss=12.998869, test CE loss=6.297893, test acc=0.0387
# Epoch 030 | train loss=12.710828, train acc=0.0579 | test adjacency loss=12.980413, test CE loss=6.304277, test acc=0.0442
# Epoch 031 | train loss=12.672756, train acc=0.0623 | test adjacency loss=12.963418, test CE loss=6.311172, test acc=0.0497
# Epoch 032 | train loss=12.637362, train acc=0.0742 | test adjacency loss=12.949042, test CE loss=6.319754, test acc=0.0497
# Epoch 033 | train loss=12.608625, train acc=0.0861 | test adjacency loss=12.934735, test CE loss=6.326493, test acc=0.0497
# Epoch 034 | train loss=12.587083, train acc=0.0935 | test adjacency loss=12.921649, test CE loss=6.337372, test acc=0.0497
# Epoch 035 | train loss=12.568964, train acc=0.0920 | test adjacency loss=12.909517, test CE loss=6.345766, test acc=0.0497
# Epoch 036 | train loss=12.548617, train acc=0.0950 | test adjacency loss=12.897133, test CE loss=6.356292, test acc=0.0497
# Epoch 037 | train loss=12.540192, train acc=0.0920 | test adjacency loss=12.886576, test CE loss=6.364875, test acc=0.0497
# Epoch 038 | train loss=12.497438, train acc=0.0950 | test adjacency loss=12.877209, test CE loss=6.373645, test acc=0.0552
# Epoch 039 | train loss=12.484310, train acc=0.1009 | test adjacency loss=12.867613, test CE loss=6.383749, test acc=0.0552
# Epoch 040 | train loss=12.471768, train acc=0.0964 | test adjacency loss=12.859415, test CE loss=6.394682, test acc=0.0552
# Epoch 041 | train loss=12.439047, train acc=0.1039 | test adjacency loss=12.851064, test CE loss=6.402244, test acc=0.0552
# Epoch 042 | train loss=12.432750, train acc=0.1024 | test adjacency loss=12.843457, test CE loss=6.411040, test acc=0.0552
# Epoch 043 | train loss=12.404169, train acc=0.1053 | test adjacency loss=12.837357, test CE loss=6.419371, test acc=0.0608
# Epoch 044 | train loss=12.391192, train acc=0.1068 | test adjacency loss=12.830599, test CE loss=6.427193, test acc=0.0608
# Epoch 045 | train loss=12.366529, train acc=0.1053 | test adjacency loss=12.827040, test CE loss=6.437489, test acc=0.0608
# Epoch 046 | train loss=12.383021, train acc=0.1039 | test adjacency loss=12.820311, test CE loss=6.443640, test acc=0.0608
# Epoch 047 | train loss=12.349222, train acc=0.1053 | test adjacency loss=12.815186, test CE loss=6.450392, test acc=0.0608
# Epoch 048 | train loss=12.344510, train acc=0.1068 | test adjacency loss=12.811109, test CE loss=6.460688, test acc=0.0608
# Epoch 049 | train loss=12.334998, train acc=0.1068 | test adjacency loss=12.805114, test CE loss=6.463442, test acc=0.0608
# Epoch 050 | train loss=12.320023, train acc=0.1068 | test adjacency loss=12.801516, test CE loss=6.472183, test acc=0.0608
# Epoch 051 | train loss=12.294417, train acc=0.1068 | test adjacency loss=12.797319, test CE loss=6.475070, test acc=0.0608
# Epoch 052 | train loss=12.294772, train acc=0.1053 | test adjacency loss=12.793133, test CE loss=6.481717, test acc=0.0608
# Epoch 053 | train loss=12.290021, train acc=0.1068 | test adjacency loss=12.790546, test CE loss=6.489024, test acc=0.0608
# Epoch 054 | train loss=12.271321, train acc=0.1068 | test adjacency loss=12.786495, test CE loss=6.492255, test acc=0.0608
# Epoch 055 | train loss=12.270574, train acc=0.1053 | test adjacency loss=12.783220, test CE loss=6.494612, test acc=0.0608
# Epoch 056 | train loss=12.261136, train acc=0.1068 | test adjacency loss=12.781170, test CE loss=6.502581, test acc=0.0608
# Epoch 057 | train loss=12.248780, train acc=0.1068 | test adjacency loss=12.777882, test CE loss=6.503504, test acc=0.0608
# Epoch 058 | train loss=12.219901, train acc=0.1039 | test adjacency loss=12.773953, test CE loss=6.504125, test acc=0.0608
# Epoch 059 | train loss=12.233079, train acc=0.1068 | test adjacency loss=12.770572, test CE loss=6.507513, test acc=0.0608
# Epoch 060 | train loss=12.208214, train acc=0.1068 | test adjacency loss=12.768341, test CE loss=6.509568, test acc=0.0608
# Epoch 061 | train loss=12.201697, train acc=0.1068 | test adjacency loss=12.765131, test CE loss=6.511328, test acc=0.0608
# Epoch 062 | train loss=12.211426, train acc=0.1068 | test adjacency loss=12.764754, test CE loss=6.517621, test acc=0.0608
# Epoch 063 | train loss=12.192478, train acc=0.1053 | test adjacency loss=12.762500, test CE loss=6.518234, test acc=0.0608
# Epoch 064 | train loss=12.186286, train acc=0.1068 | test adjacency loss=12.760639, test CE loss=6.520832, test acc=0.0608
# Saved final adjacency-aware SAP checkpoint to model_outputs/where_transformer/where_transformer_adjacency_aware_sap_last.pt

# %%
baseline_prediction_df = collect_where_predictions(
    where_transformer,
    test_where_dataset,
    DEVICE,
)

baseline_sap_df = collect_where_predictions(
    where_transformer_sap,
    test_where_dataset,
    DEVICE,
)

adjacency_prediction_df = collect_where_predictions(
    adjacency_where_transformer,
    test_where_dataset,
    DEVICE,
)

adjacency_prediction_sap_df = collect_where_predictions(
    adjacency_where_transformer_sap,
    test_where_dataset,
    DEVICE,
)


baseline_pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in baseline_prediction_df.itertuples(index=False)
    ],
    dtype=float,
)
baseline_pair_distances_sap = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in baseline_sap_df.itertuples(index=False)
    ],
    dtype=float,
)
adjacency_pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in adjacency_prediction_df.itertuples(index=False)
    ],
    dtype=float,
)
adjacency_pair_distances_sap = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in adjacency_prediction_sap_df.itertuples(index=False)
    ],
    dtype=float,
)


baseline_summary = summarize_pair_distances(baseline_pair_distances)
baseline_summary["exact_pair_accuracy"] = baseline_prediction_df[
    "exact_pair_match"
].mean()

baseline_summary_sap = summarize_pair_distances(baseline_pair_distances_sap)
baseline_summary_sap["exact_pair_accuracy"] = baseline_sap_df["exact_pair_match"].mean()

adjacency_summary = summarize_pair_distances(adjacency_pair_distances)
adjacency_summary["exact_pair_accuracy"] = adjacency_prediction_df[
    "exact_pair_match"
].mean()
adjacency_summary["mean_distance_reduction_vs_cross_entropy"] = 1 - (
    adjacency_summary["mean_distance"] / baseline_summary["mean_distance"]
)

adjacency_summary_sap = summarize_pair_distances(adjacency_pair_distances_sap)
adjacency_summary_sap["exact_pair_accuracy"] = adjacency_prediction_sap_df[
    "exact_pair_match"
].mean()
adjacency_summary_sap["mean_distance_reduction_vs_cross_entropy"] = 1 - (
    adjacency_summary_sap["mean_distance"] / baseline_summary_sap["mean_distance"]
)

adjacency_comparison_df = pd.DataFrame(
    [
        {"model": "Cross entropy", **baseline_summary},
        {"model": "Cross entropy (SAP)", **baseline_summary_sap},
        {"model": "Adjacency-aware", **adjacency_summary},
        {"model": "Adjacency-aware (SAP)", **adjacency_summary_sap},
    ]
)

display(adjacency_comparison_df.round(3))
print(
    "Adjacency-aware mean unordered pair distance reduction vs cross entropy: "
    f"{adjacency_summary['mean_distance_reduction_vs_cross_entropy']:.1%}"
)
print(
    "Adjacency-aware (SAP) mean unordered pair distance reduction vs cross entropy: "
    f"{adjacency_summary_sap['mean_distance_reduction_vs_cross_entropy']:.1%}"
)

bins = np.arange(-0.5, zone_graph_diameter + 1.5, 1)
bin_centers = (bins[:-1] + bins[1:]) / 2
bar_width = 0.2
baseline_counts, _ = np.histogram(
    baseline_pair_distances[np.isfinite(baseline_pair_distances)], bins=bins
)
baseline_sap_counts, _ = np.histogram(
    baseline_pair_distances_sap[np.isfinite(baseline_pair_distances_sap)], bins=bins
)
adjacency_counts, _ = np.histogram(
    adjacency_pair_distances[np.isfinite(adjacency_pair_distances)], bins=bins
)
adjacency_sap_counts, _ = np.histogram(
    adjacency_pair_distances_sap[np.isfinite(adjacency_pair_distances_sap)], bins=bins
)
baseline_percentages = 100 * baseline_counts / baseline_counts.sum()
baseline_sap_percentages = 100 * baseline_sap_counts / baseline_sap_counts.sum()
adjacency_percentages = 100 * adjacency_counts / adjacency_counts.sum()
adjacency_sap_percentages = 100 * adjacency_sap_counts / adjacency_sap_counts.sum()

fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(
    bin_centers - 1.5 * bar_width,
    baseline_percentages,
    width=bar_width,
    label="Cross entropy",
    align="center",
)
ax.bar(
    bin_centers - 0.5 * bar_width,
    baseline_sap_percentages,
    width=bar_width,
    label="Cross entropy (SAP)",
    align="center",
)
ax.bar(
    bin_centers + 0.5 * bar_width,
    adjacency_percentages,
    width=bar_width,
    label="Adjacency-aware",
    align="center",
)
ax.bar(
    bin_centers + 1.5 * bar_width,
    adjacency_sap_percentages,
    width=bar_width,
    label="Adjacency-aware (SAP)",
    align="center",
)
ax.set_xticks(bin_centers)
ax.set_xlabel("Unordered zone-pair graph distance")
ax.set_ylabel("Percentage (%)")
# ax.set_title("Cross-entropy vs adjacency-aware graph-distance error")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(
    OUTPUT_DIR / "where_cross_entropy_vs_adjacency_graph_distance_error.pdf",
    dpi=300,
)
plt.show()
# Out:
#                    model  mean_distance  median_distance  p90_distance  \
# 0          Cross entropy          1.547              1.5           2.5
# 1    Cross entropy (SAP)          1.522              1.5           2.5
# 2        Adjacency-aware          1.273              1.0           2.0
# 3  Adjacency-aware (SAP)          1.260              1.0           2.0
#
#    same_zone_pair_rate  adjacent_or_same_pair_rate  unreachable_count  \
# 0                0.033                       0.343                  0
# 1                0.028                       0.376                  0
# 2                0.061                       0.575                  0
# 3                0.061                       0.608                  0
#
#    exact_pair_accuracy  mean_distance_reduction_vs_cross_entropy
# 0                0.033                                       NaN
# 1                0.028                                       NaN
# 2                0.061                                     0.177
# 3                0.061                                     0.172
# Adjacency-aware mean unordered pair distance reduction vs cross entropy: 17.7%
# Adjacency-aware (SAP) mean unordered pair distance reduction vs cross entropy: 17.2%

# %% [markdown]
# # paper plot

# %%
paper_bar_width = 0.36

fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(
    bin_centers - paper_bar_width / 2,
    baseline_percentages,
    width=paper_bar_width,
    label="Cross entropy",
    align="center",
)
ax.bar(
    bin_centers + paper_bar_width / 2,
    adjacency_percentages,
    width=paper_bar_width,
    label="Adjacency-aware",
    align="center",
)
ax.set_xticks(bin_centers)
ax.set_xlabel("Unordered zone-pair graph distance")
ax.set_ylabel("Percentage (%)")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(
    OUTPUT_DIR / "where_cross_entropy_vs_adjacency_graph_distance_error_paper.pdf",
    dpi=300,
)
plt.show()
