# %%
import random
from pathlib import Path

import numpy as np
import torch

DATA_DIR = Path("output")

OUTPUT_DIR = Path("model_outputs")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

RANDOM_STATE = 42


def set_seed(seed=RANDOM_STATE):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True, warn_only=True)


set_seed()

# %%
import json

WINDOW_SELECTION_PATH = OUTPUT_DIR / "xgboost_when" / "selected_window.json"
EXPECTED_WINDOW_HOURS = 0.5
if not WINDOW_SELECTION_PATH.exists():
    raise FileNotFoundError(
        f"Missing window-selection manifest: {WINDOW_SELECTION_PATH}. "
        "Run BPA notebook 9 before this notebook."
    )

with WINDOW_SELECTION_PATH.open(encoding="utf-8") as file:
    window_selection = json.load(file)
if not isinstance(window_selection, dict):
    raise TypeError(f"{WINDOW_SELECTION_PATH} must contain a JSON object.")

required_selection_keys = {
    "selected_window_hours",
    "selection_metric",
    "selection_metric_value",
    "selected_dataset_path",
    "window_metrics_path",
    "selection_source",
}
missing_selection_keys = required_selection_keys - set(window_selection)
if missing_selection_keys:
    raise ValueError(
        f"{WINDOW_SELECTION_PATH} is missing keys: " f"{sorted(missing_selection_keys)}"
    )
if window_selection["selection_metric"] != "validation_mae_seconds":
    raise ValueError(
        "Expected selection_metric='validation_mae_seconds', found "
        f"{window_selection['selection_metric']!r}."
    )
if window_selection["selection_source"] != "stage_1_five_fold_cross_validation":
    raise ValueError(
        "Unexpected selection_source: " f"{window_selection['selection_source']!r}."
    )

try:
    WINDOW_HOURS = float(window_selection["selected_window_hours"])
    selection_metric_value = float(window_selection["selection_metric_value"])
except (TypeError, ValueError) as error:
    raise ValueError(
        "selected_window_hours and selection_metric_value must be numeric."
    ) from error
if (
    not np.isfinite(WINDOW_HOURS)
    or WINDOW_HOURS <= 0
    or not np.isfinite(selection_metric_value)
    or selection_metric_value < 0
):
    raise ValueError(
        "selected_window_hours must be positive and finite, and the MAE "
        "must be finite and non-negative."
    )
if not np.isclose(WINDOW_HOURS, EXPECTED_WINDOW_HOURS):
    raise ValueError(
        f"Expected the BPA optimal window to be {EXPECTED_WINDOW_HOURS:g}h, "
        f"but the selection manifest specifies {WINDOW_HOURS:g}h. "
        "Rerun BPA notebook 9 and verify its five-fold validation results."
    )

WINDOW_LABEL = f"{WINDOW_HOURS:g}h"
RUN_TAG = f"winsize{WINDOW_LABEL}"
selected_when_path = Path(window_selection["selected_dataset_path"])
expected_when_name = f"dataset_{RUN_TAG}_when.csv"
expected_when_path = DATA_DIR / expected_when_name
if selected_when_path.name != expected_when_name:
    raise ValueError(
        f"Manifest window/path mismatch: selected {WINDOW_LABEL}, but "
        f"selected_dataset_path is {selected_when_path}."
    )
if selected_when_path.resolve() != expected_when_path.resolve():
    raise ValueError(
        f"selected_dataset_path must resolve to {expected_when_path}, found "
        f"{selected_when_path}."
    )
if not selected_when_path.exists():
    raise FileNotFoundError(
        f"Selected WHEN dataset does not exist: {selected_when_path}"
    )

window_metrics_path = Path(window_selection["window_metrics_path"])
if not window_metrics_path.exists():
    raise FileNotFoundError(f"Selection metrics do not exist: {window_metrics_path}")

dataset_path = DATA_DIR / f"dataset_{RUN_TAG}_where.csv"
if not dataset_path.exists():
    raise FileNotFoundError(
        f"Missing WHERE dataset matching the selected window: {dataset_path}"
    )

MODEL_OUTPUT_DIR = OUTPUT_DIR / "where_transformer" / RUN_TAG
MODEL_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(
    f"Selected {WINDOW_LABEL} from {WINDOW_SELECTION_PATH} "
    f"({window_selection['selection_metric']}={selection_metric_value:.3f})."
)
print(f"Using WHERE dataset: {dataset_path}")
print(f"Writing artifacts to: {MODEL_OUTPUT_DIR}")
# Out:
# Selected 0.5h from model_outputs/xgboost_when/selected_window.json (validation_mae_seconds=364.524).
# Using WHERE dataset: output/dataset_winsize0.5h_where.csv
# Writing artifacts to: model_outputs/where_transformer/winsize0.5h

# %%
import json

import pandas as pd

where_df = pd.read_csv(
    dataset_path,
    dtype={"fold_id": "int64"},
    converters={
        "window": json.loads,
        "label": json.loads,
    },
)
where_df = where_df.loc[~where_df["is_bg"]].drop(columns="is_bg")

where_df.head()
# Out:
#    fold_id                                             window  \
# 1        4  [{'from_zone_index': 5, 'to_zone_index': 5, 'o...
# 2        4  [{'from_zone_index': 5, 'to_zone_index': 1, 'o...
# 3        1  [{'from_zone_index': 18, 'to_zone_index': 0, '...
# 4        4  [{'from_zone_index': 7, 'to_zone_index': 7, 'o...
# 6        4  [{'from_zone_index': 5, 'to_zone_index': 5, 'o...
#
#                                         label
# 1  {'from_zone_index': 0, 'to_zone_index': 0}
# 2  {'from_zone_index': 2, 'to_zone_index': 2}
# 3  {'from_zone_index': 7, 'to_zone_index': 7}
# 4  {'from_zone_index': 9, 'to_zone_index': 9}
# 6  {'from_zone_index': 9, 'to_zone_index': 9}

# %%
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset

OUTAGE_TYPE_TO_ID = {
    "Planned": 0,
    "Auto": 1,
}


class WhereOutageDataset(Dataset):
    def __init__(self, df):
        self.df = df.reset_index(drop=True)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        window = row["window"]
        label = row["label"]

        outage_type = torch.tensor(
            [OUTAGE_TYPE_TO_ID[event["outage_type"]] for event in window],
            dtype=torch.long,
        )
        from_zone_indices = torch.tensor(
            [event["from_zone_index"] for event in window],
            dtype=torch.long,
        )
        to_zone_indices = torch.tensor(
            [event["to_zone_index"] for event in window],
            dtype=torch.long,
        )
        time_interval_index = torch.tensor(
            [event["time_interval_index"] for event in window],
            dtype=torch.long,
        )
        target = torch.tensor(
            [label["from_zone_index"], label["to_zone_index"]],
            dtype=torch.long,
        )

        return {
            "outage_type": outage_type,
            "from_zone_indices": from_zone_indices,
            "to_zone_indices": to_zone_indices,
            "time_interval_index": time_interval_index,
            "target": target,
        }


TRAIN_FOLDS = [0, 1, 2, 3, 4]
TEST_FOLDS = [-1]

train_where_dataset = WhereOutageDataset(
    where_df[where_df["fold_id"].isin(TRAIN_FOLDS)]
)
test_where_dataset = WhereOutageDataset(where_df[where_df["fold_id"].isin(TEST_FOLDS)])

# %%
for i, sample_dict in enumerate(train_where_dataset):
    print(sample_dict)
    if i == 10:
        break
# Out:
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([0, 0])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([1]), 'time_interval_index': tensor([0]), 'target': tensor([2, 2])}
# {'outage_type': tensor([1, 1, 0]), 'from_zone_indices': tensor([18,  1,  5]), 'to_zone_indices': tensor([0, 1, 5]), 'time_interval_index': tensor([0, 0, 0]), 'target': tensor([7, 7])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([7]), 'to_zone_indices': tensor([7]), 'time_interval_index': tensor([0]), 'target': tensor([9, 9])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([9, 9])}
# {'outage_type': tensor([1, 1, 1, 0]), 'from_zone_indices': tensor([5, 5, 5, 7]), 'to_zone_indices': tensor([5, 5, 5, 7]), 'time_interval_index': tensor([1, 1, 1, 0]), 'target': tensor([5, 5])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([5, 5])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([5, 9])}
# {'outage_type': tensor([0, 0, 0, 0]), 'from_zone_indices': tensor([5, 5, 5, 5]), 'to_zone_indices': tensor([5, 5, 5, 5]), 'time_interval_index': tensor([1, 1, 0, 0]), 'target': tensor([5, 5])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([3]), 'to_zone_indices': tensor([3]), 'time_interval_index': tensor([0]), 'target': tensor([11, 11])}
# {'outage_type': tensor([0]), 'from_zone_indices': tensor([5]), 'to_zone_indices': tensor([5]), 'time_interval_index': tensor([0]), 'target': tensor([6, 6])}

# %%
observed_time_interval_indices = sorted(
    {
        int(event["time_interval_index"])
        for window in where_df["window"]
        for event in window
    }
)
if not observed_time_interval_indices:
    raise ValueError(
        f"The selected {WINDOW_LABEL} WHERE dataset contains no interval indices."
    )

NUM_TIME_INTERVALS = observed_time_interval_indices[-1] + 1
if observed_time_interval_indices != list(range(NUM_TIME_INTERVALS)):
    raise ValueError(
        "Time interval indices must be contiguous and zero-based; found "
        f"{observed_time_interval_indices}."
    )

train_time_interval_indices = {
    int(event["time_interval_index"])
    for window in where_df.loc[where_df["fold_id"].isin(TRAIN_FOLDS), "window"]
    for event in window
}
test_time_interval_indices = {
    int(event["time_interval_index"])
    for window in where_df.loc[where_df["fold_id"].isin(TEST_FOLDS), "window"]
    for event in window
}
if not train_time_interval_indices or not test_time_interval_indices:
    raise ValueError(
        f"The selected {WINDOW_LABEL} train or test split has no interval indices."
    )
if max(train_time_interval_indices | test_time_interval_indices) >= NUM_TIME_INTERVALS:
    raise ValueError("A train/test interval index exceeds the embedding size.")

print(
    f"{NUM_TIME_INTERVALS = }; "
    f"train={sorted(train_time_interval_indices)}, "
    f"test={sorted(test_time_interval_indices)}"
)
# Out:
# NUM_TIME_INTERVALS = 2; train=[0, 1], test=[0, 1]

# %% [markdown]
# # Model definitions for the selected WHERE window

# %%
MODEL_SCALE = 1

ZONE_EMBEDDING_DIM = int(64 * MODEL_SCALE)
OUTAGE_TYPE_EMBEDDING_DIM = int(32 * MODEL_SCALE)
TIME_INTERVAL_EMBEDDING_DIM = int(32 * MODEL_SCALE)
TRANSFORMER_DIM = int(256 * MODEL_SCALE)

DROPOUT = 0.15

# %%
import torch.nn as nn

num_zones = int(
    max(
        where_df["label"]
        .map(lambda x: max(x["from_zone_index"], x["to_zone_index"]))
        .max(),
        max(
            max(event["from_zone_index"], event["to_zone_index"])
            for window in where_df["window"]
            for event in window
        ),
    )
    + 1
)
num_outage_types = len(OUTAGE_TYPE_TO_ID)


class WhereTransformer(nn.Module):
    """ "Vanilla transformer model"""

    def __init__(
        self,
        num_zones,
        num_outage_types,
        num_time_intervals,
        zone_embedding_dim=ZONE_EMBEDDING_DIM,
        outage_type_embedding_dim=OUTAGE_TYPE_EMBEDDING_DIM,
        time_interval_embedding_dim=TIME_INTERVAL_EMBEDDING_DIM,
        transformer_dim=TRANSFORMER_DIM,
        dropout=DROPOUT,
    ):
        super().__init__()
        self.num_zones = num_zones
        self.num_time_intervals = int(num_time_intervals)
        self.zone_embedding = nn.Embedding(num_zones, zone_embedding_dim)
        self.outage_type_embedding = nn.Embedding(
            num_outage_types,
            outage_type_embedding_dim,
        )
        self.time_interval_embedding = nn.Embedding(
            self.num_time_intervals,
            time_interval_embedding_dim,
        )
        self.input_fc = nn.Linear(
            2 * zone_embedding_dim
            + outage_type_embedding_dim
            + time_interval_embedding_dim,
            transformer_dim,
        )
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=transformer_dim,
            nhead=transformer_dim // 64,
            dim_feedforward=transformer_dim * 4,
            dropout=dropout,
            batch_first=True,
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=1,
        )
        self.projection = nn.Linear(transformer_dim, 2 * num_zones)

    def forward(
        self,
        from_zone_indices,
        to_zone_indices,
        outage_type,
        time_interval_index,
    ):
        from_zone_emb = self.zone_embedding(from_zone_indices)
        to_zone_emb = self.zone_embedding(to_zone_indices)
        outage_type_emb = self.outage_type_embedding(outage_type)
        time_interval_emb = self.time_interval_embedding(time_interval_index)

        x = torch.cat(
            [from_zone_emb, to_zone_emb, outage_type_emb, time_interval_emb],
            dim=-1,
        )
        x = self.input_fc(x)

        x = self.transformer_encoder(x)

        # Pool the last event in this unpadded, one-sample sequence.
        pooled = x[:, -1, :]

        logits = self.projection(pooled)
        return logits.view(-1, 2, self.num_zones)

# %%
class GraphDistanceUnorderedZoneLoss(nn.Module):
    def __init__(
        self,
        graph,
        num_zones,
        distance_weight=0.2,
        unreachable_distance=None,
        reduction="mean",
    ):
        super().__init__()
        self.num_zones = num_zones
        self.distance_weight = distance_weight
        self.reduction = reduction

        distance_matrix = torch.as_tensor(
            graph.distances(
                source=range(num_zones),
                target=range(num_zones),
                mode="ALL",
            ),
            dtype=torch.float32,
        )
        finite_distances = distance_matrix[torch.isfinite(distance_matrix)]
        if unreachable_distance is None:
            unreachable_distance = finite_distances.max().item() + 1.0
        distance_matrix = torch.where(
            torch.isfinite(distance_matrix),
            distance_matrix,
            torch.full_like(distance_matrix, float(unreachable_distance)),
        )
        self.register_buffer("distance_matrix", distance_matrix)

    def _ordered_loss(self, from_logits, to_logits, target_from, target_to):
        ce_loss = nn.functional.cross_entropy(
            from_logits,
            target_from,
            reduction="none",
        ) + nn.functional.cross_entropy(
            to_logits,
            target_to,
            reduction="none",
        )

        from_probs = nn.functional.softmax(from_logits, dim=-1)
        to_probs = nn.functional.softmax(to_logits, dim=-1)
        from_distance = (from_probs * self.distance_matrix[target_from]).sum(dim=-1)
        to_distance = (to_probs * self.distance_matrix[target_to]).sum(dim=-1)
        distance_loss = from_distance + to_distance

        return ce_loss + self.distance_weight * distance_loss

    def forward(self, logits, target):
        from_logits = logits[:, 0, :]
        to_logits = logits[:, 1, :]
        target_from = target[:, 0]
        target_to = target[:, 1]

        forward_loss = self._ordered_loss(
            from_logits,
            to_logits,
            target_from,
            target_to,
        )
        swapped_loss = self._ordered_loss(
            from_logits,
            to_logits,
            target_to,
            target_from,
        )
        loss = torch.minimum(forward_loss, swapped_loss)

        if self.reduction == "mean":
            return loss.mean()
        if self.reduction == "sum":
            return loss.sum()
        if self.reduction == "none":
            return loss
        raise ValueError(f"Unsupported reduction: {self.reduction}")

# %%
class SelfAttentivePooling(nn.Module):
    def __init__(self, input_dim, attention_dim=None, dropout=DROPOUT):
        super().__init__()
        attention_dim = attention_dim or input_dim
        self.attention = nn.Sequential(
            nn.Linear(input_dim, attention_dim),
            nn.Tanh(),
            nn.Dropout(dropout),
            nn.Linear(attention_dim, 1),
        )

    def forward(self, x):
        attention_scores = self.attention(x).squeeze(-1)
        attention_weights = torch.softmax(attention_scores, dim=1).unsqueeze(-1)
        return (x * attention_weights).sum(dim=1)


class WhereTransformerSAP(nn.Module):
    def __init__(
        self,
        num_zones,
        num_outage_types,
        num_time_intervals,
        zone_embedding_dim=ZONE_EMBEDDING_DIM,
        outage_type_embedding_dim=OUTAGE_TYPE_EMBEDDING_DIM,
        time_interval_embedding_dim=TIME_INTERVAL_EMBEDDING_DIM,
        transformer_dim=TRANSFORMER_DIM,
        dropout=DROPOUT,
    ):
        super().__init__()
        self.num_zones = num_zones
        self.num_time_intervals = int(num_time_intervals)
        self.zone_embedding = nn.Embedding(num_zones, zone_embedding_dim)
        self.outage_type_embedding = nn.Embedding(
            num_outage_types,
            outage_type_embedding_dim,
        )
        self.time_interval_embedding = nn.Embedding(
            self.num_time_intervals,
            time_interval_embedding_dim,
        )
        self.input_fc = nn.Linear(
            2 * zone_embedding_dim
            + outage_type_embedding_dim
            + time_interval_embedding_dim,
            transformer_dim,
        )
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=transformer_dim,
            nhead=transformer_dim // 64,
            dim_feedforward=transformer_dim * 4,
            dropout=dropout,
            batch_first=True,
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=1,
        )
        self.self_attentive_pooling = SelfAttentivePooling(
            transformer_dim,
            dropout=dropout,
        )
        self.projection = nn.Linear(transformer_dim, 2 * num_zones)

    def forward(
        self,
        from_zone_indices,
        to_zone_indices,
        outage_type,
        time_interval_index,
    ):
        from_zone_emb = self.zone_embedding(from_zone_indices)
        to_zone_emb = self.zone_embedding(to_zone_indices)
        outage_type_emb = self.outage_type_embedding(outage_type)
        time_interval_emb = self.time_interval_embedding(time_interval_index)

        x = torch.cat(
            [from_zone_emb, to_zone_emb, outage_type_emb, time_interval_emb],
            dim=-1,
        )
        x = self.input_fc(x)

        x = self.transformer_encoder(x)

        pooled = self.self_attentive_pooling(x)

        logits = self.projection(pooled)
        return logits.view(-1, 2, self.num_zones)

# %% [markdown]
# # Cross-entropy last-event model for the selected window

# %%
LEARNING_RATE = 3e-6
NUM_EPOCHS = 100
VIRTUAL_BATCH_SIZE = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def sample_to_device(sample, device):
    return {
        "from_zone_indices": sample["from_zone_indices"].unsqueeze(0).to(device),
        "to_zone_indices": sample["to_zone_indices"].unsqueeze(0).to(device),
        "outage_type": sample["outage_type"].unsqueeze(0).to(device),
        "time_interval_index": sample["time_interval_index"].unsqueeze(0).to(device),
        "target": sample["target"].unsqueeze(0).to(device),
    }


def unordered_zone_loss(logits, target):
    from_logits = logits[:, 0, :]
    to_logits = logits[:, 1, :]
    target_from = target[:, 0]
    target_to = target[:, 1]

    forward_loss = nn.functional.cross_entropy(
        from_logits,
        target_from,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_to,
    )
    swapped_loss = nn.functional.cross_entropy(
        from_logits,
        target_to,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_from,
    )
    return torch.minimum(forward_loss, swapped_loss).mean()


def unordered_zone_correct_count(logits, target):
    pred = logits.argmax(dim=-1)
    pred_sorted = torch.sort(pred, dim=1).values
    target_sorted = torch.sort(target, dim=1).values
    return (pred_sorted == target_sorted).all(dim=1).sum().item()


set_seed()
where_transformer = WhereTransformer(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
    num_time_intervals=NUM_TIME_INTERVALS,
)
where_transformer.to(DEVICE)
optimizer = torch.optim.Adam(where_transformer.parameters(), lr=LEARNING_RATE)

training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    where_transformer.train()
    optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = where_transformer(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = unordered_zone_loss(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            optimizer.step()
            optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        optimizer.step()
        optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    where_transformer.eval()
    test_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = where_transformer(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy,
    }
    training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test loss={test_loss:.6f}, test acc={test_accuracy:.4f}"
    )

last_event_ce_checkpoint_path = (
    MODEL_OUTPUT_DIR
    / f"where_transformer_cross_entropy_last_event_{WINDOW_LABEL}_final.pt"
)

torch.save(
    {
        "model_state_dict": where_transformer.state_dict(),
        "window_hours": WINDOW_HOURS,
        "window_label": WINDOW_LABEL,
        "dataset": dataset_path.name,
        "window_selection_manifest": str(WINDOW_SELECTION_PATH),
        "window_selection": window_selection,
        "pooling": "last_event",
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "num_time_intervals": NUM_TIME_INTERVALS,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "time_interval_embedding_dim": TIME_INTERVAL_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "training_history": training_history,
    },
    last_event_ce_checkpoint_path,
)

print(
    "Saved final cross-entropy last-event checkpoint to "
    f"{last_event_ce_checkpoint_path}"
)
# Out:
# /home/aj/venv/lib/python3.14/site-packages/torch/autograd/graph.py:882: UserWarning: Memory Efficient attention defaults to a non-deterministic algorithm. To explicitly enable determinism call torch.use_deterministic_algorithms(True, warn_only=False). (Triggered internally at /pytorch/aten/src/ATen/native/transformers/cuda/attention_backward.cu:900.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 001 | train loss=6.657144, train acc=0.0030 | test loss=6.609224, test acc=0.0000
# Epoch 002 | train loss=6.607593, train acc=0.0030 | test loss=6.568856, test acc=0.0000
# Epoch 003 | train loss=6.543777, train acc=0.0030 | test loss=6.533102, test acc=0.0000
# Epoch 004 | train loss=6.517220, train acc=0.0015 | test loss=6.498813, test acc=0.0000
# Epoch 005 | train loss=6.469100, train acc=0.0015 | test loss=6.467337, test acc=0.0000
# Epoch 006 | train loss=6.410877, train acc=0.0015 | test loss=6.438379, test acc=0.0000
# Epoch 007 | train loss=6.382169, train acc=0.0045 | test loss=6.411085, test acc=0.0055
# Epoch 008 | train loss=6.325552, train acc=0.0045 | test loss=6.386148, test acc=0.0055
# Epoch 009 | train loss=6.307726, train acc=0.0059 | test loss=6.363429, test acc=0.0055
# Epoch 010 | train loss=6.282234, train acc=0.0015 | test loss=6.340631, test acc=0.0055
# Epoch 011 | train loss=6.247100, train acc=0.0089 | test loss=6.321110, test acc=0.0110
# Epoch 012 | train loss=6.209254, train acc=0.0134 | test loss=6.302116, test acc=0.0110
# Epoch 013 | train loss=6.191505, train acc=0.0163 | test loss=6.284736, test acc=0.0110
# Epoch 014 | train loss=6.162687, train acc=0.0208 | test loss=6.269510, test acc=0.0110
# Epoch 015 | train loss=6.151892, train acc=0.0252 | test loss=6.253167, test acc=0.0166
# Epoch 016 | train loss=6.113169, train acc=0.0297 | test loss=6.239687, test acc=0.0166
# Epoch 017 | train loss=6.092260, train acc=0.0341 | test loss=6.226600, test acc=0.0166
# Epoch 018 | train loss=6.071772, train acc=0.0341 | test loss=6.215123, test acc=0.0166
# Epoch 019 | train loss=6.062934, train acc=0.0356 | test loss=6.203453, test acc=0.0166
# Epoch 020 | train loss=6.031106, train acc=0.0326 | test loss=6.192307, test acc=0.0166
# Epoch 021 | train loss=6.026878, train acc=0.0401 | test loss=6.183180, test acc=0.0166
# Epoch 022 | train loss=6.010228, train acc=0.0356 | test loss=6.173475, test acc=0.0166
# Epoch 023 | train loss=5.987207, train acc=0.0371 | test loss=6.165333, test acc=0.0166
# Epoch 024 | train loss=5.973221, train acc=0.0460 | test loss=6.157188, test acc=0.0166
# Epoch 025 | train loss=5.955456, train acc=0.0460 | test loss=6.150103, test acc=0.0166
# Epoch 026 | train loss=5.944683, train acc=0.0475 | test loss=6.142378, test acc=0.0166
# Epoch 027 | train loss=5.934061, train acc=0.0430 | test loss=6.136247, test acc=0.0166
# Epoch 028 | train loss=5.919043, train acc=0.0445 | test loss=6.129491, test acc=0.0166
# Epoch 029 | train loss=5.905510, train acc=0.0445 | test loss=6.124648, test acc=0.0166
# Epoch 030 | train loss=5.886145, train acc=0.0475 | test loss=6.118925, test acc=0.0110
# Epoch 031 | train loss=5.880790, train acc=0.0475 | test loss=6.113398, test acc=0.0110
# Epoch 032 | train loss=5.881332, train acc=0.0445 | test loss=6.107789, test acc=0.0110
# Epoch 033 | train loss=5.853968, train acc=0.0504 | test loss=6.103652, test acc=0.0110
# Epoch 034 | train loss=5.845801, train acc=0.0460 | test loss=6.098549, test acc=0.0110
# Epoch 035 | train loss=5.835895, train acc=0.0519 | test loss=6.094083, test acc=0.0110
# Epoch 036 | train loss=5.832927, train acc=0.0504 | test loss=6.090091, test acc=0.0110
# Epoch 037 | train loss=5.832298, train acc=0.0504 | test loss=6.086224, test acc=0.0110
# Epoch 038 | train loss=5.823039, train acc=0.0460 | test loss=6.082241, test acc=0.0110
# Epoch 039 | train loss=5.789997, train acc=0.0534 | test loss=6.078568, test acc=0.0110
# Epoch 040 | train loss=5.797221, train acc=0.0534 | test loss=6.074683, test acc=0.0110
# Epoch 041 | train loss=5.802254, train acc=0.0475 | test loss=6.072018, test acc=0.0110
# Epoch 042 | train loss=5.778942, train acc=0.0623 | test loss=6.069500, test acc=0.0110
# Epoch 043 | train loss=5.777216, train acc=0.0608 | test loss=6.066456, test acc=0.0110
# Epoch 044 | train loss=5.763913, train acc=0.0534 | test loss=6.063661, test acc=0.0110
# Epoch 045 | train loss=5.759856, train acc=0.0579 | test loss=6.060412, test acc=0.0110
# Epoch 046 | train loss=5.766956, train acc=0.0564 | test loss=6.057319, test acc=0.0110
# Epoch 047 | train loss=5.740967, train acc=0.0504 | test loss=6.054204, test acc=0.0110
# Epoch 048 | train loss=5.754569, train acc=0.0593 | test loss=6.053238, test acc=0.0110
# Epoch 049 | train loss=5.745814, train acc=0.0504 | test loss=6.051488, test acc=0.0110
# Epoch 050 | train loss=5.736670, train acc=0.0549 | test loss=6.048578, test acc=0.0110
# Epoch 051 | train loss=5.724901, train acc=0.0549 | test loss=6.047053, test acc=0.0110
# Epoch 052 | train loss=5.721802, train acc=0.0579 | test loss=6.045024, test acc=0.0110
# Epoch 053 | train loss=5.730749, train acc=0.0668 | test loss=6.043173, test acc=0.0110
# Epoch 054 | train loss=5.726590, train acc=0.0593 | test loss=6.041950, test acc=0.0110
# Epoch 055 | train loss=5.708252, train acc=0.0593 | test loss=6.038985, test acc=0.0110
# Epoch 056 | train loss=5.698425, train acc=0.0653 | test loss=6.037105, test acc=0.0110
# Epoch 057 | train loss=5.698648, train acc=0.0608 | test loss=6.035849, test acc=0.0110
# Epoch 058 | train loss=5.697713, train acc=0.0623 | test loss=6.034792, test acc=0.0110
# Epoch 059 | train loss=5.683479, train acc=0.0623 | test loss=6.032998, test acc=0.0110
# Epoch 060 | train loss=5.691542, train acc=0.0608 | test loss=6.031680, test acc=0.0110
# Epoch 061 | train loss=5.687382, train acc=0.0682 | test loss=6.030249, test acc=0.0110
# Epoch 062 | train loss=5.662233, train acc=0.0579 | test loss=6.028918, test acc=0.0110
# Epoch 063 | train loss=5.688113, train acc=0.0623 | test loss=6.028223, test acc=0.0110
# Epoch 064 | train loss=5.676751, train acc=0.0593 | test loss=6.026732, test acc=0.0110
# Epoch 065 | train loss=5.659109, train acc=0.0742 | test loss=6.025845, test acc=0.0110
# Epoch 066 | train loss=5.657906, train acc=0.0638 | test loss=6.024964, test acc=0.0110
# Epoch 067 | train loss=5.659849, train acc=0.0712 | test loss=6.023499, test acc=0.0110
# Epoch 068 | train loss=5.644051, train acc=0.0697 | test loss=6.022950, test acc=0.0110
# Epoch 069 | train loss=5.657143, train acc=0.0712 | test loss=6.022070, test acc=0.0110
# Epoch 070 | train loss=5.639773, train acc=0.0697 | test loss=6.021495, test acc=0.0221
# Epoch 071 | train loss=5.631948, train acc=0.0712 | test loss=6.020591, test acc=0.0221
# Epoch 072 | train loss=5.635874, train acc=0.0757 | test loss=6.020374, test acc=0.0221
# Epoch 073 | train loss=5.617469, train acc=0.0668 | test loss=6.020072, test acc=0.0221
# Epoch 074 | train loss=5.633778, train acc=0.0727 | test loss=6.019695, test acc=0.0221
# Epoch 075 | train loss=5.633962, train acc=0.0712 | test loss=6.019382, test acc=0.0221
# Epoch 076 | train loss=5.624397, train acc=0.0668 | test loss=6.018372, test acc=0.0221
# Epoch 077 | train loss=5.621962, train acc=0.0549 | test loss=6.016804, test acc=0.0221
# Epoch 078 | train loss=5.617292, train acc=0.0742 | test loss=6.017358, test acc=0.0221
# Epoch 079 | train loss=5.611964, train acc=0.0727 | test loss=6.017493, test acc=0.0221
# Epoch 080 | train loss=5.600885, train acc=0.0638 | test loss=6.017692, test acc=0.0221
# Epoch 081 | train loss=5.593456, train acc=0.0757 | test loss=6.016717, test acc=0.0221
# Epoch 082 | train loss=5.608796, train acc=0.0623 | test loss=6.015815, test acc=0.0221
# Epoch 083 | train loss=5.587184, train acc=0.0682 | test loss=6.015826, test acc=0.0221
# Epoch 084 | train loss=5.575803, train acc=0.0786 | test loss=6.015209, test acc=0.0221
# Epoch 085 | train loss=5.600747, train acc=0.0712 | test loss=6.015665, test acc=0.0221
# Epoch 086 | train loss=5.585193, train acc=0.0668 | test loss=6.015696, test acc=0.0221
# Epoch 087 | train loss=5.597820, train acc=0.0801 | test loss=6.015749, test acc=0.0221
# Epoch 088 | train loss=5.583967, train acc=0.0801 | test loss=6.014200, test acc=0.0221
# Epoch 089 | train loss=5.553060, train acc=0.0786 | test loss=6.014806, test acc=0.0221
# Epoch 090 | train loss=5.572325, train acc=0.0742 | test loss=6.014121, test acc=0.0221
# Epoch 091 | train loss=5.564231, train acc=0.0757 | test loss=6.014501, test acc=0.0221
# Epoch 092 | train loss=5.562313, train acc=0.0697 | test loss=6.014033, test acc=0.0221
# Epoch 093 | train loss=5.554883, train acc=0.0801 | test loss=6.014037, test acc=0.0221
# Epoch 094 | train loss=5.555722, train acc=0.0742 | test loss=6.014499, test acc=0.0221
# Epoch 095 | train loss=5.560766, train acc=0.0831 | test loss=6.014878, test acc=0.0221
# Epoch 096 | train loss=5.553763, train acc=0.0653 | test loss=6.012979, test acc=0.0221
# Epoch 097 | train loss=5.550341, train acc=0.0831 | test loss=6.014393, test acc=0.0221
# Epoch 098 | train loss=5.543608, train acc=0.0890 | test loss=6.014326, test acc=0.0221
# Epoch 099 | train loss=5.549060, train acc=0.0727 | test loss=6.015350, test acc=0.0221
# Epoch 100 | train loss=5.543740, train acc=0.0727 | test loss=6.014320, test acc=0.0221
# Saved final cross-entropy last-event checkpoint to model_outputs/where_transformer/winsize0.5h/where_transformer_cross_entropy_last_event_0.5h_final.pt

# %%
import matplotlib.pyplot as plt

epochs = [row["epoch"] for row in training_history]
train_losses = [row["train_loss"] for row in training_history]
test_losses = [row["test_loss"] for row in training_history]
train_accuracies = [row["train_accuracy"] for row in training_history]
test_accuracies = [row["test_accuracy"] for row in training_history]

plt.figure(figsize=(8, 4))

plt.plot(epochs, train_losses, label="Train")
plt.plot(epochs, test_losses, label="Test")
plt.xlabel("Epoch")
plt.ylabel("Loss")
# plt.title("Training and test loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_cross_entropy_last_event_{WINDOW_LABEL}_training_loss_bpa.pdf",
    dpi=300,
)
plt.show()

plt.figure(figsize=(8, 4))

plt.plot(epochs, train_accuracies, label="Train")
plt.plot(epochs, test_accuracies, label="Test")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# plt.title("Training and test accuracy")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_cross_entropy_last_event_{WINDOW_LABEL}_training_accuracy_bpa.pdf",
    dpi=300,
)
plt.show()

# %%
from collections import deque
from pathlib import Path

import igraph as ig
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

GRAPH_PATH = Path("res/outage_graph.pkl")
EDGE_ZONE_PATH = Path("output/edge_zones.csv")
RANDOM_PAIR_BASELINE_SIZE = 10_000


def build_zone_distance_lookup(edge_zone_path):
    edge_zone_df = pd.read_csv(edge_zone_path)
    zones = sorted(
        set(edge_zone_df["from_zone"].astype(int))
        | set(edge_zone_df["to_zone"].astype(int))
    )
    adjacency = {zone: {zone} for zone in zones}

    for from_zone, to_zone in zip(
        edge_zone_df["from_zone"].astype(int),
        edge_zone_df["to_zone"].astype(int),
    ):
        adjacency.setdefault(from_zone, {from_zone}).add(to_zone)
        adjacency.setdefault(to_zone, {to_zone}).add(from_zone)

    distances = {}
    for source in adjacency:
        source_distances = {source: 0}
        queue = deque([source])
        while queue:
            current = queue.popleft()
            for neighbor in adjacency[current]:
                if neighbor not in source_distances:
                    source_distances[neighbor] = source_distances[current] + 1
                    queue.append(neighbor)
        distances[source] = source_distances

    return distances


def zone_distance(source_zone, target_zone, distance_lookup):
    return distance_lookup.get(int(source_zone), {}).get(int(target_zone), np.nan)


def unordered_pair_graph_distance(true_pair, pred_pair, distance_lookup):
    direct = (
        zone_distance(true_pair[0], pred_pair[0], distance_lookup)
        + zone_distance(true_pair[1], pred_pair[1], distance_lookup)
    ) / 2
    swapped = (
        zone_distance(true_pair[0], pred_pair[1], distance_lookup)
        + zone_distance(true_pair[1], pred_pair[0], distance_lookup)
    ) / 2
    candidates = [distance for distance in [direct, swapped] if np.isfinite(distance)]
    return min(candidates) if candidates else np.nan


def summarize_pair_distances(distances):
    distances = np.asarray(distances, dtype=float)
    finite = distances[np.isfinite(distances)]
    return {
        "mean_distance": finite.mean(),
        "median_distance": np.median(finite),
        "p90_distance": np.percentile(finite, 90),
        "same_zone_pair_rate": (finite == 0).mean(),
        "adjacent_or_same_pair_rate": (finite <= 1).mean(),
        "unreachable_count": int(np.isnan(distances).sum()),
    }


def collect_where_predictions(model, dataset, device):
    model.eval()
    rows = []
    with torch.no_grad():
        for sample in dataset:
            batch = sample_to_device(sample, device)
            logits = model(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            pred_pair = logits.argmax(dim=-1).squeeze(0).cpu().tolist()
            true_pair = sample["target"].cpu().tolist()
            rows.append(
                {
                    "true_from_zone": int(true_pair[0]),
                    "true_to_zone": int(true_pair[1]),
                    "pred_from_zone": int(pred_pair[0]),
                    "pred_to_zone": int(pred_pair[1]),
                    "exact_pair_match": sorted(true_pair) == sorted(pred_pair),
                }
            )
    return pd.DataFrame(rows)


outage_graph = ig.Graph.Read_Pickle(str(GRAPH_PATH))
zone_distance_lookup = build_zone_distance_lookup(EDGE_ZONE_PATH)
zone_ids = sorted(zone_distance_lookup)
rng = np.random.default_rng(RANDOM_STATE)

raw_graph_diameter = outage_graph.diameter(directed=False, unconn=True)
node_a, node_b = rng.choice(outage_graph.vcount(), size=2, replace=False)
random_node_distance = outage_graph.distances(
    source=[int(node_a)],
    target=[int(node_b)],
    mode="ALL",
)[0][0]

zone_graph_diameter = max(
    distance
    for source_distances in zone_distance_lookup.values()
    for distance in source_distances.values()
)
zone_a, zone_b = rng.choice(zone_ids, size=2, replace=False)
random_zone_distance = zone_distance_lookup[int(zone_a)][int(zone_b)]

checkpoint_path = Path(last_event_ce_checkpoint_path)
if not checkpoint_path.exists():
    raise FileNotFoundError(
        f"Missing selected-window checkpoint: {checkpoint_path}. "
        "Run the cross-entropy last-event training cell first."
    )
try:
    checkpoint = torch.load(checkpoint_path, map_location=DEVICE, weights_only=False)
except TypeError:
    checkpoint = torch.load(checkpoint_path, map_location=DEVICE)

if not np.isclose(float(checkpoint.get("window_hours", np.nan)), WINDOW_HOURS):
    raise ValueError(
        f"Checkpoint window does not match selected {WINDOW_LABEL}: {checkpoint_path}"
    )
if checkpoint.get("dataset") != dataset_path.name:
    raise ValueError(
        f"Checkpoint dataset does not match {dataset_path.name}: {checkpoint_path}"
    )
if checkpoint.get("num_time_intervals") != NUM_TIME_INTERVALS:
    raise ValueError(
        "Checkpoint time-interval vocabulary does not match the selected dataset."
    )
if checkpoint.get("pooling") != "last_event":
    raise ValueError(f"Checkpoint pooling metadata is invalid: {checkpoint_path}")

where_transformer.load_state_dict(checkpoint["model_state_dict"])
print(f"Loaded {WINDOW_LABEL} model checkpoint from {checkpoint_path}")

prediction_df = collect_where_predictions(where_transformer, test_where_dataset, DEVICE)
pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in prediction_df.itertuples(index=False)
    ],
    dtype=float,
)

random_pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            tuple(
                prediction_df.iloc[i % len(prediction_df)][
                    ["true_from_zone", "true_to_zone"]
                ].to_numpy()
            ),
            rng.choice(zone_ids, size=2, replace=True),
            zone_distance_lookup,
        )
        for i in range(RANDOM_PAIR_BASELINE_SIZE)
    ],
    dtype=float,
)

model_summary = summarize_pair_distances(pair_distances)
random_summary = summarize_pair_distances(random_pair_distances)
model_summary["exact_pair_accuracy"] = prediction_df["exact_pair_match"].mean()
model_summary["mean_distance_vs_diameter"] = (
    model_summary["mean_distance"] / zone_graph_diameter
)
model_summary["mean_distance_reduction_vs_random"] = 1 - (
    model_summary["mean_distance"] / random_summary["mean_distance"]
)

summary_df = pd.DataFrame(
    [
        {"model": "Transformer", **model_summary},
        {"model": "Random zone-pair baseline", **random_summary},
    ]
)

print(f"Raw outage graph: {outage_graph.vcount()} nodes, {outage_graph.ecount()} edges")
print(f"Maximum raw graph node distance: {raw_graph_diameter}")
print(
    f"Random raw nodes {int(node_a)} -> {int(node_b)} distance: "
    f"{random_node_distance}"
)
print(f"Maximum zone graph distance: {zone_graph_diameter}")
print(f"Random zones {int(zone_a)} -> {int(zone_b)} distance: {random_zone_distance}")
print(
    "Average unordered zone-pair distance, model: "
    f"{model_summary['mean_distance']:.3f}"
)
print(
    "Average unordered zone-pair distance, random baseline: "
    f"{random_summary['mean_distance']:.3f}"
)
print(
    "Model mean unordered pair distance: "
    f"{model_summary['mean_distance']:.3f} / {zone_graph_diameter} "
    f"({model_summary['mean_distance_vs_diameter']:.1%} of zone diameter)"
)
print(
    "Distance reduction versus random zone-pair baseline: "
    f"{model_summary['mean_distance_reduction_vs_random']:.1%}"
)

display(summary_df.round(3))
display(prediction_df.head())

bins = np.arange(-0.5, zone_graph_diameter + 1.5, 1)
fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(
    pair_distances[np.isfinite(pair_distances)], bins=bins, alpha=0.7, label="Model"
)
ax.hist(
    random_pair_distances[np.isfinite(random_pair_distances)],
    bins=bins,
    histtype="step",
    linewidth=2,
    label="Random baseline",
)
ax.set_xlabel("Unordered zone-pair graph distance")
ax.set_ylabel("Count")
# ax.set_title("Where-model graph-distance error")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_cross_entropy_last_event_{WINDOW_LABEL}_graph_distance_error_bpa.pdf",
    dpi=300,
)
plt.show()
# Out:
# Loaded 0.5h model checkpoint from model_outputs/where_transformer/winsize0.5h/where_transformer_cross_entropy_last_event_0.5h_final.pt
# Raw outage graph: 1082 nodes, 1462 edges
# Maximum raw graph node distance: 18
# Random raw nodes 96 -> 837 distance: 4
# Maximum zone graph distance: 4
# Random zones 10 -> 24 distance: 3
# Average unordered zone-pair distance, model: 1.586
# Average unordered zone-pair distance, random baseline: 1.795
# Model mean unordered pair distance: 1.586 / 4 (39.6% of zone diameter)
# Distance reduction versus random zone-pair baseline: 11.6%
#                        model  mean_distance  median_distance  p90_distance  \
# 0                Transformer          1.586              1.5           2.5
# 1  Random zone-pair baseline          1.795              2.0           2.5
#
#    same_zone_pair_rate  adjacent_or_same_pair_rate  unreachable_count  \
# 0                0.022                       0.376                  0
# 1                0.002                       0.161                  0
#
#    exact_pair_accuracy  mean_distance_vs_diameter  \
# 0                0.022                      0.396
# 1                  NaN                        NaN
#
#    mean_distance_reduction_vs_random
# 0                              0.116
# 1                                NaN
#    true_from_zone  true_to_zone  pred_from_zone  pred_to_zone  \
# 0               0             0               8             5
# 1               2             2              18             5
# 2               3             3               5            18
# 3              22            22              18             5
# 4              20            20               0             0
#
#    exact_pair_match
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# # Cross-entropy self-attentive-pooling model for the selected window

# %%
LEARNING_RATE = 3e-6
NUM_EPOCHS = 100
VIRTUAL_BATCH_SIZE = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def sample_to_device(sample, device):
    return {
        "from_zone_indices": sample["from_zone_indices"].unsqueeze(0).to(device),
        "to_zone_indices": sample["to_zone_indices"].unsqueeze(0).to(device),
        "outage_type": sample["outage_type"].unsqueeze(0).to(device),
        "time_interval_index": sample["time_interval_index"].unsqueeze(0).to(device),
        "target": sample["target"].unsqueeze(0).to(device),
    }


def unordered_zone_loss(logits, target):
    from_logits = logits[:, 0, :]
    to_logits = logits[:, 1, :]
    target_from = target[:, 0]
    target_to = target[:, 1]

    forward_loss = nn.functional.cross_entropy(
        from_logits,
        target_from,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_to,
    )
    swapped_loss = nn.functional.cross_entropy(
        from_logits,
        target_to,
    ) + nn.functional.cross_entropy(
        to_logits,
        target_from,
    )
    return torch.minimum(forward_loss, swapped_loss).mean()


def unordered_zone_correct_count(logits, target):
    pred = logits.argmax(dim=-1)
    pred_sorted = torch.sort(pred, dim=1).values
    target_sorted = torch.sort(target, dim=1).values
    return (pred_sorted == target_sorted).all(dim=1).sum().item()


set_seed()
where_transformer_sap = WhereTransformerSAP(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
    num_time_intervals=NUM_TIME_INTERVALS,
)
where_transformer_sap
where_transformer_sap.to(DEVICE)
optimizer = torch.optim.Adam(where_transformer_sap.parameters(), lr=LEARNING_RATE)

training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    where_transformer_sap.train()
    optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = where_transformer_sap(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = unordered_zone_loss(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            optimizer.step()
            optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        optimizer.step()
        optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    where_transformer_sap.eval()
    test_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = where_transformer_sap(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy,
    }
    training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test loss={test_loss:.6f}, test acc={test_accuracy:.4f}"
    )

sap_ce_checkpoint_path = (
    MODEL_OUTPUT_DIR / f"where_transformer_cross_entropy_sap_{WINDOW_LABEL}_final.pt"
)

torch.save(
    {
        "model_state_dict": where_transformer_sap.state_dict(),
        "window_hours": WINDOW_HOURS,
        "window_label": WINDOW_LABEL,
        "dataset": dataset_path.name,
        "window_selection_manifest": str(WINDOW_SELECTION_PATH),
        "window_selection": window_selection,
        "pooling": "self_attentive",
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "num_time_intervals": NUM_TIME_INTERVALS,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "time_interval_embedding_dim": TIME_INTERVAL_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "training_history": training_history,
    },
    sap_ce_checkpoint_path,
)

print(
    "Saved final cross-entropy self-attentive-pooling checkpoint to "
    f"{sap_ce_checkpoint_path}"
)
# Out:
# Epoch 001 | train loss=6.686880, train acc=0.0015 | test loss=6.630895, test acc=0.0055
# Epoch 002 | train loss=6.638823, train acc=0.0030 | test loss=6.600981, test acc=0.0055
# Epoch 003 | train loss=6.603848, train acc=0.0030 | test loss=6.573056, test acc=0.0000
# Epoch 004 | train loss=6.536075, train acc=0.0015 | test loss=6.546959, test acc=0.0000
# Epoch 005 | train loss=6.511908, train acc=0.0045 | test loss=6.521049, test acc=0.0000
# Epoch 006 | train loss=6.479249, train acc=0.0030 | test loss=6.496449, test acc=0.0000
# Epoch 007 | train loss=6.447017, train acc=0.0015 | test loss=6.474048, test acc=0.0000
# Epoch 008 | train loss=6.403064, train acc=0.0045 | test loss=6.452855, test acc=0.0000
# Epoch 009 | train loss=6.374262, train acc=0.0059 | test loss=6.433136, test acc=0.0000
# Epoch 010 | train loss=6.347605, train acc=0.0045 | test loss=6.413494, test acc=0.0000
# Epoch 011 | train loss=6.317528, train acc=0.0045 | test loss=6.395801, test acc=0.0055
# Epoch 012 | train loss=6.279026, train acc=0.0030 | test loss=6.378062, test acc=0.0110
# Epoch 013 | train loss=6.263854, train acc=0.0059 | test loss=6.361349, test acc=0.0110
# Epoch 014 | train loss=6.237110, train acc=0.0059 | test loss=6.345762, test acc=0.0110
# Epoch 015 | train loss=6.213904, train acc=0.0074 | test loss=6.331706, test acc=0.0110
# Epoch 016 | train loss=6.184717, train acc=0.0104 | test loss=6.317446, test acc=0.0110
# Epoch 017 | train loss=6.166595, train acc=0.0134 | test loss=6.304636, test acc=0.0110
# Epoch 018 | train loss=6.144829, train acc=0.0119 | test loss=6.292171, test acc=0.0110
# Epoch 019 | train loss=6.127023, train acc=0.0119 | test loss=6.279690, test acc=0.0110
# Epoch 020 | train loss=6.101413, train acc=0.0252 | test loss=6.269024, test acc=0.0110
# Epoch 021 | train loss=6.087596, train acc=0.0163 | test loss=6.258231, test acc=0.0166
# Epoch 022 | train loss=6.073618, train acc=0.0297 | test loss=6.247745, test acc=0.0166
# Epoch 023 | train loss=6.047562, train acc=0.0252 | test loss=6.238293, test acc=0.0166
# Epoch 024 | train loss=6.030451, train acc=0.0445 | test loss=6.228313, test acc=0.0166
# Epoch 025 | train loss=6.008492, train acc=0.0356 | test loss=6.220854, test acc=0.0166
# Epoch 026 | train loss=6.001084, train acc=0.0430 | test loss=6.212226, test acc=0.0166
# Epoch 027 | train loss=5.993402, train acc=0.0415 | test loss=6.204859, test acc=0.0166
# Epoch 028 | train loss=5.963385, train acc=0.0401 | test loss=6.196309, test acc=0.0221
# Epoch 029 | train loss=5.955618, train acc=0.0504 | test loss=6.190122, test acc=0.0221
# Epoch 030 | train loss=5.948889, train acc=0.0519 | test loss=6.183881, test acc=0.0221
# Epoch 031 | train loss=5.941718, train acc=0.0475 | test loss=6.178152, test acc=0.0166
# Epoch 032 | train loss=5.932899, train acc=0.0534 | test loss=6.172213, test acc=0.0166
# Epoch 033 | train loss=5.920476, train acc=0.0534 | test loss=6.165324, test acc=0.0166
# Epoch 034 | train loss=5.902353, train acc=0.0504 | test loss=6.159959, test acc=0.0166
# Epoch 035 | train loss=5.891116, train acc=0.0608 | test loss=6.155056, test acc=0.0166
# Epoch 036 | train loss=5.889512, train acc=0.0579 | test loss=6.150341, test acc=0.0166
# Epoch 037 | train loss=5.877365, train acc=0.0593 | test loss=6.145776, test acc=0.0166
# Epoch 038 | train loss=5.877177, train acc=0.0564 | test loss=6.141078, test acc=0.0166
# Epoch 039 | train loss=5.848455, train acc=0.0608 | test loss=6.136042, test acc=0.0166
# Epoch 040 | train loss=5.849744, train acc=0.0653 | test loss=6.132585, test acc=0.0166
# Epoch 041 | train loss=5.847138, train acc=0.0697 | test loss=6.128973, test acc=0.0166
# Epoch 042 | train loss=5.837547, train acc=0.0682 | test loss=6.124847, test acc=0.0166
# Epoch 043 | train loss=5.822134, train acc=0.0608 | test loss=6.122070, test acc=0.0166
# Epoch 044 | train loss=5.818507, train acc=0.0623 | test loss=6.118103, test acc=0.0166
# Epoch 045 | train loss=5.808181, train acc=0.0712 | test loss=6.114968, test acc=0.0166
# Epoch 046 | train loss=5.801815, train acc=0.0593 | test loss=6.112422, test acc=0.0166
# Epoch 047 | train loss=5.786913, train acc=0.0668 | test loss=6.108839, test acc=0.0166
# Epoch 048 | train loss=5.787490, train acc=0.0697 | test loss=6.106031, test acc=0.0166
# Epoch 049 | train loss=5.780402, train acc=0.0742 | test loss=6.103313, test acc=0.0166
# Epoch 050 | train loss=5.767597, train acc=0.0727 | test loss=6.100464, test acc=0.0166
# Epoch 051 | train loss=5.769423, train acc=0.0772 | test loss=6.098290, test acc=0.0166
# Epoch 052 | train loss=5.759775, train acc=0.0653 | test loss=6.094553, test acc=0.0166
# Epoch 053 | train loss=5.756124, train acc=0.0697 | test loss=6.093129, test acc=0.0166
# Epoch 054 | train loss=5.759765, train acc=0.0757 | test loss=6.090817, test acc=0.0166
# Epoch 055 | train loss=5.746127, train acc=0.0697 | test loss=6.089137, test acc=0.0166
# Epoch 056 | train loss=5.749740, train acc=0.0757 | test loss=6.086578, test acc=0.0110
# Epoch 057 | train loss=5.729386, train acc=0.0727 | test loss=6.085071, test acc=0.0110
# Epoch 058 | train loss=5.731382, train acc=0.0697 | test loss=6.082921, test acc=0.0110
# Epoch 059 | train loss=5.724431, train acc=0.0712 | test loss=6.081418, test acc=0.0110
# Epoch 060 | train loss=5.714807, train acc=0.0757 | test loss=6.079622, test acc=0.0110
# Epoch 061 | train loss=5.705587, train acc=0.0742 | test loss=6.077860, test acc=0.0110
# Epoch 062 | train loss=5.698363, train acc=0.0682 | test loss=6.076398, test acc=0.0110
# Epoch 063 | train loss=5.706765, train acc=0.0757 | test loss=6.075268, test acc=0.0110
# Epoch 064 | train loss=5.707114, train acc=0.0742 | test loss=6.074379, test acc=0.0110
# Epoch 065 | train loss=5.704271, train acc=0.0772 | test loss=6.072046, test acc=0.0110
# Epoch 066 | train loss=5.690395, train acc=0.0697 | test loss=6.070054, test acc=0.0110
# Epoch 067 | train loss=5.688768, train acc=0.0727 | test loss=6.070607, test acc=0.0110
# Epoch 068 | train loss=5.676497, train acc=0.0846 | test loss=6.069177, test acc=0.0110
# Epoch 069 | train loss=5.669798, train acc=0.0786 | test loss=6.067781, test acc=0.0110
# Epoch 070 | train loss=5.676361, train acc=0.0772 | test loss=6.067150, test acc=0.0110
# Epoch 071 | train loss=5.677328, train acc=0.0742 | test loss=6.065763, test acc=0.0110
# Epoch 072 | train loss=5.676592, train acc=0.0727 | test loss=6.064525, test acc=0.0110
# Epoch 073 | train loss=5.652054, train acc=0.0772 | test loss=6.064499, test acc=0.0110
# Epoch 074 | train loss=5.642463, train acc=0.0846 | test loss=6.063332, test acc=0.0110
# Epoch 075 | train loss=5.655805, train acc=0.0816 | test loss=6.062711, test acc=0.0110
# Epoch 076 | train loss=5.653333, train acc=0.0846 | test loss=6.061884, test acc=0.0110
# Epoch 077 | train loss=5.625209, train acc=0.0846 | test loss=6.061694, test acc=0.0110
# Epoch 078 | train loss=5.628226, train acc=0.0861 | test loss=6.059583, test acc=0.0110
# Epoch 079 | train loss=5.635637, train acc=0.0831 | test loss=6.060509, test acc=0.0110
# Epoch 080 | train loss=5.631100, train acc=0.0846 | test loss=6.058638, test acc=0.0110
# Epoch 081 | train loss=5.633094, train acc=0.0875 | test loss=6.058657, test acc=0.0110
# Epoch 082 | train loss=5.633581, train acc=0.0786 | test loss=6.057814, test acc=0.0110
# Epoch 083 | train loss=5.621013, train acc=0.0801 | test loss=6.056823, test acc=0.0110
# Epoch 084 | train loss=5.624189, train acc=0.0935 | test loss=6.056253, test acc=0.0110
# Epoch 085 | train loss=5.615806, train acc=0.0890 | test loss=6.055827, test acc=0.0110
# Epoch 086 | train loss=5.610631, train acc=0.0890 | test loss=6.056084, test acc=0.0110
# Epoch 087 | train loss=5.611402, train acc=0.0890 | test loss=6.055770, test acc=0.0110
# Epoch 088 | train loss=5.609166, train acc=0.0861 | test loss=6.055325, test acc=0.0110
# Epoch 089 | train loss=5.597707, train acc=0.0935 | test loss=6.055177, test acc=0.0110
# Epoch 090 | train loss=5.596082, train acc=0.0816 | test loss=6.054701, test acc=0.0110
# Epoch 091 | train loss=5.593824, train acc=0.0905 | test loss=6.054567, test acc=0.0110
# Epoch 092 | train loss=5.581159, train acc=0.1053 | test loss=6.052956, test acc=0.0110
# Epoch 093 | train loss=5.584961, train acc=0.0846 | test loss=6.053846, test acc=0.0110
# Epoch 094 | train loss=5.590806, train acc=0.0950 | test loss=6.053899, test acc=0.0110
# Epoch 095 | train loss=5.590566, train acc=0.0875 | test loss=6.053172, test acc=0.0110
# Epoch 096 | train loss=5.584625, train acc=0.0875 | test loss=6.053149, test acc=0.0110
# Epoch 097 | train loss=5.571235, train acc=0.0905 | test loss=6.053453, test acc=0.0110
# Epoch 098 | train loss=5.574773, train acc=0.0905 | test loss=6.053627, test acc=0.0110
# Epoch 099 | train loss=5.566501, train acc=0.0979 | test loss=6.053245, test acc=0.0166
# Epoch 100 | train loss=5.563468, train acc=0.1142 | test loss=6.052981, test acc=0.0166
# Saved final cross-entropy self-attentive-pooling checkpoint to model_outputs/where_transformer/winsize0.5h/where_transformer_cross_entropy_sap_0.5h_final.pt

# %% [markdown]
# # Adjacency-aware last-event model for the selected window

# %%
ADJACENCY_DISTANCE_WEIGHT = 2.0

edge_zone_df = pd.read_csv(EDGE_ZONE_PATH)
zone_edges = [
    (int(from_zone), int(to_zone))
    for from_zone, to_zone in zip(edge_zone_df["from_zone"], edge_zone_df["to_zone"])
    if 0 <= int(from_zone) < num_zones and 0 <= int(to_zone) < num_zones
]
zone_graph = ig.Graph(n=num_zones, edges=zone_edges, directed=False)
zone_graph.simplify(multiple=True, loops=True)

set_seed()
adjacency_where_transformer = WhereTransformer(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
    num_time_intervals=NUM_TIME_INTERVALS,
)
adjacency_where_transformer.to(DEVICE)

adjacency_criterion = GraphDistanceUnorderedZoneLoss(
    zone_graph,
    num_zones=num_zones,
    distance_weight=ADJACENCY_DISTANCE_WEIGHT,
).to(DEVICE)
adjacency_optimizer = torch.optim.Adam(
    adjacency_where_transformer.parameters(),
    lr=LEARNING_RATE,
)

adjacency_training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    adjacency_where_transformer.train()
    adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = adjacency_where_transformer(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = adjacency_criterion(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            adjacency_optimizer.step()
            adjacency_optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        adjacency_optimizer.step()
        adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    adjacency_where_transformer.eval()
    test_loss_sum = 0.0
    test_cross_entropy_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = adjacency_where_transformer(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = adjacency_criterion(logits, batch["target"])
            cross_entropy_loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_cross_entropy_loss_sum += cross_entropy_loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_cross_entropy_loss = test_cross_entropy_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_cross_entropy_loss": test_cross_entropy_loss,
        "test_accuracy": test_accuracy,
    }
    adjacency_training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test adjacency loss={test_loss:.6f}, "
        f"test CE loss={test_cross_entropy_loss:.6f}, "
        f"test acc={test_accuracy:.4f}"
    )

last_event_adjacency_checkpoint_path = (
    MODEL_OUTPUT_DIR
    / f"where_transformer_adjacency_aware_last_event_{WINDOW_LABEL}_final.pt"
)

torch.save(
    {
        "model_state_dict": adjacency_where_transformer.state_dict(),
        "window_hours": WINDOW_HOURS,
        "window_label": WINDOW_LABEL,
        "dataset": dataset_path.name,
        "window_selection_manifest": str(WINDOW_SELECTION_PATH),
        "window_selection": window_selection,
        "pooling": "last_event",
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "num_time_intervals": NUM_TIME_INTERVALS,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "time_interval_embedding_dim": TIME_INTERVAL_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "distance_weight": ADJACENCY_DISTANCE_WEIGHT,
        "training_history": adjacency_training_history,
    },
    last_event_adjacency_checkpoint_path,
)

print(
    "Saved final adjacency-aware last-event checkpoint to "
    f"{last_event_adjacency_checkpoint_path}"
)
# Out:
# Epoch 001 | train loss=13.989384, train acc=0.0030 | test adjacency loss=13.863992, test CE loss=6.611382, test acc=0.0000
# Epoch 002 | train loss=13.912023, train acc=0.0030 | test adjacency loss=13.794145, test CE loss=6.573174, test acc=0.0000
# Epoch 003 | train loss=13.818144, train acc=0.0030 | test adjacency loss=13.728926, test CE loss=6.539586, test acc=0.0000
# Epoch 004 | train loss=13.765971, train acc=0.0015 | test adjacency loss=13.665870, test CE loss=6.507626, test acc=0.0000
# Epoch 005 | train loss=13.680724, train acc=0.0015 | test adjacency loss=13.605609, test CE loss=6.478629, test acc=0.0000
# Epoch 006 | train loss=13.589082, train acc=0.0030 | test adjacency loss=13.548605, test CE loss=6.452460, test acc=0.0000
# Epoch 007 | train loss=13.532183, train acc=0.0030 | test adjacency loss=13.492797, test CE loss=6.429173, test acc=0.0000
# Epoch 008 | train loss=13.439488, train acc=0.0045 | test adjacency loss=13.440557, test CE loss=6.408874, test acc=0.0000
# Epoch 009 | train loss=13.395282, train acc=0.0119 | test adjacency loss=13.391919, test CE loss=6.391517, test acc=0.0055
# Epoch 010 | train loss=13.339114, train acc=0.0045 | test adjacency loss=13.343421, test CE loss=6.375254, test acc=0.0166
# Epoch 011 | train loss=13.277781, train acc=0.0237 | test adjacency loss=13.300211, test CE loss=6.363529, test acc=0.0166
# Epoch 012 | train loss=13.202785, train acc=0.0237 | test adjacency loss=13.258150, test CE loss=6.352073, test acc=0.0166
# Epoch 013 | train loss=13.153327, train acc=0.0371 | test adjacency loss=13.219244, test CE loss=6.344277, test acc=0.0166
# Epoch 014 | train loss=13.098396, train acc=0.0490 | test adjacency loss=13.183056, test CE loss=6.339844, test acc=0.0166
# Epoch 015 | train loss=13.063290, train acc=0.0430 | test adjacency loss=13.147573, test CE loss=6.333644, test acc=0.0166
# Epoch 016 | train loss=12.994257, train acc=0.0475 | test adjacency loss=13.116445, test CE loss=6.331239, test acc=0.0221
# Epoch 017 | train loss=12.946242, train acc=0.0519 | test adjacency loss=13.086294, test CE loss=6.330169, test acc=0.0221
# Epoch 018 | train loss=12.910874, train acc=0.0593 | test adjacency loss=13.058933, test CE loss=6.331715, test acc=0.0221
# Epoch 019 | train loss=12.879810, train acc=0.0608 | test adjacency loss=13.033089, test CE loss=6.331418, test acc=0.0221
# Epoch 020 | train loss=12.827687, train acc=0.0564 | test adjacency loss=13.007847, test CE loss=6.332857, test acc=0.0276
# Epoch 021 | train loss=12.805571, train acc=0.0638 | test adjacency loss=12.986309, test CE loss=6.335704, test acc=0.0276
# Epoch 022 | train loss=12.770289, train acc=0.0697 | test adjacency loss=12.964186, test CE loss=6.337945, test acc=0.0387
# Epoch 023 | train loss=12.726582, train acc=0.0757 | test adjacency loss=12.945397, test CE loss=6.339271, test acc=0.0387
# Epoch 024 | train loss=12.692408, train acc=0.0786 | test adjacency loss=12.926772, test CE loss=6.342684, test acc=0.0387
# Epoch 025 | train loss=12.663139, train acc=0.0786 | test adjacency loss=12.909969, test CE loss=6.348450, test acc=0.0387
# Epoch 026 | train loss=12.633536, train acc=0.0801 | test adjacency loss=12.893050, test CE loss=6.351341, test acc=0.0387
# Epoch 027 | train loss=12.611891, train acc=0.0772 | test adjacency loss=12.878526, test CE loss=6.355816, test acc=0.0387
# Epoch 028 | train loss=12.582384, train acc=0.0801 | test adjacency loss=12.863705, test CE loss=6.358693, test acc=0.0387
# Epoch 029 | train loss=12.552113, train acc=0.0846 | test adjacency loss=12.852101, test CE loss=6.363421, test acc=0.0387
# Epoch 030 | train loss=12.519424, train acc=0.0831 | test adjacency loss=12.839112, test CE loss=6.368857, test acc=0.0387
# Epoch 031 | train loss=12.510721, train acc=0.0861 | test adjacency loss=12.827497, test CE loss=6.372327, test acc=0.0387
# Epoch 032 | train loss=12.498409, train acc=0.0846 | test adjacency loss=12.815240, test CE loss=6.374566, test acc=0.0442
# Epoch 033 | train loss=12.457284, train acc=0.0905 | test adjacency loss=12.805912, test CE loss=6.378461, test acc=0.0442
# Epoch 034 | train loss=12.443584, train acc=0.0890 | test adjacency loss=12.795632, test CE loss=6.381402, test acc=0.0552
# Epoch 035 | train loss=12.427685, train acc=0.0964 | test adjacency loss=12.786191, test CE loss=6.384801, test acc=0.0608
# Epoch 036 | train loss=12.415524, train acc=0.0935 | test adjacency loss=12.777314, test CE loss=6.386558, test acc=0.0608
# Epoch 037 | train loss=12.405393, train acc=0.0994 | test adjacency loss=12.768894, test CE loss=6.389902, test acc=0.0608
# Epoch 038 | train loss=12.390888, train acc=0.0994 | test adjacency loss=12.761081, test CE loss=6.392065, test acc=0.0608
# Epoch 039 | train loss=12.347570, train acc=0.1039 | test adjacency loss=12.753721, test CE loss=6.394294, test acc=0.0608
# Epoch 040 | train loss=12.349771, train acc=0.1009 | test adjacency loss=12.746427, test CE loss=6.398507, test acc=0.0608
# Epoch 041 | train loss=12.347780, train acc=0.1039 | test adjacency loss=12.741307, test CE loss=6.402138, test acc=0.0608
# Epoch 042 | train loss=12.317804, train acc=0.1009 | test adjacency loss=12.736551, test CE loss=6.407415, test acc=0.0608
# Epoch 043 | train loss=12.315950, train acc=0.1009 | test adjacency loss=12.730699, test CE loss=6.410000, test acc=0.0608
# Epoch 044 | train loss=12.297483, train acc=0.1024 | test adjacency loss=12.725199, test CE loss=6.409035, test acc=0.0608
# Epoch 045 | train loss=12.285872, train acc=0.1039 | test adjacency loss=12.718715, test CE loss=6.410351, test acc=0.0608
# Epoch 046 | train loss=12.288525, train acc=0.1053 | test adjacency loss=12.713347, test CE loss=6.411315, test acc=0.0608
# Epoch 047 | train loss=12.265842, train acc=0.1009 | test adjacency loss=12.707148, test CE loss=6.409415, test acc=0.0608
# Epoch 048 | train loss=12.273987, train acc=0.1068 | test adjacency loss=12.705025, test CE loss=6.415143, test acc=0.0608
# Epoch 049 | train loss=12.260202, train acc=0.1039 | test adjacency loss=12.700934, test CE loss=6.418092, test acc=0.0608
# Epoch 050 | train loss=12.242754, train acc=0.1053 | test adjacency loss=12.695570, test CE loss=6.415535, test acc=0.0608
# Epoch 051 | train loss=12.231689, train acc=0.1068 | test adjacency loss=12.692071, test CE loss=6.416995, test acc=0.0608
# Epoch 052 | train loss=12.217935, train acc=0.1053 | test adjacency loss=12.688848, test CE loss=6.417923, test acc=0.0608
# Epoch 053 | train loss=12.234328, train acc=0.1053 | test adjacency loss=12.685467, test CE loss=6.419626, test acc=0.0608
# Epoch 054 | train loss=12.223706, train acc=0.1053 | test adjacency loss=12.682598, test CE loss=6.423045, test acc=0.0608
# Epoch 055 | train loss=12.205265, train acc=0.1053 | test adjacency loss=12.677604, test CE loss=6.420473, test acc=0.0608
# Epoch 056 | train loss=12.190373, train acc=0.1068 | test adjacency loss=12.674282, test CE loss=6.421428, test acc=0.0608
# Epoch 057 | train loss=12.189810, train acc=0.1068 | test adjacency loss=12.671716, test CE loss=6.420011, test acc=0.0608
# Epoch 058 | train loss=12.173568, train acc=0.1068 | test adjacency loss=12.669487, test CE loss=6.422759, test acc=0.0608
# Epoch 059 | train loss=12.170777, train acc=0.1053 | test adjacency loss=12.666347, test CE loss=6.423977, test acc=0.0608
# Epoch 060 | train loss=12.172937, train acc=0.1068 | test adjacency loss=12.663535, test CE loss=6.424405, test acc=0.0608
# Epoch 061 | train loss=12.168094, train acc=0.1068 | test adjacency loss=12.660175, test CE loss=6.419604, test acc=0.0608
# Epoch 062 | train loss=12.138410, train acc=0.1068 | test adjacency loss=12.657451, test CE loss=6.419715, test acc=0.0608
# Epoch 063 | train loss=12.167671, train acc=0.1053 | test adjacency loss=12.656114, test CE loss=6.422155, test acc=0.0608
# Epoch 064 | train loss=12.156289, train acc=0.1068 | test adjacency loss=12.653043, test CE loss=6.420076, test acc=0.0608
# Epoch 065 | train loss=12.126263, train acc=0.1068 | test adjacency loss=12.650852, test CE loss=6.419662, test acc=0.0608
# Epoch 066 | train loss=12.127976, train acc=0.1068 | test adjacency loss=12.648309, test CE loss=6.419737, test acc=0.0608
# Epoch 067 | train loss=12.127292, train acc=0.1068 | test adjacency loss=12.645396, test CE loss=6.415821, test acc=0.0608
# Epoch 068 | train loss=12.107547, train acc=0.1068 | test adjacency loss=12.644181, test CE loss=6.418293, test acc=0.0608
# Epoch 069 | train loss=12.124323, train acc=0.1053 | test adjacency loss=12.641618, test CE loss=6.415911, test acc=0.0608
# Epoch 070 | train loss=12.102447, train acc=0.1068 | test adjacency loss=12.640526, test CE loss=6.416779, test acc=0.0608
# Epoch 071 | train loss=12.093801, train acc=0.1068 | test adjacency loss=12.638010, test CE loss=6.415836, test acc=0.0608
# Epoch 072 | train loss=12.098085, train acc=0.1068 | test adjacency loss=12.636761, test CE loss=6.416728, test acc=0.0608
# Epoch 073 | train loss=12.070939, train acc=0.1068 | test adjacency loss=12.635915, test CE loss=6.418294, test acc=0.0608
# Epoch 074 | train loss=12.097270, train acc=0.1068 | test adjacency loss=12.634178, test CE loss=6.416183, test acc=0.0608
# Epoch 075 | train loss=12.102026, train acc=0.1053 | test adjacency loss=12.633228, test CE loss=6.419257, test acc=0.0608
# Epoch 076 | train loss=12.081262, train acc=0.1083 | test adjacency loss=12.631270, test CE loss=6.416127, test acc=0.0608
# Epoch 077 | train loss=12.083341, train acc=0.1068 | test adjacency loss=12.627397, test CE loss=6.409963, test acc=0.0608
# Epoch 078 | train loss=12.070130, train acc=0.1068 | test adjacency loss=12.627796, test CE loss=6.412982, test acc=0.0608
# Epoch 079 | train loss=12.059022, train acc=0.1068 | test adjacency loss=12.626899, test CE loss=6.414757, test acc=0.0608
# Epoch 080 | train loss=12.052948, train acc=0.1068 | test adjacency loss=12.626582, test CE loss=6.414904, test acc=0.0608
# Epoch 081 | train loss=12.046010, train acc=0.1068 | test adjacency loss=12.624044, test CE loss=6.412353, test acc=0.0608
# Epoch 082 | train loss=12.061425, train acc=0.1068 | test adjacency loss=12.621687, test CE loss=6.410266, test acc=0.0608
# Epoch 083 | train loss=12.027716, train acc=0.1068 | test adjacency loss=12.621221, test CE loss=6.412265, test acc=0.0608
# Epoch 084 | train loss=12.020356, train acc=0.1068 | test adjacency loss=12.619561, test CE loss=6.409453, test acc=0.0608
# Epoch 085 | train loss=12.048773, train acc=0.1068 | test adjacency loss=12.619490, test CE loss=6.410276, test acc=0.0608
# Epoch 086 | train loss=12.028118, train acc=0.1068 | test adjacency loss=12.619069, test CE loss=6.409724, test acc=0.0608
# Epoch 087 | train loss=12.043773, train acc=0.1068 | test adjacency loss=12.618259, test CE loss=6.410087, test acc=0.0608
# Epoch 088 | train loss=12.027072, train acc=0.1068 | test adjacency loss=12.614824, test CE loss=6.405205, test acc=0.0608
# Epoch 089 | train loss=11.996997, train acc=0.1053 | test adjacency loss=12.615059, test CE loss=6.407181, test acc=0.0608
# Epoch 090 | train loss=12.009123, train acc=0.1068 | test adjacency loss=12.613306, test CE loss=6.404724, test acc=0.0608
# Epoch 091 | train loss=12.005384, train acc=0.1068 | test adjacency loss=12.612991, test CE loss=6.404171, test acc=0.0608
# Epoch 092 | train loss=12.003212, train acc=0.1068 | test adjacency loss=12.611893, test CE loss=6.403522, test acc=0.0608
# Epoch 093 | train loss=11.992856, train acc=0.1068 | test adjacency loss=12.611360, test CE loss=6.405297, test acc=0.0608
# Epoch 094 | train loss=11.985390, train acc=0.1068 | test adjacency loss=12.611645, test CE loss=6.407045, test acc=0.0608
# Epoch 095 | train loss=11.992779, train acc=0.1068 | test adjacency loss=12.611170, test CE loss=6.406345, test acc=0.0608
# Epoch 096 | train loss=11.983492, train acc=0.1068 | test adjacency loss=12.607644, test CE loss=6.400810, test acc=0.0608
# Epoch 097 | train loss=11.987018, train acc=0.1068 | test adjacency loss=12.609562, test CE loss=6.404011, test acc=0.0608
# Epoch 098 | train loss=11.981125, train acc=0.1053 | test adjacency loss=12.608973, test CE loss=6.403537, test acc=0.0608
# Epoch 099 | train loss=11.979474, train acc=0.1068 | test adjacency loss=12.610300, test CE loss=6.405260, test acc=0.0608
# Epoch 100 | train loss=11.969332, train acc=0.1068 | test adjacency loss=12.608097, test CE loss=6.404211, test acc=0.0608
# Saved final adjacency-aware last-event checkpoint to model_outputs/where_transformer/winsize0.5h/where_transformer_adjacency_aware_last_event_0.5h_final.pt

# %% [markdown]
# # Adjacency-aware self-attentive-pooling model for the selected window

# %%
ADJACENCY_DISTANCE_WEIGHT = 2.0

edge_zone_df = pd.read_csv(EDGE_ZONE_PATH)
zone_edges = [
    (int(from_zone), int(to_zone))
    for from_zone, to_zone in zip(edge_zone_df["from_zone"], edge_zone_df["to_zone"])
    if 0 <= int(from_zone) < num_zones and 0 <= int(to_zone) < num_zones
]
zone_graph = ig.Graph(n=num_zones, edges=zone_edges, directed=False)
zone_graph.simplify(multiple=True, loops=True)

set_seed()
adjacency_where_transformer_sap = WhereTransformerSAP(
    num_zones=num_zones,
    num_outage_types=num_outage_types,
    num_time_intervals=NUM_TIME_INTERVALS,
)
adjacency_where_transformer_sap.to(DEVICE)

adjacency_criterion = GraphDistanceUnorderedZoneLoss(
    zone_graph,
    num_zones=num_zones,
    distance_weight=ADJACENCY_DISTANCE_WEIGHT,
).to(DEVICE)
adjacency_optimizer = torch.optim.Adam(
    adjacency_where_transformer_sap.parameters(),
    lr=LEARNING_RATE,
)

adjacency_training_history = []

for epoch in range(1, NUM_EPOCHS + 1):
    adjacency_where_transformer_sap.train()
    adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss_sum = 0.0
    train_correct = 0
    train_count = 0
    accumulated_samples = 0
    train_order = torch.randperm(len(train_where_dataset)).tolist()

    for sample_idx in train_order:
        batch = sample_to_device(train_where_dataset[sample_idx], DEVICE)
        logits = adjacency_where_transformer_sap(
            batch["from_zone_indices"],
            batch["to_zone_indices"],
            batch["outage_type"],
            batch["time_interval_index"],
        )
        loss = adjacency_criterion(logits, batch["target"])
        loss.backward()

        train_loss_sum += loss.item()
        train_correct += unordered_zone_correct_count(logits, batch["target"])
        train_count += 1
        accumulated_samples += 1

        if accumulated_samples == VIRTUAL_BATCH_SIZE:
            adjacency_optimizer.step()
            adjacency_optimizer.zero_grad(set_to_none=True)
            accumulated_samples = 0

    if accumulated_samples:
        adjacency_optimizer.step()
        adjacency_optimizer.zero_grad(set_to_none=True)

    train_loss = train_loss_sum / train_count
    train_accuracy = train_correct / train_count

    adjacency_where_transformer_sap.eval()
    test_loss_sum = 0.0
    test_cross_entropy_loss_sum = 0.0
    test_correct = 0
    test_count = 0

    with torch.no_grad():
        for sample_idx in range(len(test_where_dataset)):
            batch = sample_to_device(test_where_dataset[sample_idx], DEVICE)
            logits = adjacency_where_transformer_sap(
                batch["from_zone_indices"],
                batch["to_zone_indices"],
                batch["outage_type"],
                batch["time_interval_index"],
            )
            loss = adjacency_criterion(logits, batch["target"])
            cross_entropy_loss = unordered_zone_loss(logits, batch["target"])

            test_loss_sum += loss.item()
            test_cross_entropy_loss_sum += cross_entropy_loss.item()
            test_correct += unordered_zone_correct_count(logits, batch["target"])
            test_count += 1

    test_loss = test_loss_sum / test_count
    test_cross_entropy_loss = test_cross_entropy_loss_sum / test_count
    test_accuracy = test_correct / test_count

    epoch_metrics = {
        "epoch": epoch,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "test_loss": test_loss,
        "test_cross_entropy_loss": test_cross_entropy_loss,
        "test_accuracy": test_accuracy,
    }
    adjacency_training_history.append(epoch_metrics)

    print(
        f"Epoch {epoch:03d} | "
        f"train loss={train_loss:.6f}, train acc={train_accuracy:.4f} | "
        f"test adjacency loss={test_loss:.6f}, "
        f"test CE loss={test_cross_entropy_loss:.6f}, "
        f"test acc={test_accuracy:.4f}"
    )

sap_adjacency_checkpoint_path = (
    MODEL_OUTPUT_DIR / f"where_transformer_adjacency_aware_sap_{WINDOW_LABEL}_final.pt"
)

torch.save(
    {
        "model_state_dict": adjacency_where_transformer_sap.state_dict(),
        "window_hours": WINDOW_HOURS,
        "window_label": WINDOW_LABEL,
        "dataset": dataset_path.name,
        "window_selection_manifest": str(WINDOW_SELECTION_PATH),
        "window_selection": window_selection,
        "pooling": "self_attentive",
        "num_zones": num_zones,
        "num_outage_types": num_outage_types,
        "num_time_intervals": NUM_TIME_INTERVALS,
        "zone_embedding_dim": ZONE_EMBEDDING_DIM,
        "outage_type_embedding_dim": OUTAGE_TYPE_EMBEDDING_DIM,
        "time_interval_embedding_dim": TIME_INTERVAL_EMBEDDING_DIM,
        "transformer_dim": TRANSFORMER_DIM,
        "dropout": DROPOUT,
        "outage_type_to_id": OUTAGE_TYPE_TO_ID,
        "distance_weight": ADJACENCY_DISTANCE_WEIGHT,
        "training_history": adjacency_training_history,
    },
    sap_adjacency_checkpoint_path,
)

print(
    "Saved final adjacency-aware self-attentive-pooling checkpoint to "
    f"{sap_adjacency_checkpoint_path}"
)
# Out:
# Epoch 001 | train loss=13.983230, train acc=0.0015 | test adjacency loss=13.831951, test CE loss=6.629346, test acc=0.0055
# Epoch 002 | train loss=13.907267, train acc=0.0030 | test adjacency loss=13.773782, test CE loss=6.598166, test acc=0.0000
# Epoch 003 | train loss=13.843780, train acc=0.0030 | test adjacency loss=13.718587, test CE loss=6.569778, test acc=0.0000
# Epoch 004 | train loss=13.742305, train acc=0.0030 | test adjacency loss=13.666836, test CE loss=6.543264, test acc=0.0000
# Epoch 005 | train loss=13.693383, train acc=0.0059 | test adjacency loss=13.615639, test CE loss=6.517574, test acc=0.0000
# Epoch 006 | train loss=13.635533, train acc=0.0030 | test adjacency loss=13.566523, test CE loss=6.493987, test acc=0.0000
# Epoch 007 | train loss=13.575153, train acc=0.0030 | test adjacency loss=13.520886, test CE loss=6.472448, test acc=0.0055
# Epoch 008 | train loss=13.505541, train acc=0.0045 | test adjacency loss=13.477138, test CE loss=6.452771, test acc=0.0110
# Epoch 009 | train loss=13.453583, train acc=0.0089 | test adjacency loss=13.434911, test CE loss=6.435232, test acc=0.0110
# Epoch 010 | train loss=13.397809, train acc=0.0059 | test adjacency loss=13.394149, test CE loss=6.417668, test acc=0.0166
# Epoch 011 | train loss=13.345725, train acc=0.0059 | test adjacency loss=13.355395, test CE loss=6.403129, test acc=0.0166
# Epoch 012 | train loss=13.279306, train acc=0.0119 | test adjacency loss=13.318160, test CE loss=6.388715, test acc=0.0166
# Epoch 013 | train loss=13.238012, train acc=0.0089 | test adjacency loss=13.281374, test CE loss=6.376453, test acc=0.0221
# Epoch 014 | train loss=13.190088, train acc=0.0089 | test adjacency loss=13.246740, test CE loss=6.365504, test acc=0.0221
# Epoch 015 | train loss=13.148683, train acc=0.0104 | test adjacency loss=13.214929, test CE loss=6.356862, test acc=0.0221
# Epoch 016 | train loss=13.091613, train acc=0.0148 | test adjacency loss=13.182770, test CE loss=6.349044, test acc=0.0221
# Epoch 017 | train loss=13.050554, train acc=0.0104 | test adjacency loss=13.153788, test CE loss=6.343244, test acc=0.0221
# Epoch 018 | train loss=13.009043, train acc=0.0134 | test adjacency loss=13.125109, test CE loss=6.338864, test acc=0.0166
# Epoch 019 | train loss=12.972196, train acc=0.0148 | test adjacency loss=13.097680, test CE loss=6.334578, test acc=0.0276
# Epoch 020 | train loss=12.923415, train acc=0.0208 | test adjacency loss=13.072427, test CE loss=6.333663, test acc=0.0276
# Epoch 021 | train loss=12.889878, train acc=0.0252 | test adjacency loss=13.048858, test CE loss=6.332151, test acc=0.0276
# Epoch 022 | train loss=12.860967, train acc=0.0312 | test adjacency loss=13.025803, test CE loss=6.331758, test acc=0.0221
# Epoch 023 | train loss=12.816575, train acc=0.0326 | test adjacency loss=13.004976, test CE loss=6.332530, test acc=0.0276
# Epoch 024 | train loss=12.779029, train acc=0.0445 | test adjacency loss=12.984055, test CE loss=6.332843, test acc=0.0276
# Epoch 025 | train loss=12.735723, train acc=0.0415 | test adjacency loss=12.966604, test CE loss=6.336485, test acc=0.0276
# Epoch 026 | train loss=12.717392, train acc=0.0490 | test adjacency loss=12.948563, test CE loss=6.339756, test acc=0.0276
# Epoch 027 | train loss=12.697899, train acc=0.0608 | test adjacency loss=12.932394, test CE loss=6.343324, test acc=0.0276
# Epoch 028 | train loss=12.651385, train acc=0.0623 | test adjacency loss=12.915611, test CE loss=6.344153, test acc=0.0276
# Epoch 029 | train loss=12.627566, train acc=0.0697 | test adjacency loss=12.901440, test CE loss=6.349803, test acc=0.0331
# Epoch 030 | train loss=12.612548, train acc=0.0697 | test adjacency loss=12.888422, test CE loss=6.354879, test acc=0.0331
# Epoch 031 | train loss=12.599881, train acc=0.0772 | test adjacency loss=12.876010, test CE loss=6.359603, test acc=0.0331
# Epoch 032 | train loss=12.575604, train acc=0.0816 | test adjacency loss=12.864503, test CE loss=6.363137, test acc=0.0331
# Epoch 033 | train loss=12.549234, train acc=0.0846 | test adjacency loss=12.852082, test CE loss=6.365678, test acc=0.0387
# Epoch 034 | train loss=12.520981, train acc=0.0831 | test adjacency loss=12.841375, test CE loss=6.372167, test acc=0.0387
# Epoch 035 | train loss=12.500598, train acc=0.0905 | test adjacency loss=12.832340, test CE loss=6.376710, test acc=0.0387
# Epoch 036 | train loss=12.491624, train acc=0.0935 | test adjacency loss=12.823692, test CE loss=6.380885, test acc=0.0442
# Epoch 037 | train loss=12.471938, train acc=0.0920 | test adjacency loss=12.815012, test CE loss=6.385757, test acc=0.0497
# Epoch 038 | train loss=12.459633, train acc=0.0994 | test adjacency loss=12.806298, test CE loss=6.390527, test acc=0.0552
# Epoch 039 | train loss=12.420667, train acc=0.0979 | test adjacency loss=12.797567, test CE loss=6.393334, test acc=0.0552
# Epoch 040 | train loss=12.419119, train acc=0.0979 | test adjacency loss=12.791043, test CE loss=6.399015, test acc=0.0552
# Epoch 041 | train loss=12.414500, train acc=0.0994 | test adjacency loss=12.784755, test CE loss=6.403984, test acc=0.0552
# Epoch 042 | train loss=12.399329, train acc=0.0964 | test adjacency loss=12.777995, test CE loss=6.406953, test acc=0.0552
# Epoch 043 | train loss=12.374618, train acc=0.1039 | test adjacency loss=12.773095, test CE loss=6.413396, test acc=0.0552
# Epoch 044 | train loss=12.368542, train acc=0.1024 | test adjacency loss=12.766854, test CE loss=6.415828, test acc=0.0552
# Epoch 045 | train loss=12.342550, train acc=0.1039 | test adjacency loss=12.761361, test CE loss=6.420568, test acc=0.0552
# Epoch 046 | train loss=12.335397, train acc=0.1039 | test adjacency loss=12.756673, test CE loss=6.422416, test acc=0.0552
# Epoch 047 | train loss=12.315395, train acc=0.1009 | test adjacency loss=12.751449, test CE loss=6.426398, test acc=0.0552
# Epoch 048 | train loss=12.317415, train acc=0.1039 | test adjacency loss=12.747191, test CE loss=6.429971, test acc=0.0552
# Epoch 049 | train loss=12.303112, train acc=0.1039 | test adjacency loss=12.742736, test CE loss=6.431630, test acc=0.0552
# Epoch 050 | train loss=12.284978, train acc=0.1039 | test adjacency loss=12.738225, test CE loss=6.434703, test acc=0.0552
# Epoch 051 | train loss=12.283385, train acc=0.1053 | test adjacency loss=12.734565, test CE loss=6.436041, test acc=0.0552
# Epoch 052 | train loss=12.272665, train acc=0.1053 | test adjacency loss=12.729102, test CE loss=6.436918, test acc=0.0552
# Epoch 053 | train loss=12.262214, train acc=0.1039 | test adjacency loss=12.726760, test CE loss=6.439341, test acc=0.0552
# Epoch 054 | train loss=12.260960, train acc=0.1053 | test adjacency loss=12.723072, test CE loss=6.441037, test acc=0.0552
# Epoch 055 | train loss=12.242117, train acc=0.1039 | test adjacency loss=12.720951, test CE loss=6.445253, test acc=0.0552
# Epoch 056 | train loss=12.242768, train acc=0.1053 | test adjacency loss=12.716585, test CE loss=6.444368, test acc=0.0552
# Epoch 057 | train loss=12.226919, train acc=0.1053 | test adjacency loss=12.714070, test CE loss=6.446881, test acc=0.0552
# Epoch 058 | train loss=12.221186, train acc=0.1053 | test adjacency loss=12.710983, test CE loss=6.447378, test acc=0.0552
# Epoch 059 | train loss=12.211382, train acc=0.1068 | test adjacency loss=12.708892, test CE loss=6.450409, test acc=0.0608
# Epoch 060 | train loss=12.196622, train acc=0.1068 | test adjacency loss=12.706165, test CE loss=6.451538, test acc=0.0608
# Epoch 061 | train loss=12.183681, train acc=0.1053 | test adjacency loss=12.702924, test CE loss=6.450803, test acc=0.0608
# Epoch 062 | train loss=12.175962, train acc=0.1039 | test adjacency loss=12.700063, test CE loss=6.449772, test acc=0.0608
# Epoch 063 | train loss=12.180118, train acc=0.1039 | test adjacency loss=12.698105, test CE loss=6.451939, test acc=0.0608
# Epoch 064 | train loss=12.179021, train acc=0.1053 | test adjacency loss=12.697086, test CE loss=6.455981, test acc=0.0608
# Epoch 065 | train loss=12.170588, train acc=0.1068 | test adjacency loss=12.692975, test CE loss=6.452742, test acc=0.0608
# Epoch 066 | train loss=12.171314, train acc=0.1053 | test adjacency loss=12.689941, test CE loss=6.452667, test acc=0.0608
# Epoch 067 | train loss=12.157984, train acc=0.1039 | test adjacency loss=12.690223, test CE loss=6.458456, test acc=0.0608
# Epoch 068 | train loss=12.143588, train acc=0.1068 | test adjacency loss=12.687871, test CE loss=6.457860, test acc=0.0608
# Epoch 069 | train loss=12.137652, train acc=0.1053 | test adjacency loss=12.684993, test CE loss=6.456354, test acc=0.0608
# Epoch 070 | train loss=12.140040, train acc=0.1068 | test adjacency loss=12.683435, test CE loss=6.455016, test acc=0.0608
# Epoch 071 | train loss=12.144290, train acc=0.1039 | test adjacency loss=12.680432, test CE loss=6.452057, test acc=0.0608
# Epoch 072 | train loss=12.143235, train acc=0.1039 | test adjacency loss=12.678080, test CE loss=6.452979, test acc=0.0608
# Epoch 073 | train loss=12.113026, train acc=0.1053 | test adjacency loss=12.677430, test CE loss=6.452820, test acc=0.0608
# Epoch 074 | train loss=12.093997, train acc=0.1053 | test adjacency loss=12.675765, test CE loss=6.456337, test acc=0.0608
# Epoch 075 | train loss=12.117324, train acc=0.1053 | test adjacency loss=12.674277, test CE loss=6.455362, test acc=0.0608
# Epoch 076 | train loss=12.101822, train acc=0.1053 | test adjacency loss=12.672143, test CE loss=6.454219, test acc=0.0608
# Epoch 077 | train loss=12.068911, train acc=0.1068 | test adjacency loss=12.671452, test CE loss=6.454442, test acc=0.0608
# Epoch 078 | train loss=12.078423, train acc=0.1068 | test adjacency loss=12.667504, test CE loss=6.450883, test acc=0.0608
# Epoch 079 | train loss=12.084347, train acc=0.1068 | test adjacency loss=12.668373, test CE loss=6.451420, test acc=0.0608
# Epoch 080 | train loss=12.078699, train acc=0.1053 | test adjacency loss=12.664824, test CE loss=6.449505, test acc=0.0608
# Epoch 081 | train loss=12.080911, train acc=0.1068 | test adjacency loss=12.665309, test CE loss=6.451382, test acc=0.0608
# Epoch 082 | train loss=12.078959, train acc=0.1053 | test adjacency loss=12.663248, test CE loss=6.449292, test acc=0.0608
# Epoch 083 | train loss=12.068358, train acc=0.1053 | test adjacency loss=12.661664, test CE loss=6.450842, test acc=0.0608
# Epoch 084 | train loss=12.072179, train acc=0.1068 | test adjacency loss=12.660438, test CE loss=6.449777, test acc=0.0608
# Epoch 085 | train loss=12.049282, train acc=0.1068 | test adjacency loss=12.659317, test CE loss=6.449570, test acc=0.0608
# Epoch 086 | train loss=12.055458, train acc=0.1053 | test adjacency loss=12.658671, test CE loss=6.447168, test acc=0.0608
# Epoch 087 | train loss=12.050476, train acc=0.1039 | test adjacency loss=12.657979, test CE loss=6.448536, test acc=0.0608
# Epoch 088 | train loss=12.048152, train acc=0.1068 | test adjacency loss=12.657022, test CE loss=6.448384, test acc=0.0608
# Epoch 089 | train loss=12.032318, train acc=0.1068 | test adjacency loss=12.656155, test CE loss=6.448020, test acc=0.0608
# Epoch 090 | train loss=12.032779, train acc=0.1053 | test adjacency loss=12.655464, test CE loss=6.447537, test acc=0.0608
# Epoch 091 | train loss=12.027773, train acc=0.1039 | test adjacency loss=12.654330, test CE loss=6.446269, test acc=0.0608
# Epoch 092 | train loss=12.014143, train acc=0.1053 | test adjacency loss=12.651306, test CE loss=6.442236, test acc=0.0608
# Epoch 093 | train loss=12.018026, train acc=0.1068 | test adjacency loss=12.652742, test CE loss=6.446061, test acc=0.0608
# Epoch 094 | train loss=12.017100, train acc=0.1039 | test adjacency loss=12.652293, test CE loss=6.445719, test acc=0.0608
# Epoch 095 | train loss=12.020574, train acc=0.1053 | test adjacency loss=12.650483, test CE loss=6.442169, test acc=0.0608
# Epoch 096 | train loss=12.013671, train acc=0.1068 | test adjacency loss=12.649859, test CE loss=6.442570, test acc=0.0608
# Epoch 097 | train loss=12.005319, train acc=0.1053 | test adjacency loss=12.649984, test CE loss=6.442519, test acc=0.0608
# Epoch 098 | train loss=11.997863, train acc=0.1053 | test adjacency loss=12.650283, test CE loss=6.444438, test acc=0.0608
# Epoch 099 | train loss=11.993047, train acc=0.1039 | test adjacency loss=12.649274, test CE loss=6.445129, test acc=0.0608
# Epoch 100 | train loss=11.991721, train acc=0.1068 | test adjacency loss=12.647875, test CE loss=6.440600, test acc=0.0608
# Saved final adjacency-aware self-attentive-pooling checkpoint to model_outputs/where_transformer/winsize0.5h/where_transformer_adjacency_aware_sap_0.5h_final.pt

# %%
baseline_prediction_df = collect_where_predictions(
    where_transformer,
    test_where_dataset,
    DEVICE,
)

baseline_sap_df = collect_where_predictions(
    where_transformer_sap,
    test_where_dataset,
    DEVICE,
)

adjacency_prediction_df = collect_where_predictions(
    adjacency_where_transformer,
    test_where_dataset,
    DEVICE,
)

adjacency_prediction_sap_df = collect_where_predictions(
    adjacency_where_transformer_sap,
    test_where_dataset,
    DEVICE,
)


baseline_pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in baseline_prediction_df.itertuples(index=False)
    ],
    dtype=float,
)
baseline_pair_distances_sap = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in baseline_sap_df.itertuples(index=False)
    ],
    dtype=float,
)
adjacency_pair_distances = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in adjacency_prediction_df.itertuples(index=False)
    ],
    dtype=float,
)
adjacency_pair_distances_sap = np.asarray(
    [
        unordered_pair_graph_distance(
            (row.true_from_zone, row.true_to_zone),
            (row.pred_from_zone, row.pred_to_zone),
            zone_distance_lookup,
        )
        for row in adjacency_prediction_sap_df.itertuples(index=False)
    ],
    dtype=float,
)


baseline_summary = summarize_pair_distances(baseline_pair_distances)
baseline_summary["exact_pair_accuracy"] = baseline_prediction_df[
    "exact_pair_match"
].mean()

baseline_summary_sap = summarize_pair_distances(baseline_pair_distances_sap)
baseline_summary_sap["exact_pair_accuracy"] = baseline_sap_df["exact_pair_match"].mean()

adjacency_summary = summarize_pair_distances(adjacency_pair_distances)
adjacency_summary["exact_pair_accuracy"] = adjacency_prediction_df[
    "exact_pair_match"
].mean()
adjacency_summary["mean_distance_reduction_vs_cross_entropy"] = 1 - (
    adjacency_summary["mean_distance"] / baseline_summary["mean_distance"]
)

adjacency_summary_sap = summarize_pair_distances(adjacency_pair_distances_sap)
adjacency_summary_sap["exact_pair_accuracy"] = adjacency_prediction_sap_df[
    "exact_pair_match"
].mean()
adjacency_summary_sap["mean_distance_reduction_vs_cross_entropy"] = 1 - (
    adjacency_summary_sap["mean_distance"] / baseline_summary_sap["mean_distance"]
)

adjacency_comparison_df = pd.DataFrame(
    [
        {"model": "Cross entropy", **baseline_summary},
        {"model": "Cross entropy (SAP)", **baseline_summary_sap},
        {"model": "Adjacency-aware", **adjacency_summary},
        {"model": "Adjacency-aware (SAP)", **adjacency_summary_sap},
    ]
)

comparison_table_path = (
    MODEL_OUTPUT_DIR / f"where_transformer_{WINDOW_LABEL}_model_comparison.csv"
)
adjacency_comparison_df.to_csv(comparison_table_path, index=False)
print(f"Saved {WINDOW_LABEL} model comparison to {comparison_table_path}")

display(adjacency_comparison_df.round(3))
print(
    "Adjacency-aware mean unordered pair distance reduction vs cross entropy: "
    f"{adjacency_summary['mean_distance_reduction_vs_cross_entropy']:.1%}"
)
print(
    "Adjacency-aware (SAP) mean unordered pair distance reduction vs cross entropy: "
    f"{adjacency_summary_sap['mean_distance_reduction_vs_cross_entropy']:.1%}"
)

bins = np.arange(-0.5, zone_graph_diameter + 1.5, 1)
bin_centers = (bins[:-1] + bins[1:]) / 2
bar_width = 0.2
baseline_counts, _ = np.histogram(
    baseline_pair_distances[np.isfinite(baseline_pair_distances)], bins=bins
)
baseline_sap_counts, _ = np.histogram(
    baseline_pair_distances_sap[np.isfinite(baseline_pair_distances_sap)], bins=bins
)
adjacency_counts, _ = np.histogram(
    adjacency_pair_distances[np.isfinite(adjacency_pair_distances)], bins=bins
)
adjacency_sap_counts, _ = np.histogram(
    adjacency_pair_distances_sap[np.isfinite(adjacency_pair_distances_sap)], bins=bins
)
baseline_percentages = 100 * baseline_counts / baseline_counts.sum()
baseline_sap_percentages = 100 * baseline_sap_counts / baseline_sap_counts.sum()
adjacency_percentages = 100 * adjacency_counts / adjacency_counts.sum()
adjacency_sap_percentages = 100 * adjacency_sap_counts / adjacency_sap_counts.sum()

fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(
    bin_centers - 1.5 * bar_width,
    baseline_percentages,
    width=bar_width,
    label="Cross entropy",
    align="center",
)
ax.bar(
    bin_centers - 0.5 * bar_width,
    baseline_sap_percentages,
    width=bar_width,
    label="Cross entropy (SAP)",
    align="center",
)
ax.bar(
    bin_centers + 0.5 * bar_width,
    adjacency_percentages,
    width=bar_width,
    label="Adjacency-aware",
    align="center",
)
ax.bar(
    bin_centers + 1.5 * bar_width,
    adjacency_sap_percentages,
    width=bar_width,
    label="Adjacency-aware (SAP)",
    align="center",
)
ax.set_xticks(bin_centers)
ax.set_xlabel("Unordered zone-pair graph distance")
ax.set_ylabel("Percentage (%)")
# ax.set_title("Cross-entropy vs adjacency-aware graph-distance error")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_{WINDOW_LABEL}_cross_entropy_vs_adjacency_graph_distance_error_bpa.pdf",
    dpi=300,
)
plt.show()
# Out:
# Saved 0.5h model comparison to model_outputs/where_transformer/winsize0.5h/where_transformer_0.5h_model_comparison.csv
#                    model  mean_distance  median_distance  p90_distance  \
# 0          Cross entropy          1.586              1.5           2.5
# 1    Cross entropy (SAP)          1.552              1.5           2.5
# 2        Adjacency-aware          1.260              1.0           2.0
# 3  Adjacency-aware (SAP)          1.262              1.0           2.0
#
#    same_zone_pair_rate  adjacent_or_same_pair_rate  unreachable_count  \
# 0                0.022                       0.376                  0
# 1                0.017                       0.381                  0
# 2                0.061                       0.608                  0
# 3                0.061                       0.597                  0
#
#    exact_pair_accuracy  mean_distance_reduction_vs_cross_entropy
# 0                0.022                                       NaN
# 1                0.017                                       NaN
# 2                0.061                                     0.206
# 3                0.061                                     0.187
# Adjacency-aware mean unordered pair distance reduction vs cross entropy: 20.6%
# Adjacency-aware (SAP) mean unordered pair distance reduction vs cross entropy: 18.7%

# %% [markdown]
# # Selected-window paper plot

# %%
paper_bar_width = 0.36

fig, ax = plt.subplots(figsize=(8, 4))
ax.bar(
    bin_centers - paper_bar_width / 2,
    baseline_percentages,
    width=paper_bar_width,
    label="Cross entropy",
    align="center",
)
ax.bar(
    bin_centers + paper_bar_width / 2,
    adjacency_percentages,
    width=paper_bar_width,
    label="Adjacency-aware",
    align="center",
)
ax.set_xticks(bin_centers)
ax.set_xlabel("Unordered zone-pair graph distance")
ax.set_ylabel("Percentage (%)")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(
    MODEL_OUTPUT_DIR
    / f"where_transformer_{WINDOW_LABEL}_cross_entropy_vs_adjacency_graph_distance_error_paper_bpa.pdf",
    dpi=300,
)
plt.show()
