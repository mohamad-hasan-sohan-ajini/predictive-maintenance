# %%
import csv
from pathlib import Path

# %%
actual_path = Path("raw-zip-actual")
actual_files = sorted(actual_path.glob("*.zip"))
print(len(actual_files))
actual_files[:5]
# Out:
# 230
# [PosixPath('raw-zip-actual/20060101RTLineOutages_csv.zip'),
#  PosixPath('raw-zip-actual/20060201RTLineOutages_csv.zip'),
#  PosixPath('raw-zip-actual/20060301RTLineOutages_csv.zip'),
#  PosixPath('raw-zip-actual/20060401RTLineOutages_csv.zip'),
#  PosixPath('raw-zip-actual/20060501RTLineOutages_csv.zip')]

# %%
scheduled_path = Path("raw-zip-scheduled")
scheduled_files = sorted(scheduled_path.glob("*.zip"))
print(len(scheduled_files))
scheduled_files[:5]
# Out:
# 218
# [PosixPath('raw-zip-scheduled/20080101SCLineOutages_csv.zip'),
#  PosixPath('raw-zip-scheduled/20080201SCLineOutages_csv.zip'),
#  PosixPath('raw-zip-scheduled/20080301SCLineOutages_csv.zip'),
#  PosixPath('raw-zip-scheduled/20080401SCLineOutages_csv.zip'),
#  PosixPath('raw-zip-scheduled/20080501SCLineOutages_csv.zip')]

# %%
import re
from collections import defaultdict, namedtuple

ActualOutage = namedtuple(
    "ActualOutage",
    [
        "timestamp",
        "ptid",
        "equipment_name",
        "outage_datetime",
        "bus1",
        "bus2",
        "voltage",
    ],
)
ScheduledOutage = namedtuple(
    "ScheduledOutage",
    [
        "timestamp",
        "ptid",
        "equipment_name",
        "scheduled_out_datetime",
        "scheduled_in_datetime",
        "bus1",
        "bus2",
        "voltage",
    ],
)
Interval = namedtuple("Interval", ["start", "end"])

equipment_name_pattern = r"^([A-Za-z0-9._ -]{8})-([A-Za-z0-9._ -]{8})_(\d{2,3})_(.+)$"

# %%
zip_path = actual_files[0]

# %%
import io
from datetime import datetime
from zipfile import ZipFile


def parse_actual_outage(row):
    equipment_name = row["Equipment Name"]
    m = re.match(equipment_name_pattern, equipment_name)
    if m is None:
        return None
    # Before Feb. 2015 the key had an extra space at the beginning, so try both
    # Before Oct. 2010 exists a trailing space!
    outage_date_time_keys = [
        "Outage Date/Time",
        " Outage Date/Time",
        " Outage Date/Time ",
    ]
    for outage_date_time_key in outage_date_time_keys:
        if outage_date_time_key in row:
            outage_date_time = row[outage_date_time_key]
            break
    return ActualOutage(
        timestamp=datetime.strptime(row["Timestamp"], "%m/%d/%Y %H:%M:%S"),
        ptid=int(row["PTID"]),
        equipment_name=row["Equipment Name"],
        outage_datetime=datetime.strptime(outage_date_time, "%m/%d/%Y %H:%M:%S"),
        bus1=m.group(1),
        bus2=m.group(2),
        voltage=int(m.group(3)),
    )


def parse_scheduled_outage(row):
    equipment_name = row["Equipment Name"]
    m = re.match(equipment_name_pattern, equipment_name)
    if m is None:
        return None
    return ScheduledOutage(
        timestamp=datetime.strptime(row["Timestamp"], "%m/%d/%Y %H:%M:%S"),
        ptid=int(row["PTID"]),
        equipment_name=row["Equipment Name"],
        scheduled_out_datetime=datetime.strptime(
            row["Scheduled Out Date/Time"],
            "%m/%d/%Y %H:%M:%S",
        ),
        scheduled_in_datetime=datetime.strptime(
            row["Scheduled In Date/Time"],
            "%m/%d/%Y %H:%M:%S",
        ),
        bus1=m.group(1),
        bus2=m.group(2),
        voltage=int(m.group(3)),
    )


def list_csvs(zip_path):
    with ZipFile(zip_path) as z:
        return [i for i in sorted(z.namelist()) if i.endswith(".csv")]


def read_csv_from_zip(zip_path, csv_name, parse_row):
    with ZipFile(zip_path) as z:
        with z.open(csv_name) as f:
            data = f.read()
        csv_reader = csv.DictReader(io.StringIO(data.decode("utf-8")))
        # Only keep rows with line outages
        data = [parse_row(row) for row in csv_reader]
        data = [row for row in data if row is not None]
    return data


def summarize_data(data):
    """Implement processing method described in this paper titled "Transmission grid outage statistics extracted from a webpage logging outages in northeast america" """
    # group by ptid
    by_ptid = defaultdict(list)
    for outage in data:
        by_ptid[outage.ptid].append(outage)
    # separate ptid by outage date
    by_ptid_and_outage_date = defaultdict(lambda: defaultdict(list))
    for ptid, rows in by_ptid.items():
        for row in rows:
            by_ptid_and_outage_date[ptid][row.outage_datetime].append(row)
        # check partition length be at least two, for beginning and ending
        for partition_key in by_ptid_and_outage_date[ptid].keys():
            partition_list = by_ptid_and_outage_date[ptid][row.outage_datetime]
            if len(partition_list) == 1:
                partition_list.append(partition_list[0])
    # compression by skipping redundancies data
    summary = {}
    for ptid, date_log_dd in by_ptid_and_outage_date.items():
        partitions = {}
        for date, log_list in date_log_dd.items():
            interval = Interval(log_list[0], log_list[-1])
            partitions[date] = interval
        summary[ptid] = partitions
    return summary


# Example using an existing variable in the notebook:
zip_path = actual_files[0]
print(zip_path)
print("members:", list_csvs(zip_path))

# Read one file from the zip (text)
member = list_csvs(zip_path)[0]
data = read_csv_from_zip(zip_path, member, parse_actual_outage)
print(len(data))
summary = summarize_data(data)
print(len(summary))
# Out:
# raw-zip-actual/20060101RTLineOutages_csv.zip
# members: ['20060101RTLineOutages.csv', '20060102RTLineOutages.csv', '20060103RTLineOutages.csv', '20060104RTLineOutages.csv', '20060105RTLineOutages.csv', '20060106RTLineOutages.csv', '20060107RTLineOutages.csv', '20060108RTLineOutages.csv', '20060109RTLineOutages.csv', '20060110RTLineOutages.csv', '20060111RTLineOutages.csv', '20060112RTLineOutages.csv', '20060113RTLineOutages.csv', '20060114RTLineOutages.csv', '20060115RTLineOutages.csv', '20060116RTLineOutages.csv', '20060117RTLineOutages.csv', '20060118RTLineOutages.csv', '20060119RTLineOutages.csv', '20060120RTLineOutages.csv', '20060121RTLineOutages.csv', '20060122RTLineOutages.csv', '20060123RTLineOutages.csv', '20060124RTLineOutages.csv', '20060125RTLineOutages.csv', '20060126RTLineOutages.csv', '20060127RTLineOutages.csv', '20060128RTLineOutages.csv', '20060129RTLineOutages.csv', '20060130RTLineOutages.csv', '20060131RTLineOutages.csv']
# 8640
# 30

# %%
from tqdm import tqdm

actual_outages = defaultdict(dict)
for zip_path in tqdm(actual_files):
    for member in list_csvs(zip_path):
        data = read_csv_from_zip(zip_path, member, parse_actual_outage)
ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 2, 8, 18, 21), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2015, 2, 9, 23, 57, 22), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 2, 8, 18, 21), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2015, 6, 1, 12, 41): Interval(start=ActualOutage(timestamp=datetime.datetime(2015, 6, 1, 12, 47, 8), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 6, 1, 12, 41), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2015, 6, 6, 23, 57, 6), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 6, 1, 12, 41), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2015, 6, 16, 12, 44): Interval(start=ActualOutage(timestamp=datetime.datetime(2015, 6, 16, 12, 47, 6), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 6, 16, 12, 44), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2015, 6, 18, 8, 37, 5), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 6, 16, 12, 44), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2015, 6, 18, 8, 35): Interval(start=ActualOutage(timestamp=datetime.datetime(2015, 6, 18, 8, 37, 5), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 6, 18, 8, 35), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2015, 6, 18, 23, 57, 1), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 6, 18, 8, 35), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2015, 6, 26, 8, 9): Interval(start=ActualOutage(timestamp=datetime.datetime(2015, 6, 26, 8, 12, 5), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 6, 26, 8, 9), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2015, 6, 26, 23, 57, 5), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 6, 26, 8, 9), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2015, 7, 22, 17, 45): Interval(start=ActualOutage(timestamp=datetime.datetime(2015, 7, 22, 17, 47, 7), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 7, 22, 17, 45), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2015, 7, 23, 23, 57, 4), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 7, 22, 17, 45), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2015, 7, 23, 7, 35): Interval(start=ActualOutage(timestamp=datetime.datetime(2015, 7, 23, 7, 42, 4), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 7, 23, 7, 35), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2015, 7, 23, 23, 57, 4), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 7, 23, 7, 35), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2015, 7, 24, 6, 8): Interval(start=ActualOutage(timestamp=datetime.datetime(2015, 7, 24, 6, 12, 5), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 7, 24, 6, 8), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2015, 7, 24, 23, 57, 6), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2015, 7, 24, 6, 8), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 4, 3, 2, 28): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 4, 3, 2, 32, 7), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 4, 3, 2, 28), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 4, 3, 23, 57, 11), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 4, 3, 2, 28), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 4, 13, 20, 46): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 4, 13, 20, 47, 49), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 4, 13, 20, 46), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 4, 15, 23, 57, 10), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 4, 13, 20, 46), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 5, 16, 11, 45): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 5, 16, 11, 47, 31), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 5, 16, 11, 45), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 5, 19, 23, 57, 3), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 5, 16, 11, 45), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 6, 20, 12, 1): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 6, 20, 12, 2, 42), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 6, 20, 12, 1), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 6, 24, 23, 57, 10), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 6, 20, 12, 1), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 7, 5, 9, 51): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 7, 5, 9, 57, 9), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 5, 9, 51), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 7, 10, 23, 57, 12), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 5, 9, 51), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 7, 12, 15, 49): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 7, 12, 15, 52, 9), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 12, 15, 49), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 7, 16, 23, 57, 8), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 12, 15, 49), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 7, 16, 13, 21): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 7, 16, 13, 27, 10), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 16, 13, 21), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 7, 19, 23, 57, 11), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 16, 13, 21), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 7, 22, 18, 41): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 7, 22, 18, 42, 7), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 22, 18, 41), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 7, 25, 23, 57, 13), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 22, 18, 41), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 7, 25, 10, 54): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 7, 25, 10, 57, 7), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 25, 10, 54), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 7, 25, 23, 57, 13), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 25, 10, 54), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 7, 25, 17, 30): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 7, 25, 17, 32, 7), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 25, 17, 30), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 7, 31, 23, 57, 8), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 7, 25, 17, 30), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 8, 2, 13, 7): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 8, 2, 13, 12, 7), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 8, 2, 13, 7), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 8, 3, 23, 57, 9), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 8, 2, 13, 7), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 8, 3, 12, 47): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 8, 3, 12, 52, 10), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 8, 3, 12, 47), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 9, 15, 23, 57, 8), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 8, 3, 12, 47), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2016, 8, 23, 13, 33): Interval(start=ActualOutage(timestamp=datetime.datetime(2016, 8, 23, 13, 37, 8), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 8, 23, 13, 33), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2016, 8, 23, 15, 7, 9), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2016, 8, 23, 13, 33), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
# ...
#  datetime.datetime(2021, 4, 8, 10, 36): Interval(start=ActualOutage(timestamp=datetime.datetime(2021, 4, 8, 9, 42), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 4, 8, 10, 36), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2021, 4, 28, 9, 22), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 4, 8, 10, 36), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2021, 4, 29, 10, 14): Interval(start=ActualOutage(timestamp=datetime.datetime(2021, 4, 29, 9, 17), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 4, 29, 10, 14), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2021, 10, 11, 8, 2, 1), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 4, 29, 10, 14), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2021, 10, 11, 9, 12): Interval(start=ActualOutage(timestamp=datetime.datetime(2021, 10, 11, 8, 17), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 10, 11, 9, 12), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2021, 11, 30, 13, 57, 1), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 10, 11, 9, 12), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2021, 11, 30, 15, 12): Interval(start=ActualOutage(timestamp=datetime.datetime(2021, 11, 30, 15, 17, 1), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 11, 30, 15, 12), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2021, 11, 30, 15, 22, 1), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 11, 30, 15, 12), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2021, 11, 30, 15, 26): Interval(start=ActualOutage(timestamp=datetime.datetime(2021, 11, 30, 15, 32, 1), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 11, 30, 15, 26), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2022, 2, 28, 9, 2, 1), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2021, 11, 30, 15, 26), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2022, 3, 4, 14, 48): Interval(start=ActualOutage(timestamp=datetime.datetime(2022, 3, 4, 14, 52), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 3, 4, 14, 48), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2022, 7, 31, 16, 2), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 3, 4, 14, 48), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2022, 8, 4, 20, 16): Interval(start=ActualOutage(timestamp=datetime.datetime(2022, 8, 4, 19, 22), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 8, 4, 20, 16), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2022, 11, 21, 8, 12), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 8, 4, 20, 16), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2022, 8, 17, 9, 0): Interval(start=ActualOutage(timestamp=datetime.datetime(2022, 8, 17, 8, 37), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 8, 17, 9, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2022, 8, 17, 11, 12), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 8, 17, 9, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2022, 9, 26, 11, 34): Interval(start=ActualOutage(timestamp=datetime.datetime(2022, 9, 26, 10, 37), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 9, 26, 11, 34), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2022, 9, 26, 11, 27), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 9, 26, 11, 34), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2022, 11, 21, 7, 0): Interval(start=ActualOutage(timestamp=datetime.datetime(2022, 11, 21, 8, 17), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 11, 21, 7, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2022, 11, 21, 9, 22), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 11, 21, 7, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2022, 11, 23, 13, 43): Interval(start=ActualOutage(timestamp=datetime.datetime(2022, 11, 23, 13, 47), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 11, 23, 13, 43), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2022, 11, 24, 4, 57), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 11, 23, 13, 43), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2022, 12, 12, 8, 20): Interval(start=ActualOutage(timestamp=datetime.datetime(2022, 12, 12, 8, 27), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 12, 12, 8, 20), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2023, 3, 28, 7, 2), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2022, 12, 12, 8, 20), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2023, 3, 28, 8, 0): Interval(start=ActualOutage(timestamp=datetime.datetime(2023, 3, 28, 7, 7), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2023, 3, 28, 8, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2023, 3, 28, 9, 37), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2023, 3, 28, 8, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2023, 3, 28, 11, 43): Interval(start=ActualOutage(timestamp=datetime.datetime(2023, 3, 28, 10, 47), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2023, 3, 28, 11, 43), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2023, 3, 30, 6, 57), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2023, 3, 28, 11, 43), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2023, 3, 30, 8, 0): Interval(start=ActualOutage(timestamp=datetime.datetime(2023, 3, 30, 7, 2), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2023, 3, 30, 8, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2023, 4, 18, 9, 2), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2023, 3, 30, 8, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2023, 7, 19, 9, 25): Interval(start=ActualOutage(timestamp=datetime.datetime(2023, 7, 19, 8, 32), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2023, 7, 19, 9, 25), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2023, 7, 19, 9, 42), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2023, 7, 19, 9, 25), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2024, 1, 21, 7, 40): Interval(start=ActualOutage(timestamp=datetime.datetime(2024, 1, 21, 7, 47), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 1, 21, 7, 40), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2024, 6, 4, 8, 7), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 1, 21, 7, 40), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2024, 7, 12, 16, 21): Interval(start=ActualOutage(timestamp=datetime.datetime(2024, 7, 12, 16, 32), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 7, 12, 16, 21), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2024, 7, 12, 18, 47), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 7, 12, 16, 21), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2024, 8, 19, 20, 1): Interval(start=ActualOutage(timestamp=datetime.datetime(2024, 8, 19, 20, 2), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 8, 19, 20, 1), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2024, 8, 20, 1, 57), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 8, 19, 20, 1), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2024, 9, 7, 2, 42): Interval(start=ActualOutage(timestamp=datetime.datetime(2024, 9, 7, 2, 47), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 9, 7, 2, 42), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2024, 9, 9, 14, 22), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 9, 7, 2, 42), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2024, 9, 29, 12, 38): Interval(start=ActualOutage(timestamp=datetime.datetime(2024, 9, 29, 12, 42), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 9, 29, 12, 38), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2024, 10, 31, 17, 12), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2024, 9, 29, 12, 38), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2025, 1, 30, 11, 41): Interval(start=ActualOutage(timestamp=datetime.datetime(2025, 1, 30, 11, 47), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 1, 30, 11, 41), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2025, 2, 26, 12, 32), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 1, 30, 11, 41), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2025, 3, 24, 9, 3): Interval(start=ActualOutage(timestamp=datetime.datetime(2025, 3, 24, 9, 7), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 3, 24, 9, 3), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2025, 3, 24, 14, 32), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 3, 24, 9, 3), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2025, 3, 24, 14, 38): Interval(start=ActualOutage(timestamp=datetime.datetime(2025, 3, 24, 14, 42), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 3, 24, 14, 38), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2025, 3, 24, 16, 27), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 3, 24, 14, 38), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2025, 3, 27, 9, 28): Interval(start=ActualOutage(timestamp=datetime.datetime(2025, 3, 27, 11, 27), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 3, 27, 9, 28), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2025, 3, 29, 16, 17), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 3, 27, 9, 28), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2025, 4, 4, 10, 56): Interval(start=ActualOutage(timestamp=datetime.datetime(2025, 4, 4, 11, 2), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 4, 4, 10, 56), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2025, 4, 4, 11, 2), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 4, 4, 10, 56), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2025, 4, 5, 0, 26): Interval(start=ActualOutage(timestamp=datetime.datetime(2025, 4, 5, 0, 27), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 4, 5, 0, 26), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2025, 5, 1, 9, 32), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 4, 5, 0, 26), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2025, 5, 1, 9, 41): Interval(start=ActualOutage(timestamp=datetime.datetime(2025, 5, 1, 9, 42), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 5, 1, 9, 41), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2025, 5, 1, 11, 47), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 5, 1, 9, 41), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2025, 5, 1, 11, 50): Interval(start=ActualOutage(timestamp=datetime.datetime(2025, 5, 1, 11, 52), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 5, 1, 11, 50), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2025, 6, 2, 8, 27), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 5, 1, 11, 50), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2025, 6, 2, 8, 0): Interval(start=ActualOutage(timestamp=datetime.datetime(2025, 6, 2, 8, 42), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 6, 2, 8, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2026, 2, 13, 14, 57), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2025, 6, 2, 8, 0), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115)),
#  datetime.datetime(2026, 2, 13, 14, 1): Interval(start=ActualOutage(timestamp=datetime.datetime(2026, 2, 13, 15, 2), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2026, 2, 13, 14, 1), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115), end=ActualOutage(timestamp=datetime.datetime(2026, 2, 24, 8, 12), ptid=25013, equipment_name='E.SAYRE_-NWAVERLY_115_956', outage_datetime=datetime.datetime(2026, 2, 13, 14, 1), bus1='E.SAYRE_', bus2='NWAVERLY', voltage=115))}

# %%
import pandas as pd

actual_outage_csv_path = Path("processed-actual-outages.csv")

# build a flat table from the nested defaultdict
rows = []
for ptid, partitions in actual_outages.items():
    for outage_dt, interval in partitions.items():
        rows.append(
            {
                "PTID": ptid,
                "Name": interval.start.equipment_name,
                "OutDatetime": outage_dt,
                "MinTimeStamp": interval.start.timestamp,
                "MaxTimeStamp": interval.end.timestamp,
                "Voltage": interval.start.voltage,
                "FirstBus": interval.start.bus1,
                "SecondBus": interval.start.bus2,
            }
        )

rows = sorted(rows, key=lambda x: x["OutDatetime"])
df = pd.DataFrame(rows)

# write out; use the existing json path with a .csv suffix
df.to_csv(actual_outage_csv_path, index=False)

print(f"saved {len(df)} rows to {actual_outage_csv_path}")
# Out:
# saved 74471 rows to processed-actual-outages.csv
